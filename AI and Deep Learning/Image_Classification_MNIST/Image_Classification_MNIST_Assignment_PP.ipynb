# %% [markdown]
# <a href="https://colab.research.google.com/github/how-to-train-your-model/data-science-portfolio/blob/main/Image_Classification_MNIST_Assignment_PP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # A.1 First Research/Programming Assignment

# %% [markdown]
# # Objective:
#  - In this notebook, we will build a DNN model for classifying MNIST digits. The DNN model will consist of 784 input nodes, a hidden layer with 128 nodes and 10 output nodes (corresponding to the 10 digits).
#  - We use mnist.load_data() to get the 70,000 images divided into a set of 60,000 training images and 10,000 test images. We hold back 5,000 of the 60,000 training images for validation.
#  - After training and evaluating our DNN model we analyze its performance. In particular, we use confusion matrices to compare the predicted classes with the class labels to try to determine why some images were misclassified by the model.
#  - We then obtain the 60,000 activation values of one of the hidden nodes for the (original) set of training data. We want to use these activation values as "proxies" for the predicted classes of the 60,000 images.
#  - And just like we compared the predicted classes with the class labels using confusion matrices to determine the efficacy of the model, we use box plots to visualize the relationship between the activation values of one hidden node and the class labels. We don't expect these activation values to have much "predictive power". In fact, the same activation values can be associated with multiple class labels resulting in a lot of overlap in the box plots.
#  - We also perform similar experiments comparing the values at two pixel locations in the images with the class labels. This time we use scatter plots to visualize the relationship between the pair of pixel values with the class labels (represented by different colored dots).
#  - Pixel values at two locations in image should not have much predictive value. To improve on this approach, we the PCA decomposition on both the raw data of 784 pixel values and 128 hidden node activation values to reduce the number of features to 2 in each case. Once again, we use a scatter plot to visualize the correlation between the two principal component values and the class labels.
#  - Finally, we use a Random Forest Classifier to find the relative importance of the 784 features (pixels) in the training set. We then select the 70 most important feature (pixels) from the training, validation and test images to test our 'best' model on.

# %% [markdown]
# # Importing packages as needed

# %%
import datetime
from packaging import version
from collections import Counter
import numpy as np
import pandas as pd

import matplotlib as mpl  
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns

from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error as MSE
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split #for split the data
from sklearn.metrics import accuracy_score ,precision_score,recall_score,f1_score ,precision_recall_fscore_support #for accuracy_score
from sklearn.metrics import confusion_matrix #for confusion matrix
from sklearn.model_selection import KFold #for K-fold cross validation
from sklearn.model_selection import cross_val_score #score evaluation
from sklearn.model_selection import cross_val_predict #prediction

import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow import keras
from tensorflow.keras import models
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten , Input , Dropout
from tensorflow.keras.datasets import mnist
#from plot_keras_history import plot_history

import warnings
warnings.filterwarnings('ignore')

# %%
# Allows for muliple output in one cell window
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
 import tensorflow as tf;
 print(tf.__version__);
# Out:
# 2.8.2

# %% [markdown]
# # Importing train and test datasets from Keras dataset repository

# %%
(x_train, y_train), (x_test, y_test)= tf.keras.datasets.mnist.load_data()

# %% [markdown]
# # EDA of datasets

# %%
print('x_train:\t{}'.format(x_train.shape))
print('y_train:\t{}'.format(y_train.shape))
print('x_test:\t\t{}'.format(x_test.shape))
print('y_test:\t\t{}'.format(y_test.shape))
# Out:
# x_train:	(60000, 28, 28)
# y_train:	(60000,)
# x_test:		(10000, 28, 28)
# y_test:		(10000,)

# %%
#Reviewing the max and min value in the train dataset
x_train.min(), x_train.max()
# Out:
# (0, 255)

# %%
#Reviewing the max and min value  in the test dataset
x_test.min(), x_test.max()
# Out:
# (0, 255)

# %%
#Reviewing the datatype 
x_train.dtype , x_test.dtype
# Out:
# (dtype('uint8'), dtype('uint8'))

# %%
#Printing few of the observations for review
print("First ten labels training dataset:\n {}\n".format(y_train[0:10]))
# Out:
# First ten labels training dataset:
#  [5 0 4 1 9 2 1 3 1 4]

# %% [markdown]
# ### Missing value check

# %%
#Checking if there is null in x_train or x_test
np.all(np.isnan(x_train)) , np.all(np.isnan(x_test))
# Out:
# (False, False)

# %% [markdown]
# No data is missing across all columns

# %% [markdown]
# ### Reviewing the labels

# %%
 #Understanding the frequency of labels for training y 
pd.DataFrame(y_train).value_counts()
pd.DataFrame(y_train).value_counts().plot(kind='bar',figsize=(5, 5) )
# Out:
# 1    6742
# 7    6265
# 3    6131
# 2    5958
# 9    5949
# 0    5923
# 6    5918
# 8    5851
# 4    5842
# 5    5421
# dtype: int64

# %%
#Understanding the frequency of labels for test y 
pd.DataFrame(y_test).value_counts()
pd.DataFrame(y_test).value_counts().plot(kind='bar', figsize=(5, 5) )
# Out:
# 1    1135
# 2    1032
# 7    1028
# 3    1010
# 9    1009
# 4     982
# 0     980
# 8     974
# 6     958
# 5     892
# dtype: int64

# %% [markdown]
# ### Plotting the handwritten images

# %%
fig = plt.figure(figsize = (15, 9))

for i in range(50):
    plt.subplot(5, 10, 1+i)
    plt.title(y_train[i])
    plt.xticks([])
    plt.yticks([])
    plt.imshow(x_train[i].reshape(28,28), cmap='binary')
# Out:
# Text(0.5, 1.0, '5')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '0')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '4')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '1')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '2')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '1')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '3')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '1')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '4')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '3')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '5')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '3')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '6')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '1')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '7')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '2')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '8')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '6')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '4')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '0')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '1')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '1')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '2')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '4')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '3')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '2')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '7')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '3')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '8')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '6')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '0')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '5')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '6')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '0')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '7')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '6')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '1')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '8')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '7')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '3')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '8')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '5')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 1.0, '3')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)

# %% [markdown]
# #Preprocessing Data
#
#  - Before we build our model, we need to prepare the data into the shape the network expected
#  - More specifically, we will convert the labels (integers 0 to 9) to 1D numpy arrays of shape (10,) with elements 0s and 1s.
#  - We also reshape the images from 2D arrays of shape (28,28) to 1D float32 arrays of shape (784,) and then rescale their elements to values between 0 and 1.

# %%
#To flatten it into a 1D array the number of columns of a 28x28 pixel image would be 
print('image_vector_size: ', 28*28 )
# Out:
# image_vector_size:  784

# %%
# Flattening the images to a 1 D array:
x_train_reshaped = np.reshape(x_train, (60000, 784))
x_test_reshaped = np.reshape(x_test, (10000, 784))

# Verifying the shape:
print('x_train_reshaped shape: ', x_train_reshaped.shape)
print('x_test_reshaped shape: ', x_test_reshaped.shape)
# Out:
# x_train_reshaped shape:  (60000, 784)
# x_test_reshaped shape:  (10000, 784)

# %% [markdown]
# Each element in an image is a pixel value where pixel values range from 0 to 255:
# 1.   0 = White
# 2.   255 = Black

# %%
print(set(x_train_reshaped[0]))
# Out:
# {0, 1, 2, 3, 9, 11, 14, 16, 18, 23, 24, 25, 26, 27, 30, 35, 36, 39, 43, 45, 46, 49, 55, 56, 64, 66, 70, 78, 80, 81, 82, 90, 93, 94, 107, 108, 114, 119, 126, 127, 130, 132, 133, 135, 136, 139, 148, 150, 154, 156, 160, 166, 170, 171, 172, 175, 182, 183, 186, 187, 190, 195, 198, 201, 205, 207, 212, 213, 219, 221, 225, 226, 229, 238, 240, 241, 242, 244, 247, 249, 250, 251, 252, 253, 255}

# %% [markdown]
# ### Rescaling Train and Test samples

# %%
# Normalize from [0:255] => [0.0:1.0]
x_train_norm = np.multiply(x_train_reshaped, 1.0 / 255.0) 
x_test_norm = np.multiply(x_test_reshaped, 1.0 / 255.0)

# %%
#Reviewing scaling 
x_train_norm.min() , x_train_norm.max()
x_test_norm.min() , x_test_norm.max()
# Out:
# (0.0, 1.0)
# (0.0, 1.0)

# %% [markdown]
# ##Preparing the data
# We set apart 5,000 samples of our training data to use as a validation set. Since we will be using sparse_categorical_crossentropy as the loss function we do not need to use to_categorical to convert the class vector of labels to binary matrix representation.

# %%
#x_train_norm.shape
#val_train, x_train = x_train_norm[:5000], x_train_norm[5000:] 
#val_train.shape
#x_train.shape

# %% [markdown]
# #**EXPERIMENT 1 (1 node hidden, 10 output):**
#
# Our dense neural network (DNN) will consist of 784 input nodes, a hidden layer with 1 node and 10 output nodes (corresponding to the 10 digits). We use mnist.load_data() to get the 70,000 images divided into a set of 60,000 training images and 10,000 test images. We hold back 5,000 of the 60,000 training images for validation. After training the model, we group the 60,000 activation values of the hidden node for the (original) set of training images by the 10 predicted classes and visualize these sets of values using a boxplot. We expect the overlap between the range of values in the "boxes" to be minimal. In addition, we find the pattern that maximally activates the hidden node as a "warm up" exercise for similar analysis we will perform on CNN models in Assignment 2.
#
# 1.   To build a dense neural network that consists of 784 input nodes, a hidden layer with 1 node and 10 output nodes (corresponding to the 10 digits).The requirement is to hold back 5,000 of the 60,000 training images for validation.
# 2. After training the model, the requirement is to group the 60,000 activation values of the hidden node for the (original) set of training images by the 10 predicted classes and visualize these sets of values using a boxplot.

# %%
# A simple DNN with 784 input nodes, a hidden layer with 1 node and 10 output nodes (corresponding to the 10 digits)
image_size = 784 # 28*28
out_nodes = 10 # ten unique digits

model = models.Sequential()
model.add(Dense(units=1, activation='relu', 
                kernel_regularizer=tf.keras.regularizers.L2(0.001), 
                input_shape=(image_size,)))
model.add(Dense( name = "output_layer", units=out_nodes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 785
#
#  output_layer (Dense)        (None, 10)                20
#
# =================================================================
# Total params: 805
# Trainable params: 805
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# A single layer with a single node is similar to employing what is known as a multinomial logit model (logistic regression if there are only two classes).

# %%
keras.utils.plot_model(model, "mnist_experiment1.png", show_shapes=True)

# %%
print("Size of Dataset: " , len(x_train_norm))
cross_validation_size = int(len(x_train_norm)*0.08333333333333333)
print("Size of Cross Validation Set: " , cross_validation_size)
# Out:
# Size of Dataset:  60000
# Size of Cross Validation Set:  5000

# %%
#Splitting train dataset into train and validation datasets
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(x_train_norm, y_train, test_size=cross_validation_size, random_state=2)

# %%
from tensorflow.keras.utils import to_categorical
y_train_encoded = to_categorical(Y_train ,num_classes = 10)
y_valid_encoded = to_categorical(Y_valid ,num_classes = 10)
y_test_encoded = to_categorical(y_test , num_classes = 10)

# %% [markdown]
# ## Compiling the model
# To make our network ready for training, we need to pick three more things, as part of "compilation" step:
#  - A loss function: the is how the network will be able to measure how good a job it is doing on its training data, and thus how it will be able to steer itself in the right direction.
#  - An optimizer: this is the mechanism through which the network will update itself based on the data it sees and its loss function.
#  - Metrics to monitor during training and testing. Here we will only care about accuracy (the fraction of the images that were correctly classified).

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=50,
    mode='auto', baseline=None, restore_best_weights=False)

history = model.fit(
    X_train, y_train_encoded, 
    epochs = 200, batch_size = 64, 
    callbacks = [early_stopping], 
    validation_data = (X_valid,y_valid_encoded))
# Out:
# Epoch 1/200
# 860/860 [==============================] - 3s 3ms/step - loss: 2.0517 - accuracy: 0.1964 - val_loss: 1.9258 - val_accuracy: 0.2266
# Epoch 2/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.8822 - accuracy: 0.2558 - val_loss: 1.8406 - val_accuracy: 0.2886
# Epoch 3/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.8204 - accuracy: 0.2950 - val_loss: 1.7966 - val_accuracy: 0.3052
# Epoch 4/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.7870 - accuracy: 0.3096 - val_loss: 1.7742 - val_accuracy: 0.3162
# Epoch 5/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.7655 - accuracy: 0.3204 - val_loss: 1.7527 - val_accuracy: 0.3348
# Epoch 6/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.7498 - accuracy: 0.3269 - val_loss: 1.7389 - val_accuracy: 0.3430
# Epoch 7/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.7374 - accuracy: 0.3341 - val_loss: 1.7274 - val_accuracy: 0.3468
# Epoch 8/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.7273 - accuracy: 0.3400 - val_loss: 1.7201 - val_accuracy: 0.3504
# Epoch 9/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.7189 - accuracy: 0.3426 - val_loss: 1.7127 - val_accuracy: 0.3510
# Epoch 10/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.7123 - accuracy: 0.3462 - val_loss: 1.7085 - val_accuracy: 0.3514
# Epoch 11/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.7065 - accuracy: 0.3481 - val_loss: 1.7025 - val_accuracy: 0.3564
# Epoch 12/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.7004 - accuracy: 0.3510 - val_loss: 1.6977 - val_accuracy: 0.3532
# Epoch 13/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6961 - accuracy: 0.3522 - val_loss: 1.7004 - val_accuracy: 0.3472
# Epoch 14/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6921 - accuracy: 0.3539 - val_loss: 1.6896 - val_accuracy: 0.3694
# Epoch 15/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6883 - accuracy: 0.3575 - val_loss: 1.6867 - val_accuracy: 0.3620
# Epoch 16/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6846 - accuracy: 0.3593 - val_loss: 1.6838 - val_accuracy: 0.3668
# Epoch 17/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6820 - accuracy: 0.3610 - val_loss: 1.6805 - val_accuracy: 0.3606
# Epoch 18/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6792 - accuracy: 0.3619 - val_loss: 1.6793 - val_accuracy: 0.3680
# Epoch 19/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6763 - accuracy: 0.3627 - val_loss: 1.6781 - val_accuracy: 0.3762
# Epoch 20/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6738 - accuracy: 0.3658 - val_loss: 1.6768 - val_accuracy: 0.3684
# Epoch 21/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6717 - accuracy: 0.3663 - val_loss: 1.6780 - val_accuracy: 0.3690
# Epoch 22/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6698 - accuracy: 0.3689 - val_loss: 1.6718 - val_accuracy: 0.3672
# Epoch 23/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6684 - accuracy: 0.3674 - val_loss: 1.6690 - val_accuracy: 0.3734
# Epoch 24/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6661 - accuracy: 0.3682 - val_loss: 1.6675 - val_accuracy: 0.3700
# Epoch 25/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6641 - accuracy: 0.3691 - val_loss: 1.6662 - val_accuracy: 0.3742
# Epoch 26/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6626 - accuracy: 0.3717 - val_loss: 1.6647 - val_accuracy: 0.3648
# Epoch 27/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6613 - accuracy: 0.3720 - val_loss: 1.6655 - val_accuracy: 0.3712
# Epoch 28/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6599 - accuracy: 0.3699 - val_loss: 1.6619 - val_accuracy: 0.3798
# Epoch 29/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6580 - accuracy: 0.3722 - val_loss: 1.6611 - val_accuracy: 0.3680
# Epoch 30/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6570 - accuracy: 0.3725 - val_loss: 1.6589 - val_accuracy: 0.3808
# Epoch 31/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6556 - accuracy: 0.3757 - val_loss: 1.6572 - val_accuracy: 0.3720
# Epoch 32/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6547 - accuracy: 0.3752 - val_loss: 1.6554 - val_accuracy: 0.3802
# Epoch 33/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6536 - accuracy: 0.3769 - val_loss: 1.6564 - val_accuracy: 0.3744
# Epoch 34/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6524 - accuracy: 0.3758 - val_loss: 1.6565 - val_accuracy: 0.3766
# Epoch 35/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6517 - accuracy: 0.3772 - val_loss: 1.6569 - val_accuracy: 0.3724
# Epoch 36/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6508 - accuracy: 0.3777 - val_loss: 1.6556 - val_accuracy: 0.3698
# Epoch 37/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6502 - accuracy: 0.3757 - val_loss: 1.6540 - val_accuracy: 0.3856
# Epoch 38/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6492 - accuracy: 0.3796 - val_loss: 1.6523 - val_accuracy: 0.3796
# Epoch 39/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6480 - accuracy: 0.3772 - val_loss: 1.6490 - val_accuracy: 0.3796
# Epoch 40/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6472 - accuracy: 0.3789 - val_loss: 1.6512 - val_accuracy: 0.3898
# Epoch 41/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6464 - accuracy: 0.3786 - val_loss: 1.6468 - val_accuracy: 0.3852
# Epoch 42/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6457 - accuracy: 0.3818 - val_loss: 1.6473 - val_accuracy: 0.3814
# Epoch 43/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6452 - accuracy: 0.3803 - val_loss: 1.6490 - val_accuracy: 0.3870
# Epoch 44/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6440 - accuracy: 0.3805 - val_loss: 1.6483 - val_accuracy: 0.3850
# Epoch 45/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6438 - accuracy: 0.3803 - val_loss: 1.6470 - val_accuracy: 0.3910
# Epoch 46/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6436 - accuracy: 0.3835 - val_loss: 1.6480 - val_accuracy: 0.3788
# Epoch 47/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6430 - accuracy: 0.3815 - val_loss: 1.6483 - val_accuracy: 0.3894
# Epoch 48/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6418 - accuracy: 0.3848 - val_loss: 1.6440 - val_accuracy: 0.3972
# Epoch 49/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6418 - accuracy: 0.3837 - val_loss: 1.6442 - val_accuracy: 0.3802
# Epoch 50/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6406 - accuracy: 0.3815 - val_loss: 1.6468 - val_accuracy: 0.3826
# Epoch 51/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6404 - accuracy: 0.3827 - val_loss: 1.6529 - val_accuracy: 0.3786
# Epoch 52/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6399 - accuracy: 0.3828 - val_loss: 1.6445 - val_accuracy: 0.3842
# Epoch 53/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6394 - accuracy: 0.3841 - val_loss: 1.6438 - val_accuracy: 0.3794
# Epoch 54/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6385 - accuracy: 0.3830 - val_loss: 1.6429 - val_accuracy: 0.3810
# Epoch 55/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6387 - accuracy: 0.3826 - val_loss: 1.6467 - val_accuracy: 0.3858
# Epoch 56/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6372 - accuracy: 0.3859 - val_loss: 1.6443 - val_accuracy: 0.3882
# Epoch 57/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6374 - accuracy: 0.3837 - val_loss: 1.6422 - val_accuracy: 0.3862
# Epoch 58/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6368 - accuracy: 0.3857 - val_loss: 1.6414 - val_accuracy: 0.3866
# Epoch 59/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6366 - accuracy: 0.3843 - val_loss: 1.6412 - val_accuracy: 0.3856
# Epoch 60/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6365 - accuracy: 0.3857 - val_loss: 1.6439 - val_accuracy: 0.3844
# Epoch 61/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6359 - accuracy: 0.3837 - val_loss: 1.6386 - val_accuracy: 0.3940
# Epoch 62/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6351 - accuracy: 0.3882 - val_loss: 1.6455 - val_accuracy: 0.3878
# Epoch 63/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6347 - accuracy: 0.3862 - val_loss: 1.6393 - val_accuracy: 0.3828
# Epoch 64/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6341 - accuracy: 0.3849 - val_loss: 1.6485 - val_accuracy: 0.3842
# Epoch 65/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6345 - accuracy: 0.3876 - val_loss: 1.6458 - val_accuracy: 0.3832
# Epoch 66/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6337 - accuracy: 0.3835 - val_loss: 1.6389 - val_accuracy: 0.3934
# Epoch 67/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6336 - accuracy: 0.3863 - val_loss: 1.6390 - val_accuracy: 0.3868
# Epoch 68/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6332 - accuracy: 0.3860 - val_loss: 1.6421 - val_accuracy: 0.3850
# Epoch 69/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6329 - accuracy: 0.3850 - val_loss: 1.6394 - val_accuracy: 0.3916
# Epoch 70/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6321 - accuracy: 0.3844 - val_loss: 1.6404 - val_accuracy: 0.3782
# Epoch 71/200
# 860/860 [==============================] - 2s 3ms/step - loss: 1.6321 - accuracy: 0.3840 - val_loss: 1.6427 - val_accuracy: 0.3958
# Epoch 71: early stopping

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', label = "Training Accuracy")
plt.plot(epochs, val_acc, 'b', label = "Validation Accuracy")
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = "bottom right")
plt.figure()
#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', label = "Training Loss")
plt.plot(epochs, val_loss, 'b', label = "Validation Loss")
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = "upper right")
plt.figure()
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Training and Validation Loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
#Reviewing validation accuracy , precision and recall
y_pred_valid = model.predict(X_valid)
y_pred_valid = np.argmax(y_pred_valid, axis=1)
print("The accuracy percentage for validation dataset is {}".format(accuracy_score(Y_valid, y_pred_valid)))
# Out:
# The accuracy percentage for validation dataset is 0.4092

# %%
print('The efficiency metrics for DNN Validation data is :')
print(classification_report(Y_valid, y_pred_valid))
# Out:
# The efficiency metrics for DNN Validation data is :
#               precision    recall  f1-score   support
#
#            0       0.39      0.11      0.17       523
#            1       0.53      0.85      0.65       568
#            2       0.16      0.17      0.16       479
#            3       0.25      0.42      0.31       496
#            4       0.49      0.41      0.45       509
#            5       0.00      0.00      0.00       480
#            6       0.39      0.89      0.54       493
#            7       0.72      0.66      0.69       499
#            8       0.26      0.09      0.14       488
#            9       0.47      0.42      0.44       465
#
#     accuracy                           0.41      5000
#    macro avg       0.37      0.40      0.36      5000
# weighted avg       0.37      0.41      0.36      5000

# %%
sns.heatmap(metrics.confusion_matrix(Y_valid, y_pred_valid),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Validation dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Validation dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %%
#Test data accuracy , precision and recall
y_pred = model.predict(x_test_norm)
y_pred_test =np.argmax(y_pred, axis=1)
print("The accuracy percentage for test dataset is {}".format(accuracy_score(y_test, y_pred_test)))
# Out:
# The accuracy percentage for test dataset is 0.4099

# %%
print('The efficiency metrics for DNN Test data is :')
print(classification_report(y_test, y_pred_test))
# Out:
# The efficiency metrics for DNN Test data is :
#               precision    recall  f1-score   support
#
#            0       0.26      0.09      0.13       980
#            1       0.56      0.86      0.68      1135
#            2       0.17      0.17      0.17      1032
#            3       0.28      0.44      0.34      1010
#            4       0.49      0.44      0.46       982
#            5       0.00      0.00      0.00       892
#            6       0.37      0.86      0.51       958
#            7       0.69      0.64      0.66      1028
#            8       0.32      0.10      0.15       974
#            9       0.44      0.41      0.42      1009
#
#     accuracy                           0.41     10000
#    macro avg       0.36      0.40      0.35     10000
# weighted avg       0.37      0.41      0.36     10000

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_pred_test),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Test dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Test dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %% [markdown]
# Plotting the predicted images in the test dataset

# %%
plt.figure(figsize = (12, 8))

start_index = 0

for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    pred = np.argmax(y_pred_test[start_index + i])
    actual = np.argmax(y_test_encoded[start_index + i])
    col = 'g'
    if pred != actual:
        col = 'r'
    plt.xlabel('i={} | pred={} | true={}'.format(start_index + i, pred, actual), color = col)
    plt.imshow(x_test[start_index + i], cmap='binary')
plt.show()
# Out:
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=0 | pred=0 | true=7')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=1 | pred=0 | true=2')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=2 | pred=0 | true=1')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=3 | pred=0 | true=0')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=4 | pred=0 | true=4')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=5 | pred=0 | true=1')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=6 | pred=0 | true=4')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=7 | pred=0 | true=9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=8 | pred=0 | true=5')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=9 | pred=0 | true=9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=10 | pred=0 | true=0')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=11 | pred=0 | true=6')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=12 | pred=0 | true=9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=13 | pred=0 | true=0')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=14 | pred=0 | true=1')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=15 | pred=0 | true=5')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=16 | pred=0 | true=9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=17 | pred=0 | true=7')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=18 | pred=0 | true=3')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=19 | pred=0 | true=4')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=20 | pred=0 | true=9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=21 | pred=0 | true=6')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=22 | pred=0 | true=6')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=23 | pred=0 | true=5')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=24 | pred=0 | true=4')

# %% [markdown]
# After training the model, the requirement is to group the 60,000 activation values of the hidden node for the (original) set of training images by the 10 predicted classes and visualize these sets of values using a boxplot.

# %%
# Extracts the outputs of the 2 layers:
layer_outputs = [layer.output for layer in model.layers]

# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

print(f"There are {len(layer_outputs)} layers")
layer_outputs; # description of the layers
# Out:
# There are 2 layers

# %%
x_train_norm.shape
# Out:
# (60000, 784)

# %%
predict_x=model.predict(x_train_norm)
pred_classes = np.argmax(predict_x,axis=1)

# %%
activations = activation_model.predict(x_train_norm)
hidden_layer_activation = activations[0]
hidden_layer_activation.shape
# Out:
# (60000, 1)

# %%
boxplot_df = pd.DataFrame({'act_value':hidden_layer_activation.reshape(60000),
                           'pred_class':pred_classes})
boxplot_df['pred_class'].value_counts()
# Out:
# 6    13359
# 1    10642
# 3    10107
# 2     6089
# 7     5714
# 4     5291
# 9     5126
# 8     1864
# 0     1808
# Name: pred_class, dtype: int64

# %%
# Let us use seaborn for the boxplots this time.
import seaborn as sns
bplot = sns.boxplot(y='act_value', x='pred_class', 
                 data=boxplot_df, 
                 width=0.5,
                 palette="colorblind")

# %%
# Get the outputs of all the hidden nodes for each of the 60000 training images
activations = activation_model.predict(x_train_norm)
hidden_layer_activation = activations[0]
output_layer_activations = activations[1]
hidden_layer_activation.shape   #  each hidden nodes has one activation value per training image
# Out:
# (60000, 1)

# %%
output_layer_activations.shape
# Out:
# (60000, 10)

# %%
print(f"The maximum activation value of the hidden nodes in the hidden layer is \
{hidden_layer_activation.max()}")
# Out:
# The maximum activation value of the hidden nodes in the hidden layer is 7.819182872772217

# %%
# Some stats about the output layer as an aside...
np.set_printoptions(suppress = True)  # display probabilities as decimals and NOT in scientific notation
ouput_layer_activation = activations[1]
print(f"The output node has shape {ouput_layer_activation.shape}")
print(f"The output for the first image are {ouput_layer_activation[0].round(4)}")
print(f"The sum of the probabilities is (approximately) {ouput_layer_activation[0].sum()}")
# Out:
# The output node has shape (60000, 10)
# The output for the first image are [0.1159 0.0407 0.2099 0.2179 0.0024 0.2016 0.0333 0.     0.178  0.0002]
# The sum of the probabilities is (approximately) 1.0

# %%
#Get the dataframe of all the node values
activation_data = {'actual_class':y_train}
for k in range(0,1): 
    activation_data[f"act_val_{k}"] = hidden_layer_activation[:,k]

activation_df = pd.DataFrame(activation_data)
activation_df.head(15).round(3).T
# Out:
#                  0      1      2      3      4   ...     10    11     12   13     14
# actual_class  5.000  0.000  4.000  1.000  9.000  ...  3.000  5.00  3.000  6.0  1.000
# act_val_0     1.186  0.544  3.038  2.266  3.856  ...  2.081  1.29  1.015  0.0  2.298
#
# [2 rows x 15 columns]

# %%
# To see how closely the hidden node activation values correlate with the class labels
# Let us use seaborn for the boxplots this time.
bplot = sns.boxplot(y='act_val_0', x='actual_class', 
                 data=activation_df[['act_val_0','actual_class']], 
                 width=0.5,
                 palette="colorblind")

# %%
# displaying the range of activation values 0 for each class labels
activation_df.groupby("actual_class")["act_val_0"].apply(lambda x: [round(min(x.tolist()),2),
 round(max(x.tolist()),2)]).reset_index().rename(columns={"act_val_0": "range_of_act_values"})
# Out:
#    actual_class range_of_act_values
# 0             0         [0.0, 3.15]
# 1             1         [0.0, 3.87]
# 2             2         [0.0, 3.95]
# 3             3         [0.0, 7.17]
# 4             4         [0.0, 5.09]
# 5             5         [0.0, 5.18]
# 6             6         [0.0, 2.91]
# 7             7         [0.0, 7.82]
# 8             8         [0.0, 4.97]
# 9             9         [0.0, 6.25]

# %% [markdown]
# #**2. Experimental Design 2**
# 1. Build a DNN with 784 input nodes, a hidden layer with 2 nodes and 10 output nodes (corresponding to the 10 digits).
# 2. For each of the 60,000 images, the output of the two hidden nodes are plotted using a scatterplot. We color code the points according to which of the 10 classes the the output of the two nodes predicts.
# 3. Also compare the accuracy % & confusion matrix of Experiments 1 & 2.

# %%
tf.keras.backend.clear_session()  # For easy reset of notebook state.
model = models.Sequential()
model.add(Dense(units=2, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(0.001), input_shape=(image_size,)))
model.add(Dense( name = "output_layer", units=num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2)                 1570
#
#  output_layer (Dense)        (None, 10)                30
#
# =================================================================
# Total params: 1,600
# Trainable params: 1,600
# Non-trainable params: 0
# _________________________________________________________________

# %%
# For use with non-categorical labels
model.compile(optimizer='rmsprop',           
               loss = 'categorical_crossentropy',
               metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=50,
    mode='auto', baseline=None, restore_best_weights=False)

history = model.fit(X_train, y_train_encoded, epochs = 200, batch_size = 64, callbacks = [early_stopping], validation_data = (X_valid, y_valid_encoded))
# Out:
# Epoch 1/200
# 860/860 [==============================] - 2s 2ms/step - loss: 1.7803 - accuracy: 0.4096 - val_loss: 1.5279 - val_accuracy: 0.5010
# Epoch 2/200
# 860/860 [==============================] - 2s 2ms/step - loss: 1.4096 - accuracy: 0.5519 - val_loss: 1.3135 - val_accuracy: 0.5930
# Epoch 3/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.2597 - accuracy: 0.6083 - val_loss: 1.2197 - val_accuracy: 0.6100
# Epoch 4/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.1883 - accuracy: 0.6236 - val_loss: 1.1736 - val_accuracy: 0.6196
# Epoch 5/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.1481 - accuracy: 0.6266 - val_loss: 1.1516 - val_accuracy: 0.6186
# Epoch 6/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.1228 - accuracy: 0.6293 - val_loss: 1.1322 - val_accuracy: 0.6202
# Epoch 7/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.1053 - accuracy: 0.6325 - val_loss: 1.1096 - val_accuracy: 0.6290
# Epoch 8/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0919 - accuracy: 0.6357 - val_loss: 1.1010 - val_accuracy: 0.6308
# Epoch 9/200
# 860/860 [==============================] - 2s 2ms/step - loss: 1.0814 - accuracy: 0.6403 - val_loss: 1.0878 - val_accuracy: 0.6396
# Epoch 10/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0729 - accuracy: 0.6422 - val_loss: 1.0854 - val_accuracy: 0.6368
# Epoch 11/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0652 - accuracy: 0.6446 - val_loss: 1.0779 - val_accuracy: 0.6394
# Epoch 12/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0592 - accuracy: 0.6470 - val_loss: 1.0686 - val_accuracy: 0.6410
# Epoch 13/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0537 - accuracy: 0.6476 - val_loss: 1.0730 - val_accuracy: 0.6420
# Epoch 14/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0483 - accuracy: 0.6517 - val_loss: 1.0609 - val_accuracy: 0.6446
# Epoch 15/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0445 - accuracy: 0.6527 - val_loss: 1.0644 - val_accuracy: 0.6392
# Epoch 16/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0409 - accuracy: 0.6527 - val_loss: 1.0491 - val_accuracy: 0.6486
# Epoch 17/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0374 - accuracy: 0.6551 - val_loss: 1.0476 - val_accuracy: 0.6500
# Epoch 18/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0346 - accuracy: 0.6562 - val_loss: 1.0455 - val_accuracy: 0.6488
# Epoch 19/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0319 - accuracy: 0.6564 - val_loss: 1.0408 - val_accuracy: 0.6494
# Epoch 20/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0294 - accuracy: 0.6581 - val_loss: 1.0355 - val_accuracy: 0.6514
# Epoch 21/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0273 - accuracy: 0.6579 - val_loss: 1.0505 - val_accuracy: 0.6468
# Epoch 22/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0257 - accuracy: 0.6593 - val_loss: 1.0416 - val_accuracy: 0.6478
# Epoch 23/200
# 860/860 [==============================] - 2s 2ms/step - loss: 1.0237 - accuracy: 0.6593 - val_loss: 1.0330 - val_accuracy: 0.6522
# Epoch 24/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0222 - accuracy: 0.6599 - val_loss: 1.0331 - val_accuracy: 0.6512
# Epoch 25/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0215 - accuracy: 0.6593 - val_loss: 1.0280 - val_accuracy: 0.6522
# Epoch 26/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0199 - accuracy: 0.6594 - val_loss: 1.0449 - val_accuracy: 0.6488
# Epoch 27/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0184 - accuracy: 0.6616 - val_loss: 1.0310 - val_accuracy: 0.6538
# Epoch 28/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0175 - accuracy: 0.6614 - val_loss: 1.0234 - val_accuracy: 0.6546
# Epoch 29/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0161 - accuracy: 0.6616 - val_loss: 1.0276 - val_accuracy: 0.6558
# Epoch 30/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0153 - accuracy: 0.6626 - val_loss: 1.0238 - val_accuracy: 0.6538
# Epoch 31/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0141 - accuracy: 0.6623 - val_loss: 1.0213 - val_accuracy: 0.6574
# Epoch 32/200
# 860/860 [==============================] - 2s 2ms/step - loss: 1.0134 - accuracy: 0.6635 - val_loss: 1.0296 - val_accuracy: 0.6516
# Epoch 33/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0127 - accuracy: 0.6615 - val_loss: 1.0397 - val_accuracy: 0.6518
# Epoch 34/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0122 - accuracy: 0.6624 - val_loss: 1.0322 - val_accuracy: 0.6542
# Epoch 35/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0113 - accuracy: 0.6629 - val_loss: 1.0236 - val_accuracy: 0.6598
# Epoch 36/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0114 - accuracy: 0.6614 - val_loss: 1.0296 - val_accuracy: 0.6516
# Epoch 37/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0102 - accuracy: 0.6637 - val_loss: 1.0160 - val_accuracy: 0.6576
# Epoch 38/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0094 - accuracy: 0.6640 - val_loss: 1.0342 - val_accuracy: 0.6428
# Epoch 39/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0092 - accuracy: 0.6644 - val_loss: 1.0322 - val_accuracy: 0.6508
# Epoch 40/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0086 - accuracy: 0.6657 - val_loss: 1.0281 - val_accuracy: 0.6536
# Epoch 41/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0078 - accuracy: 0.6645 - val_loss: 1.0197 - val_accuracy: 0.6592
# Epoch 42/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0078 - accuracy: 0.6624 - val_loss: 1.0171 - val_accuracy: 0.6632
# Epoch 43/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0068 - accuracy: 0.6644 - val_loss: 1.0304 - val_accuracy: 0.6526
# Epoch 44/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0071 - accuracy: 0.6642 - val_loss: 1.0228 - val_accuracy: 0.6594
# Epoch 45/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0066 - accuracy: 0.6645 - val_loss: 1.0406 - val_accuracy: 0.6454
# Epoch 46/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0065 - accuracy: 0.6646 - val_loss: 1.0149 - val_accuracy: 0.6590
# Epoch 47/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0056 - accuracy: 0.6650 - val_loss: 1.0204 - val_accuracy: 0.6596
# Epoch 48/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0057 - accuracy: 0.6654 - val_loss: 1.0175 - val_accuracy: 0.6578
# Epoch 49/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0060 - accuracy: 0.6642 - val_loss: 1.0205 - val_accuracy: 0.6562
# Epoch 50/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0047 - accuracy: 0.6660 - val_loss: 1.0172 - val_accuracy: 0.6538
# Epoch 51/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0055 - accuracy: 0.6652 - val_loss: 1.0215 - val_accuracy: 0.6546
# Epoch 52/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0048 - accuracy: 0.6669 - val_loss: 1.0175 - val_accuracy: 0.6546
# Epoch 53/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0042 - accuracy: 0.6653 - val_loss: 1.0181 - val_accuracy: 0.6540
# Epoch 54/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0041 - accuracy: 0.6651 - val_loss: 1.0170 - val_accuracy: 0.6572
# Epoch 55/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0038 - accuracy: 0.6668 - val_loss: 1.0108 - val_accuracy: 0.6602
# Epoch 56/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0037 - accuracy: 0.6644 - val_loss: 1.0144 - val_accuracy: 0.6616
# Epoch 57/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0037 - accuracy: 0.6651 - val_loss: 1.0109 - val_accuracy: 0.6606
# Epoch 58/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0024 - accuracy: 0.6656 - val_loss: 1.0249 - val_accuracy: 0.6560
# Epoch 59/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0030 - accuracy: 0.6663 - val_loss: 1.0124 - val_accuracy: 0.6596
# Epoch 60/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0025 - accuracy: 0.6664 - val_loss: 1.0171 - val_accuracy: 0.6566
# Epoch 61/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0022 - accuracy: 0.6663 - val_loss: 1.0178 - val_accuracy: 0.6614
# Epoch 62/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0024 - accuracy: 0.6664 - val_loss: 1.0147 - val_accuracy: 0.6604
# Epoch 63/200
# 860/860 [==============================] - 2s 2ms/step - loss: 1.0023 - accuracy: 0.6648 - val_loss: 1.0300 - val_accuracy: 0.6498
# Epoch 64/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0019 - accuracy: 0.6675 - val_loss: 1.0268 - val_accuracy: 0.6452
# Epoch 65/200
# 860/860 [==============================] - 1s 2ms/step - loss: 1.0024 - accuracy: 0.6660 - val_loss: 1.0183 - val_accuracy: 0.6642
# Epoch 00065: early stopping

# %%
keras.utils.plot_model(model, "mnist_experiment2.png", show_shapes=True)

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', label = "Training Accuracy")
plt.plot(epochs, val_acc, 'b', label = "Validation Accuracy")
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = "bottom right")
plt.figure()
#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', label = "Training Loss")
plt.plot(epochs, val_loss, 'b', label = "Validation Loss")
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = "upper right")
plt.figure()
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Training and Validation Loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
#Reviewing validation accuracy , precision and recall
y_pred_valid = model.predict(X_valid)
y_pred_valid = np.argmax(y_pred_valid, axis=1)
print("The accuracy percentage for validation dataset is {}".format(accuracy_score(Y_valid, y_pred_valid)))
# Out:
# The accuracy percentage for validation dataset is 0.6642

# %%
print('The efficiency metrics for DNN Validation data is :')
print(classification_report(Y_valid, y_pred_valid))
# Out:
# The efficiency metrics for DNN Validation data is :
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78       523
#            1       0.89      0.91      0.90       568
#            2       0.42      0.47      0.44       479
#            3       0.58      0.59      0.59       496
#            4       0.79      0.81      0.80       509
#            5       0.46      0.39      0.42       480
#            6       0.81      0.86      0.83       493
#            7       0.78      0.80      0.79       499
#            8       0.41      0.32      0.36       488
#            9       0.58      0.68      0.62       465
#
#     accuracy                           0.66      5000
#    macro avg       0.65      0.66      0.65      5000
# weighted avg       0.66      0.66      0.66      5000

# %%
sns.heatmap(metrics.confusion_matrix(Y_valid, y_pred_valid),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Validation dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Validation dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %%
#Test data accuracy , precision and recall
y_pred = model.predict(x_test_norm)
y_pred_test =np.argmax(y_pred, axis=1)
print("The accuracy percentage for test dataset is {}".format(accuracy_score(y_test, y_pred_test)))
# Out:
# The accuracy percentage for test dataset is 0.6754

# %%
print('The efficiency metrics for DNN Test data is :')
print(classification_report(y_test, y_pred_test))
# Out:
# The efficiency metrics for DNN Test data is :
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.79       980
#            1       0.86      0.92      0.89      1135
#            2       0.44      0.44      0.44      1032
#            3       0.55      0.61      0.58      1010
#            4       0.76      0.82      0.79       982
#            5       0.50      0.43      0.46       892
#            6       0.83      0.87      0.85       958
#            7       0.77      0.82      0.80      1028
#            8       0.51      0.37      0.43       974
#            9       0.63      0.65      0.64      1009
#
#     accuracy                           0.68     10000
#    macro avg       0.66      0.67      0.66     10000
# weighted avg       0.67      0.68      0.67     10000

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_pred_test),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Test dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Test dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %%
#Visualizing the predicted labels for test dataset
plt.figure(figsize = (12, 8))

start_index = 0

for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    pred = np.argmax(y_pred_test[start_index + i])
    actual = np.argmax(y_test_encoded[start_index + i])
    col = 'g'
    if pred != actual:
        col = 'r'
    plt.xlabel('i={} | pred={} | true={}'.format(start_index + i, pred, actual), color = col)
    plt.imshow(x_test[start_index + i], cmap='binary')
plt.show()
# Out:
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=0 | pred=0 | true=7')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=1 | pred=0 | true=2')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=2 | pred=0 | true=1')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=3 | pred=0 | true=0')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=4 | pred=0 | true=4')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=5 | pred=0 | true=1')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=6 | pred=0 | true=4')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=7 | pred=0 | true=9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=8 | pred=0 | true=5')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=9 | pred=0 | true=9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=10 | pred=0 | true=0')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=11 | pred=0 | true=6')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=12 | pred=0 | true=9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=13 | pred=0 | true=0')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=14 | pred=0 | true=1')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=15 | pred=0 | true=5')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=16 | pred=0 | true=9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=17 | pred=0 | true=7')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=18 | pred=0 | true=3')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=19 | pred=0 | true=4')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=20 | pred=0 | true=9')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=21 | pred=0 | true=6')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=22 | pred=0 | true=6')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=23 | pred=0 | true=5')
# ([], <a list of 0 Text major ticklabel objects>)
# ([], <a list of 0 Text major ticklabel objects>)
# Text(0.5, 0, 'i=24 | pred=0 | true=4')

# %% [markdown]
# For each of the 60,000 images, the output of the two hidden nodes are plotted using a scatterplot. We color code the points according to which of the 10 classes the the output of the two nodes predicts.

# %%
#Creating the activation model 
#from tensorflow.keras import models

# Extracts the outputs of the 2 layers:
layer_outputs = [layer.output for layer in model.layers]

# Creates a model that will return these outputs, given the model input:
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

print(f"There are {len(layer_outputs)} layers")
layer_outputs # description of the layers
# Out:
# There are 2 layers
# [<KerasTensor: shape=(None, 2) dtype=float32 (created by layer 'dense')>,
#  <KerasTensor: shape=(None, 10) dtype=float32 (created by layer 'output_layer')>]

# %%
activations = activation_model.predict(x_train_norm)
hidden_layer_activation = activations[0]
hidden_layer_activation.shape   #  2 hidden node each has one activation value per training image
# Out:
# (60000, 2)

# %%
hidden_node1_activation = hidden_layer_activation[:,0] # get activation values of the first hidden node
hidden_node2_activation = hidden_layer_activation[:,1] # get activation values of the second hidden node

print(f"The maximum activation value of the first hidden node is {hidden_node1_activation.max()}")
print(f"The maximum activation value of the second hidden node is {hidden_node2_activation.max()}")
# Out:
# The maximum activation value of the first hidden node is 12.564101219177246
# The maximum activation value of the second hidden node is 12.402273178100586

# %%
scatterPlot_df =  pd.DataFrame({'act_value_h1':hidden_node1_activation,
                                'act_value_h2':hidden_node2_activation,
                                'pred_class':pred_classes})
scatterPlot_df.head()
# Out:
#    act_value_h1  act_value_h2  pred_class
# 0      3.444303      4.593638           3
# 1      6.030570      5.314489           2
# 2      0.775313      1.199224           4
# 3      0.423342      0.512069           1
# 4      1.578010      0.955457           9

# %%
#plt.legend(loc='upper left', prop={'size':6}, bbox_to_anchor=(1,1),ncol=1)
plt.scatter(scatterPlot_df.act_value_h1, 
            scatterPlot_df.act_value_h2, 
            c=scatterPlot_df.pred_class,
            label=scatterPlot_df.pred_class)
plt.show()

# %%
groups = scatterPlot_df.groupby('pred_class')

# Plot
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.act_value_h1, group.act_value_h2, marker='o', linestyle='', ms=12, label=name)
ax.legend()

plt.show()

# %% [markdown]
# ## **Experimental Design 3**
#
# Model is a 1-layer and 128 nodes with ReLU and regularization

# %%
# A simple DNN with 784 input nodes, a hidden layer with 128 nodes and 10 output nodes (corresponding to the 10 digits)
image_size = 784 # 28*28
num_classes = 10 # ten unique digits

model = Sequential()
model.add(Dense(units=128, activation='relu', kernel_regularizer=tf.keras.regularizers.L2(0.001), input_shape=(image_size,)))
model.add(Dense( name = "output_layer", units=num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               100480
# _________________________________________________________________
# output_layer (Dense)         (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
# For use with non-categorical labels
model.compile(optimizer='adam',           
               loss = 'categorical_crossentropy',
               metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=50,
    mode='auto', baseline=None, restore_best_weights=False)

history = model.fit(X_train, y_train_encoded, epochs = 200, batch_size = 64, callbacks = [early_stopping], validation_data = (X_valid, y_valid_encoded))
# Out:
# Epoch 1/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.4395 - accuracy: 0.9101 - val_loss: 0.3159 - val_accuracy: 0.9334
# Epoch 2/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.2525 - accuracy: 0.9522 - val_loss: 0.2335 - val_accuracy: 0.9538
# Epoch 3/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.2108 - accuracy: 0.9619 - val_loss: 0.2174 - val_accuracy: 0.9564
# Epoch 4/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1899 - accuracy: 0.9667 - val_loss: 0.2049 - val_accuracy: 0.9602
# Epoch 5/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1755 - accuracy: 0.9700 - val_loss: 0.1807 - val_accuracy: 0.9664
# Epoch 6/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1673 - accuracy: 0.9716 - val_loss: 0.1847 - val_accuracy: 0.9658
# Epoch 7/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1583 - accuracy: 0.9734 - val_loss: 0.1681 - val_accuracy: 0.9718
# Epoch 8/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1533 - accuracy: 0.9746 - val_loss: 0.1707 - val_accuracy: 0.9678
# Epoch 9/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1471 - accuracy: 0.9752 - val_loss: 0.1692 - val_accuracy: 0.9660
# Epoch 10/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1445 - accuracy: 0.9761 - val_loss: 0.1609 - val_accuracy: 0.9716
# Epoch 11/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1406 - accuracy: 0.9766 - val_loss: 0.1560 - val_accuracy: 0.9712
# Epoch 12/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1365 - accuracy: 0.9782 - val_loss: 0.1565 - val_accuracy: 0.9704
# Epoch 13/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1328 - accuracy: 0.9789 - val_loss: 0.1500 - val_accuracy: 0.9722
# Epoch 14/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1328 - accuracy: 0.9780 - val_loss: 0.1599 - val_accuracy: 0.9700
# Epoch 15/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1286 - accuracy: 0.9790 - val_loss: 0.1529 - val_accuracy: 0.9732
# Epoch 16/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1281 - accuracy: 0.9794 - val_loss: 0.1510 - val_accuracy: 0.9728
# Epoch 17/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1249 - accuracy: 0.9801 - val_loss: 0.1538 - val_accuracy: 0.9720
# Epoch 18/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1241 - accuracy: 0.9799 - val_loss: 0.1572 - val_accuracy: 0.9710
# Epoch 19/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1222 - accuracy: 0.9809 - val_loss: 0.1498 - val_accuracy: 0.9694
# Epoch 20/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1219 - accuracy: 0.9799 - val_loss: 0.1515 - val_accuracy: 0.9726
# Epoch 21/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1201 - accuracy: 0.9808 - val_loss: 0.1499 - val_accuracy: 0.9718
# Epoch 22/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1200 - accuracy: 0.9812 - val_loss: 0.1518 - val_accuracy: 0.9706
# Epoch 23/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1172 - accuracy: 0.9817 - val_loss: 0.1470 - val_accuracy: 0.9738
# Epoch 24/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1176 - accuracy: 0.9807 - val_loss: 0.1427 - val_accuracy: 0.9752
# Epoch 25/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1152 - accuracy: 0.9814 - val_loss: 0.1628 - val_accuracy: 0.9686
# Epoch 26/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1138 - accuracy: 0.9823 - val_loss: 0.1396 - val_accuracy: 0.9744
# Epoch 27/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1131 - accuracy: 0.9825 - val_loss: 0.1459 - val_accuracy: 0.9738
# Epoch 28/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1137 - accuracy: 0.9819 - val_loss: 0.1414 - val_accuracy: 0.9734
# Epoch 29/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1124 - accuracy: 0.9823 - val_loss: 0.1487 - val_accuracy: 0.9712
# Epoch 30/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1123 - accuracy: 0.9826 - val_loss: 0.1368 - val_accuracy: 0.9750
# Epoch 31/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1108 - accuracy: 0.9831 - val_loss: 0.1397 - val_accuracy: 0.9748
# Epoch 32/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1101 - accuracy: 0.9827 - val_loss: 0.1601 - val_accuracy: 0.9678
# Epoch 33/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1092 - accuracy: 0.9824 - val_loss: 0.1435 - val_accuracy: 0.9724
# Epoch 34/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1091 - accuracy: 0.9830 - val_loss: 0.1387 - val_accuracy: 0.9734
# Epoch 35/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1097 - accuracy: 0.9830 - val_loss: 0.1427 - val_accuracy: 0.9740
# Epoch 36/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1109 - accuracy: 0.9827 - val_loss: 0.1337 - val_accuracy: 0.9780
# Epoch 37/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1087 - accuracy: 0.9825 - val_loss: 0.1388 - val_accuracy: 0.9726
# Epoch 38/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1052 - accuracy: 0.9847 - val_loss: 0.1626 - val_accuracy: 0.9684
# Epoch 39/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1089 - accuracy: 0.9821 - val_loss: 0.1347 - val_accuracy: 0.9750
# Epoch 40/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1040 - accuracy: 0.9842 - val_loss: 0.1490 - val_accuracy: 0.9706
# Epoch 41/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1090 - accuracy: 0.9825 - val_loss: 0.1363 - val_accuracy: 0.9772
# Epoch 42/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1058 - accuracy: 0.9837 - val_loss: 0.1427 - val_accuracy: 0.9732
# Epoch 43/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1054 - accuracy: 0.9834 - val_loss: 0.1413 - val_accuracy: 0.9732
# Epoch 44/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1042 - accuracy: 0.9842 - val_loss: 0.1316 - val_accuracy: 0.9766
# Epoch 45/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1055 - accuracy: 0.9829 - val_loss: 0.1399 - val_accuracy: 0.9736
# Epoch 46/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1038 - accuracy: 0.9839 - val_loss: 0.1336 - val_accuracy: 0.9764
# Epoch 47/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1030 - accuracy: 0.9842 - val_loss: 0.1547 - val_accuracy: 0.9686
# Epoch 48/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1032 - accuracy: 0.9841 - val_loss: 0.1403 - val_accuracy: 0.9740
# Epoch 49/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1028 - accuracy: 0.9841 - val_loss: 0.1332 - val_accuracy: 0.9760
# Epoch 50/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1014 - accuracy: 0.9846 - val_loss: 0.1437 - val_accuracy: 0.9712
# Epoch 51/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1049 - accuracy: 0.9843 - val_loss: 0.1345 - val_accuracy: 0.9776
# Epoch 52/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1032 - accuracy: 0.9843 - val_loss: 0.1407 - val_accuracy: 0.9736
# Epoch 53/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1017 - accuracy: 0.9845 - val_loss: 0.1312 - val_accuracy: 0.9774
# Epoch 54/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1034 - accuracy: 0.9841 - val_loss: 0.1475 - val_accuracy: 0.9704
# Epoch 55/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1010 - accuracy: 0.9845 - val_loss: 0.1335 - val_accuracy: 0.9762
# Epoch 56/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1014 - accuracy: 0.9844 - val_loss: 0.1347 - val_accuracy: 0.9744
# Epoch 57/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1015 - accuracy: 0.9842 - val_loss: 0.1392 - val_accuracy: 0.9736
# Epoch 58/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1008 - accuracy: 0.9837 - val_loss: 0.1524 - val_accuracy: 0.9694
# Epoch 59/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1031 - accuracy: 0.9840 - val_loss: 0.1356 - val_accuracy: 0.9754
# Epoch 60/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1018 - accuracy: 0.9843 - val_loss: 0.1355 - val_accuracy: 0.9746
# Epoch 61/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1011 - accuracy: 0.9844 - val_loss: 0.1341 - val_accuracy: 0.9756
# Epoch 62/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.0998 - accuracy: 0.9852 - val_loss: 0.1385 - val_accuracy: 0.9750
# Epoch 63/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.1014 - accuracy: 0.9848 - val_loss: 0.1353 - val_accuracy: 0.9760
# Epoch 00063: early stopping

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               100480
# _________________________________________________________________
# output_layer (Dense)         (None, 10)                1290
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "mnist_experiment3.png", show_shapes=True)

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', label = "Training Accuracy")
plt.plot(epochs, val_acc, 'b', label = "Validation Accuracy")
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = "bottom right")
plt.figure()
#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', label = "Training Loss")
plt.plot(epochs, val_loss, 'b', label = "Validation Loss")
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = "upper right")
plt.figure()
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Training and Validation Loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
#Reviewing validation accuracy , precision and recall
y_pred_valid = model.predict(X_valid)
y_pred_valid = np.argmax(y_pred_valid, axis=1)
print("The accuracy percentage for validation dataset is {}".format(accuracy_score(Y_valid, y_pred_valid)))
# Out:
# The accuracy percentage for validation dataset is 0.976

# %%
print('The efficiency metrics for DNN Validation data is :')
print(classification_report(Y_valid, y_pred_valid))
# Out:
# The efficiency metrics for DNN Validation data is :
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       523
#            1       0.99      0.98      0.98       568
#            2       0.97      0.97      0.97       479
#            3       0.97      0.97      0.97       496
#            4       0.98      0.95      0.97       509
#            5       0.98      0.98      0.98       480
#            6       0.97      0.98      0.98       493
#            7       0.99      0.98      0.98       499
#            8       0.97      0.98      0.97       488
#            9       0.94      0.98      0.96       465
#
#     accuracy                           0.98      5000
#    macro avg       0.98      0.98      0.98      5000
# weighted avg       0.98      0.98      0.98      5000

# %%
sns.heatmap(metrics.confusion_matrix(Y_valid, y_pred_valid),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Validation dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Validation dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %%
#Reviewing validation accuracy , precision and recall
y_pred_test = model.predict(x_test_norm)
y_pred_test = np.argmax(y_pred_test, axis=1)
print("The accuracy percentage for test dataset is {}".format(accuracy_score(y_test, y_pred_test)))
# Out:
# The accuracy percentage for test dataset is 0.9737

# %%
print('The efficiency metrics for DNN Test data is :')
print(classification_report(y_test, y_pred_test))
# Out:
# The efficiency metrics for DNN Test data is :
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       980
#            1       1.00      0.98      0.99      1135
#            2       0.98      0.97      0.97      1032
#            3       0.96      0.98      0.97      1010
#            4       0.99      0.94      0.96       982
#            5       0.97      0.98      0.97       892
#            6       0.96      0.98      0.97       958
#            7       0.98      0.98      0.98      1028
#            8       0.96      0.97      0.97       974
#            9       0.95      0.98      0.96      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_pred_test),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Test dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Test dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %% [markdown]
# # **Experiment Design 4:**
# 1. Use PCA decomposition to reduce the number of dimensions of our training set of 28x28 dimensional MNIST images from 784 to 154 (with 95% of training images variance lying along these components).
# 2. We also reduce the number of dimensions of 'best' model from Experiment 3 to 154 inputs nodes and train it on the new lower dimensional data. We then compare the performance of Experiments 3 and 4.

# %%
pca = PCA(0.95)
principalComponents = pca.fit_transform(x_train_norm)
principalDf = pd.DataFrame(data = principalComponents)
principalDf = principalDf.add_prefix('pca_')
principalDf.shape
# Out:
# (60000, 154)

# %%
#Checking if 95% is explained
var= pca.explained_variance_ratio_
var1=np.cumsum(np.round(pca.explained_variance_ratio_, decimals=4)*100)
print(max(var1))
# Out:
# 94.99999999999986

# %%
#Plotting 
plt.bar(range(1,len(var)+1),var )
plt.ylabel('Explained variance')
plt.xlabel('Components')
plt.plot(range(1,len(var)+1),
         var1,
         marker = 'o',
         linestyle ='--',
         label="Cumulative Explained Variance")
plt.legend(loc='upper left')
plt.show()
# Out:
# <BarContainer object of 154 artists>
# Text(0, 0.5, 'Explained variance')
# Text(0.5, 0, 'Components')

# %%
actual_class = pd.DataFrame(y_train, columns = ["actual_class"])
actual_class.head()
# Out:
#    actual_class
# 0             5
# 1             0
# 2             4
# 3             1
# 4             9

# %%
pixel_pca_df = pd.concat([principalDf, actual_class ], axis = 1)

# %%
plt.figure(figsize=(16,10))
sns.scatterplot(
    x="pca_1", y="pca_2",
    hue="actual_class",
    palette=sns.color_palette("hls", 10),
    data=pixel_pca_df,
    legend="full",
    alpha=0.3
);

# %%
#pixel_pca_df.head()

# %%
tf.keras.backend.clear_session()
image_size = 154
from keras.constraints import maxnorm
model = Sequential()
model.add(Dense(128, input_dim=(image_size), activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dense( name = "output_layer", units=num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               19840
# _________________________________________________________________
# output_layer (Dense)         (None, 10)                1290
# =================================================================
# Total params: 21,130
# Trainable params: 21,130
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Splitting train dataset into train and validation datasets
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(principalDf, y_train, test_size=cross_validation_size, random_state=2)

# %%
X_train.shape , X_valid.shape
# Out:
# ((55000, 154), (5000, 154))

# %%
from tensorflow.keras.utils import to_categorical
y_train_encoded = to_categorical(Y_train ,num_classes = 10)
y_valid_encoded = to_categorical(Y_valid ,num_classes = 10)
y_test_encoded = to_categorical(y_test , num_classes = 10)

# %%
# For use with non-categorical labels
model.compile(optimizer='adam',           
               loss = 'categorical_crossentropy',
               metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=50,
    mode='auto', baseline=None, restore_best_weights=False)

history = model.fit(X_train, y_train_encoded, epochs = 200, batch_size = 64, callbacks = [early_stopping], validation_data = (X_valid, y_valid_encoded))
# Out:
# Epoch 1/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.4032 - accuracy: 0.8943 - val_loss: 0.2007 - val_accuracy: 0.9400
# Epoch 2/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1525 - accuracy: 0.9562 - val_loss: 0.1422 - val_accuracy: 0.9558
# Epoch 3/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1038 - accuracy: 0.9711 - val_loss: 0.1159 - val_accuracy: 0.9664
# Epoch 4/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0768 - accuracy: 0.9791 - val_loss: 0.1025 - val_accuracy: 0.9704
# Epoch 5/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0589 - accuracy: 0.9845 - val_loss: 0.0910 - val_accuracy: 0.9742
# Epoch 6/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0466 - accuracy: 0.9876 - val_loss: 0.0868 - val_accuracy: 0.9742
# Epoch 7/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0366 - accuracy: 0.9909 - val_loss: 0.0816 - val_accuracy: 0.9754
# Epoch 8/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0288 - accuracy: 0.9933 - val_loss: 0.0808 - val_accuracy: 0.9734
# Epoch 9/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0230 - accuracy: 0.9946 - val_loss: 0.0809 - val_accuracy: 0.9762
# Epoch 10/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0178 - accuracy: 0.9967 - val_loss: 0.0799 - val_accuracy: 0.9760
# Epoch 11/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0139 - accuracy: 0.9979 - val_loss: 0.0787 - val_accuracy: 0.9782
# Epoch 12/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0110 - accuracy: 0.9986 - val_loss: 0.0786 - val_accuracy: 0.9770
# Epoch 13/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0084 - accuracy: 0.9993 - val_loss: 0.0843 - val_accuracy: 0.9750
# Epoch 14/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0068 - accuracy: 0.9993 - val_loss: 0.0827 - val_accuracy: 0.9754
# Epoch 15/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0053 - accuracy: 0.9996 - val_loss: 0.0861 - val_accuracy: 0.9776
# Epoch 16/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0040 - accuracy: 0.9998 - val_loss: 0.0908 - val_accuracy: 0.9758
# Epoch 17/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0034 - accuracy: 0.9999 - val_loss: 0.0902 - val_accuracy: 0.9756
# Epoch 18/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.0883 - val_accuracy: 0.9780
# Epoch 19/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 0.0999 - val_accuracy: 0.9774
# Epoch 20/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.0999 - val_accuracy: 0.9760
# Epoch 21/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0976 - val_accuracy: 0.9762
# Epoch 22/200
# 860/860 [==============================] - 2s 2ms/step - loss: 9.8137e-04 - accuracy: 1.0000 - val_loss: 0.0974 - val_accuracy: 0.9782
# Epoch 00022: early stopping

# %%
keras.utils.plot_model(model, "mnist_experiment4.png", show_shapes=True)

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', label = "Training Accuracy")
plt.plot(epochs, val_acc, 'b', label = "Validation Accuracy")
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = "bottom right")
plt.figure()
#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', label = "Training Loss")
plt.plot(epochs, val_loss, 'b', label = "Validation Loss")
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = "upper right")
plt.figure()
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Training and Validation Loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
#Reviewing validation accuracy , precision and recall
y_pred_valid = model.predict(X_valid)
y_pred_valid = np.argmax(y_pred_valid, axis=1)
print("The accuracy percentage for validation dataset is {}".format(accuracy_score(Y_valid, y_pred_valid)))
# Out:
# The accuracy percentage for validation dataset is 0.9782

# %%
print('The efficiency metrics for DNN Validation data is :')
print(classification_report(Y_valid, y_pred_valid))
# Out:
# The efficiency metrics for DNN Validation data is :
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99       523
#            1       0.98      0.99      0.99       568
#            2       0.97      0.99      0.98       479
#            3       0.97      0.97      0.97       496
#            4       0.97      0.98      0.97       509
#            5       0.98      0.97      0.97       480
#            6       0.97      0.98      0.98       493
#            7       0.98      0.98      0.98       499
#            8       0.99      0.97      0.98       488
#            9       0.97      0.97      0.97       465
#
#     accuracy                           0.98      5000
#    macro avg       0.98      0.98      0.98      5000
# weighted avg       0.98      0.98      0.98      5000

# %%
sns.heatmap(metrics.confusion_matrix(Y_valid, y_pred_valid),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Validation dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Validation dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %%
#Transforming the test dataset
pca_test = pca.transform(x_test_norm)
principalDf_test = pd.DataFrame(data = pca_test)
principalDf_test = principalDf_test.add_prefix('pca_')

# %%
principalDf_test.shape
# Out:
# (10000, 154)

# %%
#Reviewing validation accuracy , precision and recall
y_pred_test = model.predict(principalDf_test)
y_pred_test = np.argmax(y_pred_test, axis=1)
print("The accuracy percentage for test dataset is {}".format(accuracy_score(y_test, y_pred_test)))
# Out:
# The accuracy percentage for test dataset is 0.9805

# %%
print('The efficiency metrics for DNN Test data is :')
print(classification_report(y_test, y_pred_test))
# Out:
# The efficiency metrics for DNN Test data is :
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.97      0.98      1032
#            3       0.98      0.99      0.98      1010
#            4       0.97      0.98      0.98       982
#            5       0.98      0.98      0.98       892
#            6       0.98      0.98      0.98       958
#            7       0.98      0.98      0.98      1028
#            8       0.97      0.97      0.97       974
#            9       0.98      0.98      0.98      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_pred_test),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Test dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Test dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %% [markdown]
# ## **Experiment Design 5**:
# 1.   We use a Random Forest classifier to get the relative importance of the 784 features (pixels) of the 28x28 dimensional images in training set of MNIST images and select the top 70 features (pixels).
# 2.   We train our 'best' dense neural network using these 70 features and compare its performance to the the dense neural network models from EXPERIMENTS 3 and 4.

# %%
rnd_clf = RandomForestClassifier(n_estimators=500, max_leaf_nodes=16,random_state=42)
y_train_pred_rf = rnd_clf.fit(x_train_norm, y_train)

# %%
n = 70
imp_arr = rnd_clf.feature_importances_
idx = (-imp_arr).argsort()[:n]          # get the indices of the 70 "most important" features/pixels
len(idx)
# Out:
# 70

# %%
def plot_digit(data):
    image = data.reshape(28, 28)
    plt.imshow(image, cmap = 'hot',
               interpolation="nearest")
    plt.axis("off")

plot_digit(rnd_clf.feature_importances_)
cbar = plt.colorbar(ticks=[rnd_clf.feature_importances_.min(), rnd_clf.feature_importances_.max()])
cbar.ax.set_yticklabels(['Not important', 'Very important'])
plt.show()
# Out:
# [Text(1, 0, 'Not important'), Text(1, 0, 'Very important')]

# %%
# Create training and test images using just the 70 pixel locations obtained above
train_images_sm = x_train_norm[:,idx]
test_images_sm = x_test_norm[:,idx]
train_images_sm.shape, test_images_sm.shape # the reduced images have dimension 70
# Out:
# ((60000, 70), (10000, 70))

# %%
# to convert an index n, 0<= n < 784
def pair(n,size):
    x = n//size 
    y = n%size
    return x,y

# %%
plt.imshow(x_train_norm[2].reshape(28,28),cmap='binary')
x, y = np.array([pair(k,28) for k in idx]).T
plt.scatter(x,y,color='red',s=20)

# %%
#Splitting train dataset into train and validation datasets
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(train_images_sm, y_train, test_size=cross_validation_size, random_state=2)

# %%
X_train.shape , X_valid.shape
# Out:
# ((55000, 70), (5000, 70))

# %%
from tensorflow.keras.utils import to_categorical
y_train_encoded = to_categorical(Y_train ,num_classes = 10)
y_valid_encoded = to_categorical(Y_valid ,num_classes = 10)
y_test_encoded = to_categorical(y_test , num_classes = 10)

# %%
tf.keras.backend.clear_session()
image_size = 70
from keras.constraints import maxnorm
model = Sequential()
model.add(Dense(128, input_dim=(image_size), activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dense( name = "output_layer", units=num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               9088
# _________________________________________________________________
# output_layer (Dense)         (None, 10)                1290
# =================================================================
# Total params: 10,378
# Trainable params: 10,378
# Non-trainable params: 0
# _________________________________________________________________

# %%
# For use with non-categorical labels
model.compile(optimizer='adam',           
               loss = 'categorical_crossentropy',
               metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=50,
    mode='auto', baseline=None, restore_best_weights=False)

history = model.fit(X_train, y_train_encoded, epochs = 200, batch_size = 64, callbacks = [early_stopping], validation_data = (X_valid, y_valid_encoded))
# Out:
# Epoch 1/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.6875 - accuracy: 0.7943 - val_loss: 0.4892 - val_accuracy: 0.8508
# Epoch 2/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.4294 - accuracy: 0.8700 - val_loss: 0.4024 - val_accuracy: 0.8786
# Epoch 3/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.3567 - accuracy: 0.8918 - val_loss: 0.3518 - val_accuracy: 0.8932
# Epoch 4/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.3143 - accuracy: 0.9046 - val_loss: 0.3160 - val_accuracy: 0.9078
# Epoch 5/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.2851 - accuracy: 0.9129 - val_loss: 0.2985 - val_accuracy: 0.9100
# Epoch 6/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.2641 - accuracy: 0.9194 - val_loss: 0.2832 - val_accuracy: 0.9120
# Epoch 7/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.2479 - accuracy: 0.9229 - val_loss: 0.2732 - val_accuracy: 0.9156
# Epoch 8/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.2356 - accuracy: 0.9269 - val_loss: 0.2616 - val_accuracy: 0.9212
# Epoch 9/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.2243 - accuracy: 0.9308 - val_loss: 0.2576 - val_accuracy: 0.9208
# Epoch 10/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.2151 - accuracy: 0.9329 - val_loss: 0.2479 - val_accuracy: 0.9224
# Epoch 11/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.2080 - accuracy: 0.9352 - val_loss: 0.2460 - val_accuracy: 0.9220
# Epoch 12/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.2015 - accuracy: 0.9364 - val_loss: 0.2410 - val_accuracy: 0.9240
# Epoch 13/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1949 - accuracy: 0.9385 - val_loss: 0.2409 - val_accuracy: 0.9256
# Epoch 14/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1896 - accuracy: 0.9407 - val_loss: 0.2400 - val_accuracy: 0.9254
# Epoch 15/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1845 - accuracy: 0.9426 - val_loss: 0.2460 - val_accuracy: 0.9216
# Epoch 16/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1802 - accuracy: 0.9435 - val_loss: 0.2350 - val_accuracy: 0.9274
# Epoch 17/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1759 - accuracy: 0.9451 - val_loss: 0.2300 - val_accuracy: 0.9314
# Epoch 18/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1730 - accuracy: 0.9462 - val_loss: 0.2309 - val_accuracy: 0.9294
# Epoch 19/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1685 - accuracy: 0.9473 - val_loss: 0.2319 - val_accuracy: 0.9304
# Epoch 20/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1662 - accuracy: 0.9476 - val_loss: 0.2294 - val_accuracy: 0.9302
# Epoch 21/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1627 - accuracy: 0.9493 - val_loss: 0.2292 - val_accuracy: 0.9322
# Epoch 22/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1597 - accuracy: 0.9495 - val_loss: 0.2398 - val_accuracy: 0.9280
# Epoch 23/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1565 - accuracy: 0.9506 - val_loss: 0.2257 - val_accuracy: 0.9296
# Epoch 24/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1544 - accuracy: 0.9516 - val_loss: 0.2236 - val_accuracy: 0.9322
# Epoch 25/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1509 - accuracy: 0.9530 - val_loss: 0.2275 - val_accuracy: 0.9292
# Epoch 26/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1489 - accuracy: 0.9535 - val_loss: 0.2262 - val_accuracy: 0.9290
# Epoch 27/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1470 - accuracy: 0.9536 - val_loss: 0.2243 - val_accuracy: 0.9298
# Epoch 28/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1451 - accuracy: 0.9537 - val_loss: 0.2281 - val_accuracy: 0.9310
# Epoch 29/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1419 - accuracy: 0.9557 - val_loss: 0.2292 - val_accuracy: 0.9308
# Epoch 30/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1406 - accuracy: 0.9552 - val_loss: 0.2269 - val_accuracy: 0.9286
# Epoch 31/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1383 - accuracy: 0.9570 - val_loss: 0.2341 - val_accuracy: 0.9288
# Epoch 32/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1369 - accuracy: 0.9568 - val_loss: 0.2294 - val_accuracy: 0.9298
# Epoch 33/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1351 - accuracy: 0.9570 - val_loss: 0.2255 - val_accuracy: 0.9300
# Epoch 34/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1329 - accuracy: 0.9583 - val_loss: 0.2270 - val_accuracy: 0.9346
# Epoch 00034: early stopping

# %%
keras.utils.plot_model(model, "mnist_experiment5.png", show_shapes=True)

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', label = "Training Accuracy")
plt.plot(epochs, val_acc, 'b', label = "Validation Accuracy")
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = "bottom right")
plt.figure()
#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', label = "Training Loss")
plt.plot(epochs, val_loss, 'b', label = "Validation Loss")
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = "upper right")
plt.figure()
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Training and Validation Loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
#Reviewing validation accuracy , precision and recall
y_pred_valid = model.predict(X_valid)
y_pred_valid = np.argmax(y_pred_valid, axis=1)
print("The accuracy percentage for validation dataset is {}".format(accuracy_score(Y_valid, y_pred_valid)))
# Out:
# The accuracy percentage for validation dataset is 0.9346

# %%
print('The efficiency metrics for DNN Validation data is :')
print(classification_report(Y_valid, y_pred_valid))
# Out:
# The efficiency metrics for DNN Validation data is :
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       523
#            1       0.97      0.98      0.98       568
#            2       0.93      0.91      0.92       479
#            3       0.93      0.91      0.92       496
#            4       0.90      0.94      0.92       509
#            5       0.88      0.89      0.89       480
#            6       0.95      0.95      0.95       493
#            7       0.96      0.95      0.96       499
#            8       0.96      0.91      0.93       488
#            9       0.91      0.90      0.91       465
#
#     accuracy                           0.93      5000
#    macro avg       0.93      0.93      0.93      5000
# weighted avg       0.93      0.93      0.93      5000

# %%
sns.heatmap(metrics.confusion_matrix(Y_valid, y_pred_valid),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Validation dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Validation dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %%
y_pred_test = model.predict(test_images_sm)
y_pred_test = np.argmax(y_pred_test, axis=1)
print("The accuracy percentage for test dataset is {}".format(accuracy_score(y_test, y_pred_test)))
# Out:
# The accuracy percentage for test dataset is 0.9394

# %%
print('The efficiency metrics for DNN Test data is :')
print(classification_report(y_test, y_pred_test))
# Out:
# The efficiency metrics for DNN Test data is :
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       980
#            1       0.98      0.99      0.98      1135
#            2       0.95      0.92      0.93      1032
#            3       0.94      0.92      0.93      1010
#            4       0.91      0.95      0.93       982
#            5       0.90      0.90      0.90       892
#            6       0.95      0.93      0.94       958
#            7       0.94      0.96      0.95      1028
#            8       0.96      0.92      0.94       974
#            9       0.93      0.92      0.93      1009
#
#     accuracy                           0.94     10000
#    macro avg       0.94      0.94      0.94     10000
# weighted avg       0.94      0.94      0.94     10000

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_pred_test),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Test dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Test dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %% [markdown]
# # **Experiment Design 6**
# DNN with 1 hidden layer with 256 nodes

# %%
tf.keras.backend.clear_session()
from keras.constraints import maxnorm
image_size = 784
model = Sequential()
model.add(Dense(256, input_dim=(image_size), activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dense( name = "output_layer", units=num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# output_layer (Dense)         (None, 10)                2570
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Splitting train dataset into train and validation datasets
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(x_train_norm, y_train, test_size=cross_validation_size, random_state=2)

# %%
from tensorflow.keras.utils import to_categorical
y_train_encoded = to_categorical(Y_train ,num_classes = 10)
y_valid_encoded = to_categorical(Y_valid ,num_classes = 10)
y_test_encoded = to_categorical(y_test , num_classes = 10)

# %%
# For use with non-categorical labels
model.compile(optimizer='adam',           
               loss = 'categorical_crossentropy',
               metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=50,
    mode='auto', baseline=None, restore_best_weights=False)

history = model.fit(X_train, y_train_encoded, epochs = 200, batch_size = 64, callbacks = [early_stopping], validation_data = (X_valid, y_valid_encoded))
# Out:
# Epoch 1/200
# 860/860 [==============================] - 5s 5ms/step - loss: 0.2659 - accuracy: 0.9256 - val_loss: 0.1474 - val_accuracy: 0.9602
# Epoch 2/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.1131 - accuracy: 0.9672 - val_loss: 0.1068 - val_accuracy: 0.9686
# Epoch 3/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0750 - accuracy: 0.9777 - val_loss: 0.0900 - val_accuracy: 0.9724
# Epoch 4/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0554 - accuracy: 0.9834 - val_loss: 0.0767 - val_accuracy: 0.9758
# Epoch 5/200
# 860/860 [==============================] - 4s 4ms/step - loss: 0.0421 - accuracy: 0.9870 - val_loss: 0.0735 - val_accuracy: 0.9778
# Epoch 6/200
# 860/860 [==============================] - 4s 4ms/step - loss: 0.0306 - accuracy: 0.9912 - val_loss: 0.0710 - val_accuracy: 0.9768
# Epoch 7/200
# 860/860 [==============================] - 4s 4ms/step - loss: 0.0235 - accuracy: 0.9936 - val_loss: 0.0700 - val_accuracy: 0.9764
# Epoch 8/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0188 - accuracy: 0.9946 - val_loss: 0.0671 - val_accuracy: 0.9784
# Epoch 9/200
# 860/860 [==============================] - 4s 4ms/step - loss: 0.0169 - accuracy: 0.9949 - val_loss: 0.0702 - val_accuracy: 0.9764
# Epoch 10/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0140 - accuracy: 0.9960 - val_loss: 0.0701 - val_accuracy: 0.9788
# Epoch 11/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0113 - accuracy: 0.9971 - val_loss: 0.0794 - val_accuracy: 0.9782
# Epoch 12/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0111 - accuracy: 0.9969 - val_loss: 0.0833 - val_accuracy: 0.9764
# Epoch 13/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0096 - accuracy: 0.9975 - val_loss: 0.0847 - val_accuracy: 0.9774
# Epoch 14/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0106 - accuracy: 0.9970 - val_loss: 0.0668 - val_accuracy: 0.9788
# Epoch 15/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.0950 - val_accuracy: 0.9758
# Epoch 16/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 0.0738 - val_accuracy: 0.9806
# Epoch 17/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.0796 - val_accuracy: 0.9774
# Epoch 18/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0102 - accuracy: 0.9967 - val_loss: 0.0753 - val_accuracy: 0.9790
# Epoch 19/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0072 - accuracy: 0.9979 - val_loss: 0.0770 - val_accuracy: 0.9784
# Epoch 20/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0855 - val_accuracy: 0.9780
# Epoch 21/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.0812 - val_accuracy: 0.9780
# Epoch 22/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0101 - accuracy: 0.9967 - val_loss: 0.0928 - val_accuracy: 0.9750
# Epoch 23/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 0.0841 - val_accuracy: 0.9776
# Epoch 24/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0746 - val_accuracy: 0.9798
# Epoch 00024: early stopping

# %%
keras.utils.plot_model(model, "mnist_experiment6.png", show_shapes=True)

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', label = "Training Accuracy")
plt.plot(epochs, val_acc, 'b', label = "Validation Accuracy")
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = "bottom right")
plt.figure()
#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', label = "Training Loss")
plt.plot(epochs, val_loss, 'b', label = "Validation Loss")
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = "upper right")
plt.figure()
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Training and Validation Loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
#Reviewing validation accuracy , precision and recall
y_pred_valid = model.predict(X_valid)
y_pred_valid = np.argmax(y_pred_valid, axis=1)
print("The accuracy percentage for validation dataset is {}".format(accuracy_score(Y_valid, y_pred_valid)))
# Out:
# The accuracy percentage for validation dataset is 0.9798

# %%
print('The efficiency metrics for DNN Validation data is :')
print(classification_report(Y_valid, y_pred_valid))
# Out:
# The efficiency metrics for DNN Validation data is :
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99       523
#            1       0.99      0.99      0.99       568
#            2       0.98      0.99      0.98       479
#            3       0.96      0.97      0.96       496
#            4       0.97      0.99      0.98       509
#            5       0.98      0.97      0.98       480
#            6       0.98      0.99      0.99       493
#            7       0.98      0.99      0.99       499
#            8       0.99      0.97      0.98       488
#            9       0.96      0.97      0.97       465
#
#     accuracy                           0.98      5000
#    macro avg       0.98      0.98      0.98      5000
# weighted avg       0.98      0.98      0.98      5000

# %%
sns.heatmap(metrics.confusion_matrix(Y_valid, y_pred_valid),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Validation dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Validation dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %%
#Reviewing validation accuracy , precision and recall
y_pred_valid = model.predict(X_valid)
y_pred_valid = np.argmax(y_pred_valid, axis=1)
print("The accuracy percentage for test dataset is {}".format(accuracy_score(y_test, y_pred_test)))
# Out:
# The accuracy percentage for test dataset is 0.9394

# %%
print('The efficiency metrics for DNN Test data is :')
print(classification_report(y_test, y_pred_test))
# Out:
# The efficiency metrics for DNN Test data is :
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96       980
#            1       0.98      0.99      0.98      1135
#            2       0.95      0.92      0.93      1032
#            3       0.94      0.92      0.93      1010
#            4       0.91      0.95      0.93       982
#            5       0.90      0.90      0.90       892
#            6       0.95      0.93      0.94       958
#            7       0.94      0.96      0.95      1028
#            8       0.96      0.92      0.94       974
#            9       0.93      0.92      0.93      1009
#
#     accuracy                           0.94     10000
#    macro avg       0.94      0.94      0.94     10000
# weighted avg       0.94      0.94      0.94     10000

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_pred_test),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Test dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Test dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %% [markdown]
# # **Experimental Design 7**
# DNN with 1 hidden layer with 256 nodes and a drop out to avoid possible overfitting

# %%
tf.keras.backend.clear_session()
from keras.constraints import maxnorm
image_size = 784
model = Sequential()
model.add(Dense(256, input_dim=(image_size), activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.2))
model.add(Dense( name = "output_layer", units=num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# output_layer (Dense)         (None, 10)                2570
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Splitting train dataset into train and validation datasets
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(x_train_norm, y_train, test_size=cross_validation_size, random_state=2)

# %%
from tensorflow.keras.utils import to_categorical
y_train_encoded = to_categorical(Y_train ,num_classes = 10)
y_valid_encoded = to_categorical(Y_valid ,num_classes = 10)
y_test_encoded = to_categorical(y_test , num_classes = 10)

# %%
X_train.shape , X_valid.shape
# Out:
# ((55000, 784), (5000, 784))

# %%
# For use with non-categorical labels
model.compile(optimizer='adam',           
               loss = 'categorical_crossentropy',
               metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=50,
    mode='auto', baseline=None, restore_best_weights=False)

history = model.fit(X_train, y_train_encoded, epochs = 200, batch_size = 64, callbacks = [early_stopping], validation_data = (X_valid, y_valid_encoded))
# Out:
# Epoch 1/200
# 860/860 [==============================] - 5s 5ms/step - loss: 0.2898 - accuracy: 0.9168 - val_loss: 0.1544 - val_accuracy: 0.9566
# Epoch 2/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.1322 - accuracy: 0.9611 - val_loss: 0.1093 - val_accuracy: 0.9666
# Epoch 3/200
# 860/860 [==============================] - 5s 5ms/step - loss: 0.0956 - accuracy: 0.9709 - val_loss: 0.0822 - val_accuracy: 0.9752
# Epoch 4/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0737 - accuracy: 0.9773 - val_loss: 0.0799 - val_accuracy: 0.9762
# Epoch 5/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0591 - accuracy: 0.9815 - val_loss: 0.0714 - val_accuracy: 0.9768
# Epoch 6/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0498 - accuracy: 0.9844 - val_loss: 0.0689 - val_accuracy: 0.9782
# Epoch 7/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0409 - accuracy: 0.9871 - val_loss: 0.0694 - val_accuracy: 0.9790
# Epoch 8/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0383 - accuracy: 0.9877 - val_loss: 0.0655 - val_accuracy: 0.9778
# Epoch 9/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0333 - accuracy: 0.9890 - val_loss: 0.0611 - val_accuracy: 0.9794
# Epoch 10/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0288 - accuracy: 0.9907 - val_loss: 0.0728 - val_accuracy: 0.9782
# Epoch 11/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0270 - accuracy: 0.9914 - val_loss: 0.0635 - val_accuracy: 0.9810
# Epoch 12/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0248 - accuracy: 0.9916 - val_loss: 0.0631 - val_accuracy: 0.9790
# Epoch 13/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0244 - accuracy: 0.9918 - val_loss: 0.0639 - val_accuracy: 0.9792
# Epoch 14/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0218 - accuracy: 0.9926 - val_loss: 0.0612 - val_accuracy: 0.9798
# Epoch 15/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0226 - accuracy: 0.9931 - val_loss: 0.0636 - val_accuracy: 0.9802
# Epoch 16/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0190 - accuracy: 0.9940 - val_loss: 0.0600 - val_accuracy: 0.9824
# Epoch 17/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0215 - accuracy: 0.9927 - val_loss: 0.0619 - val_accuracy: 0.9800
# Epoch 18/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0214 - accuracy: 0.9928 - val_loss: 0.0546 - val_accuracy: 0.9836
# Epoch 19/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.0628 - val_accuracy: 0.9798
# Epoch 20/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0206 - accuracy: 0.9934 - val_loss: 0.0639 - val_accuracy: 0.9822
# Epoch 21/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0161 - accuracy: 0.9949 - val_loss: 0.0730 - val_accuracy: 0.9818
# Epoch 22/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0171 - accuracy: 0.9942 - val_loss: 0.0678 - val_accuracy: 0.9788
# Epoch 23/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0164 - accuracy: 0.9946 - val_loss: 0.0661 - val_accuracy: 0.9814
# Epoch 24/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0156 - accuracy: 0.9948 - val_loss: 0.0637 - val_accuracy: 0.9818
# Epoch 25/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0184 - accuracy: 0.9943 - val_loss: 0.0642 - val_accuracy: 0.9834
# Epoch 26/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0160 - accuracy: 0.9945 - val_loss: 0.0642 - val_accuracy: 0.9826
# Epoch 27/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0169 - accuracy: 0.9944 - val_loss: 0.0641 - val_accuracy: 0.9826
# Epoch 28/200
# 860/860 [==============================] - 4s 5ms/step - loss: 0.0154 - accuracy: 0.9949 - val_loss: 0.0686 - val_accuracy: 0.9830
# Epoch 00028: early stopping

# %%
keras.utils.plot_model(model, "mnist_experiment7.png", show_shapes=True)

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', label = "Training Accuracy")
plt.plot(epochs, val_acc, 'b', label = "Validation Accuracy")
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = "bottom right")
plt.figure()
#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', label = "Training Loss")
plt.plot(epochs, val_loss, 'b', label = "Validation Loss")
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = "upper right")
plt.figure()
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Training and Validation Loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
#Reviewing validation accuracy , precision and recall
y_pred_valid = model.predict(X_valid)
y_pred_valid = np.argmax(y_pred_valid, axis=1)
print("The accuracy percentage for validation dataset is {}".format(accuracy_score(Y_valid, y_pred_valid)))
# Out:
# The accuracy percentage for validation dataset is 0.983

# %%
print('The efficiency metrics for DNN Validation data is :')
print(classification_report(Y_valid, y_pred_valid))
# Out:
# The efficiency metrics for DNN Validation data is :
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       523
#            1       0.99      0.99      0.99       568
#            2       0.98      0.98      0.98       479
#            3       0.97      0.98      0.98       496
#            4       0.98      0.98      0.98       509
#            5       0.99      0.98      0.99       480
#            6       0.98      0.99      0.99       493
#            7       0.99      0.98      0.98       499
#            8       0.99      0.97      0.98       488
#            9       0.97      0.98      0.98       465
#
#     accuracy                           0.98      5000
#    macro avg       0.98      0.98      0.98      5000
# weighted avg       0.98      0.98      0.98      5000

# %%
sns.heatmap(metrics.confusion_matrix(Y_valid, y_pred_valid),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Validation dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Validation dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %%
y_pred_test = model.predict(x_test_norm)
y_pred_test = np.argmax(y_pred_test, axis=1)
print("The accuracy percentage for test dataset is {}".format(accuracy_score(y_test, y_pred_test)))
# Out:
# The accuracy percentage for test dataset is 0.98

# %%
print('The efficiency metrics for DNN Validation data is :')
print(classification_report(y_test, y_pred_test))
# Out:
# The efficiency metrics for DNN Validation data is :
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.99      0.97      0.98      1032
#            3       0.96      0.99      0.97      1010
#            4       0.98      0.98      0.98       982
#            5       0.98      0.98      0.98       892
#            6       0.98      0.98      0.98       958
#            7       0.99      0.96      0.98      1028
#            8       0.98      0.97      0.97       974
#            9       0.97      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_pred_test),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Test dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Test dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %% [markdown]
# # **Experiment Design 8**
# DNN with 1 hidden layer and 64 input nodes

# %%
tf.keras.backend.clear_session()
image_size = 784
from keras.constraints import maxnorm
model = Sequential()
model.add(Dense(64, input_dim=(image_size), activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dense( name = "output_layer", units=num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# output_layer (Dense)         (None, 10)                650
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
# For use with non-categorical labels
model.compile(optimizer='adam',           
               loss = 'categorical_crossentropy',
               metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=50,
    mode='auto', baseline=None, restore_best_weights=False)

history = model.fit(X_train, y_train_encoded, epochs = 200, batch_size = 64, callbacks = [early_stopping], validation_data = (X_valid, y_valid_encoded))
# Out:
# Epoch 1/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.3638 - accuracy: 0.8997 - val_loss: 0.2204 - val_accuracy: 0.9336
# Epoch 2/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.1731 - accuracy: 0.9506 - val_loss: 0.1631 - val_accuracy: 0.9500
# Epoch 3/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.1309 - accuracy: 0.9618 - val_loss: 0.1319 - val_accuracy: 0.9604
# Epoch 4/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.1051 - accuracy: 0.9699 - val_loss: 0.1256 - val_accuracy: 0.9606
# Epoch 5/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0897 - accuracy: 0.9736 - val_loss: 0.1108 - val_accuracy: 0.9656
# Epoch 6/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0785 - accuracy: 0.9775 - val_loss: 0.1013 - val_accuracy: 0.9682
# Epoch 7/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0709 - accuracy: 0.9795 - val_loss: 0.1020 - val_accuracy: 0.9682
# Epoch 8/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0643 - accuracy: 0.9816 - val_loss: 0.0945 - val_accuracy: 0.9700
# Epoch 9/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0605 - accuracy: 0.9832 - val_loss: 0.0963 - val_accuracy: 0.9696
# Epoch 10/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0550 - accuracy: 0.9844 - val_loss: 0.0996 - val_accuracy: 0.9698
# Epoch 11/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0518 - accuracy: 0.9851 - val_loss: 0.0840 - val_accuracy: 0.9726
# Epoch 12/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0486 - accuracy: 0.9861 - val_loss: 0.0937 - val_accuracy: 0.9718
# Epoch 13/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0461 - accuracy: 0.9869 - val_loss: 0.0919 - val_accuracy: 0.9710
# Epoch 14/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0422 - accuracy: 0.9883 - val_loss: 0.0917 - val_accuracy: 0.9700
# Epoch 15/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0422 - accuracy: 0.9879 - val_loss: 0.0864 - val_accuracy: 0.9722
# Epoch 16/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0385 - accuracy: 0.9891 - val_loss: 0.0796 - val_accuracy: 0.9756
# Epoch 17/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0369 - accuracy: 0.9897 - val_loss: 0.0902 - val_accuracy: 0.9728
# Epoch 18/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0366 - accuracy: 0.9895 - val_loss: 0.0814 - val_accuracy: 0.9738
# Epoch 19/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0346 - accuracy: 0.9900 - val_loss: 0.0815 - val_accuracy: 0.9744
# Epoch 20/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0327 - accuracy: 0.9908 - val_loss: 0.0801 - val_accuracy: 0.9738
# Epoch 21/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0316 - accuracy: 0.9910 - val_loss: 0.0801 - val_accuracy: 0.9748
# Epoch 22/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0300 - accuracy: 0.9914 - val_loss: 0.0787 - val_accuracy: 0.9760
# Epoch 23/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0299 - accuracy: 0.9912 - val_loss: 0.0814 - val_accuracy: 0.9740
# Epoch 24/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0279 - accuracy: 0.9923 - val_loss: 0.0809 - val_accuracy: 0.9766
# Epoch 25/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0274 - accuracy: 0.9924 - val_loss: 0.0815 - val_accuracy: 0.9746
# Epoch 26/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0261 - accuracy: 0.9931 - val_loss: 0.0823 - val_accuracy: 0.9748
# Epoch 27/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0256 - accuracy: 0.9928 - val_loss: 0.0821 - val_accuracy: 0.9742
# Epoch 28/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0256 - accuracy: 0.9923 - val_loss: 0.0823 - val_accuracy: 0.9758
# Epoch 29/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0245 - accuracy: 0.9931 - val_loss: 0.0777 - val_accuracy: 0.9774
# Epoch 30/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0240 - accuracy: 0.9927 - val_loss: 0.0810 - val_accuracy: 0.9764
# Epoch 31/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0226 - accuracy: 0.9936 - val_loss: 0.0710 - val_accuracy: 0.9764
# Epoch 32/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0227 - accuracy: 0.9936 - val_loss: 0.0796 - val_accuracy: 0.9778
# Epoch 33/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0220 - accuracy: 0.9935 - val_loss: 0.0813 - val_accuracy: 0.9740
# Epoch 34/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0232 - accuracy: 0.9930 - val_loss: 0.0813 - val_accuracy: 0.9748
# Epoch 35/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0224 - accuracy: 0.9933 - val_loss: 0.0753 - val_accuracy: 0.9772
# Epoch 36/200
# 860/860 [==============================] - 3s 3ms/step - loss: 0.0203 - accuracy: 0.9947 - val_loss: 0.0892 - val_accuracy: 0.9742
# Epoch 37/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0199 - accuracy: 0.9941 - val_loss: 0.0943 - val_accuracy: 0.9706
# Epoch 38/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0209 - accuracy: 0.9939 - val_loss: 0.0858 - val_accuracy: 0.9746
# Epoch 39/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0189 - accuracy: 0.9947 - val_loss: 0.0784 - val_accuracy: 0.9780
# Epoch 40/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0182 - accuracy: 0.9950 - val_loss: 0.0846 - val_accuracy: 0.9766
# Epoch 41/200
# 860/860 [==============================] - 2s 3ms/step - loss: 0.0183 - accuracy: 0.9952 - val_loss: 0.0785 - val_accuracy: 0.9744
# Epoch 00041: early stopping

# %%
keras.utils.plot_model(model, "mnist_experiment8.png", show_shapes=True)

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', label = "Training Accuracy")
plt.plot(epochs, val_acc, 'b', label = "Validation Accuracy")
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = "bottom right")
plt.figure()
#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', label = "Training Loss")
plt.plot(epochs, val_loss, 'b', label = "Validation Loss")
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = "upper right")
plt.figure()
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Training and Validation Loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
#Reviewing validation accuracy , precision and recall
y_pred_valid = model.predict(X_valid)
y_pred_valid = np.argmax(y_pred_valid, axis=1)
print("The accuracy percentage for validation dataset is {}".format(accuracy_score(Y_valid, y_pred_valid)))
# Out:
# The accuracy percentage for validation dataset is 0.9744

# %%
print('The efficiency metrics for DNN Validation data is :')
print(classification_report(Y_valid, y_pred_valid))
# Out:
# The efficiency metrics for DNN Validation data is :
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       523
#            1       0.98      0.99      0.98       568
#            2       0.98      0.97      0.98       479
#            3       0.98      0.95      0.96       496
#            4       0.97      0.99      0.98       509
#            5       0.97      0.96      0.97       480
#            6       0.97      0.99      0.98       493
#            7       0.98      0.99      0.98       499
#            8       0.96      0.96      0.96       488
#            9       0.97      0.97      0.97       465
#
#     accuracy                           0.97      5000
#    macro avg       0.97      0.97      0.97      5000
# weighted avg       0.97      0.97      0.97      5000

# %%
sns.heatmap(metrics.confusion_matrix(Y_valid, y_pred_valid),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Validation dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Validation dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %%
y_pred_test = model.predict(x_test_norm)
y_pred_test = np.argmax(y_pred_test, axis=1)
print("The accuracy percentage for test dataset is {}".format(accuracy_score(y_test, y_pred_test)))
# Out:
# The accuracy percentage for test dataset is 0.9747

# %%
print('The efficiency metrics for DNN Validation data is :')
print(classification_report(y_test, y_pred_test))
# Out:
# The efficiency metrics for DNN Validation data is :
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.97      0.97      1032
#            3       0.98      0.97      0.97      1010
#            4       0.96      0.98      0.97       982
#            5       0.99      0.96      0.97       892
#            6       0.98      0.98      0.98       958
#            7       0.98      0.96      0.97      1028
#            8       0.95      0.98      0.96       974
#            9       0.98      0.97      0.97      1009
#
#     accuracy                           0.97     10000
#    macro avg       0.97      0.97      0.97     10000
# weighted avg       0.97      0.97      0.97     10000

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_pred_test),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Test dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Test dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %% [markdown]
# # **Experiment Design 9**
# 95% PCA with drop out

# %%
tf.keras.backend.clear_session()
image_size = 154
from keras.constraints import maxnorm
model = Sequential()
model.add(Dense(64, input_dim=(image_size), activation='relu', kernel_constraint=maxnorm(3)))
model.add(Dropout(0.2))
model.add(Dense( name = "output_layer", units=num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                9920
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# output_layer (Dense)         (None, 10)                650
# =================================================================
# Total params: 10,570
# Trainable params: 10,570
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "mnist_experiment9.png", show_shapes=True)

# %%
#Splitting train dataset into train and validation datasets
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(principalDf, y_train, test_size=cross_validation_size, random_state=2)

# %%
# For use with non-categorical labels
model.compile(optimizer='adam',           
               loss = 'categorical_crossentropy',
               metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=50,
    mode='auto', baseline=None, restore_best_weights=False)

history = model.fit(X_train, y_train_encoded, epochs = 200, batch_size = 64, callbacks = [early_stopping], validation_data = (X_valid, y_valid_encoded))
# Out:
# Epoch 1/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.6148 - accuracy: 0.8236 - val_loss: 0.2553 - val_accuracy: 0.9232
# Epoch 2/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.2605 - accuracy: 0.9241 - val_loss: 0.1929 - val_accuracy: 0.9400
# Epoch 3/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.2074 - accuracy: 0.9386 - val_loss: 0.1632 - val_accuracy: 0.9500
# Epoch 4/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1807 - accuracy: 0.9463 - val_loss: 0.1453 - val_accuracy: 0.9538
# Epoch 5/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1595 - accuracy: 0.9524 - val_loss: 0.1333 - val_accuracy: 0.9568
# Epoch 6/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1456 - accuracy: 0.9557 - val_loss: 0.1236 - val_accuracy: 0.9604
# Epoch 7/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1347 - accuracy: 0.9590 - val_loss: 0.1144 - val_accuracy: 0.9646
# Epoch 8/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1221 - accuracy: 0.9626 - val_loss: 0.1100 - val_accuracy: 0.9646
# Epoch 9/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1177 - accuracy: 0.9642 - val_loss: 0.1048 - val_accuracy: 0.9664
# Epoch 10/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1103 - accuracy: 0.9662 - val_loss: 0.1035 - val_accuracy: 0.9664
# Epoch 11/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1047 - accuracy: 0.9672 - val_loss: 0.1022 - val_accuracy: 0.9696
# Epoch 12/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0997 - accuracy: 0.9692 - val_loss: 0.0996 - val_accuracy: 0.9706
# Epoch 13/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0980 - accuracy: 0.9704 - val_loss: 0.0959 - val_accuracy: 0.9700
# Epoch 14/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0913 - accuracy: 0.9721 - val_loss: 0.0934 - val_accuracy: 0.9710
# Epoch 15/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0881 - accuracy: 0.9719 - val_loss: 0.0936 - val_accuracy: 0.9724
# Epoch 16/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0869 - accuracy: 0.9726 - val_loss: 0.0945 - val_accuracy: 0.9698
# Epoch 17/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0872 - accuracy: 0.9727 - val_loss: 0.0917 - val_accuracy: 0.9714
# Epoch 18/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0828 - accuracy: 0.9743 - val_loss: 0.0903 - val_accuracy: 0.9722
# Epoch 19/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0805 - accuracy: 0.9737 - val_loss: 0.0920 - val_accuracy: 0.9710
# Epoch 20/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0773 - accuracy: 0.9752 - val_loss: 0.0912 - val_accuracy: 0.9726
# Epoch 21/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0769 - accuracy: 0.9756 - val_loss: 0.0898 - val_accuracy: 0.9728
# Epoch 22/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0729 - accuracy: 0.9767 - val_loss: 0.0920 - val_accuracy: 0.9734
# Epoch 23/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0727 - accuracy: 0.9763 - val_loss: 0.0909 - val_accuracy: 0.9738
# Epoch 24/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0706 - accuracy: 0.9772 - val_loss: 0.0931 - val_accuracy: 0.9728
# Epoch 25/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0696 - accuracy: 0.9776 - val_loss: 0.0910 - val_accuracy: 0.9720
# Epoch 26/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0698 - accuracy: 0.9773 - val_loss: 0.0918 - val_accuracy: 0.9738
# Epoch 27/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0659 - accuracy: 0.9786 - val_loss: 0.0909 - val_accuracy: 0.9746
# Epoch 28/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0677 - accuracy: 0.9781 - val_loss: 0.0918 - val_accuracy: 0.9744
# Epoch 29/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0655 - accuracy: 0.9795 - val_loss: 0.0910 - val_accuracy: 0.9730
# Epoch 30/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0651 - accuracy: 0.9784 - val_loss: 0.0880 - val_accuracy: 0.9734
# Epoch 31/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0645 - accuracy: 0.9785 - val_loss: 0.0917 - val_accuracy: 0.9738
# Epoch 32/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0632 - accuracy: 0.9794 - val_loss: 0.0896 - val_accuracy: 0.9750
# Epoch 33/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0622 - accuracy: 0.9792 - val_loss: 0.0928 - val_accuracy: 0.9744
# Epoch 34/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0609 - accuracy: 0.9800 - val_loss: 0.0903 - val_accuracy: 0.9742
# Epoch 35/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0626 - accuracy: 0.9796 - val_loss: 0.0916 - val_accuracy: 0.9724
# Epoch 36/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0598 - accuracy: 0.9799 - val_loss: 0.0895 - val_accuracy: 0.9754
# Epoch 37/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0600 - accuracy: 0.9805 - val_loss: 0.0931 - val_accuracy: 0.9748
# Epoch 38/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0576 - accuracy: 0.9812 - val_loss: 0.0901 - val_accuracy: 0.9754
# Epoch 39/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0598 - accuracy: 0.9797 - val_loss: 0.0899 - val_accuracy: 0.9748
# Epoch 40/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0574 - accuracy: 0.9805 - val_loss: 0.0927 - val_accuracy: 0.9730
# Epoch 00040: early stopping

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', label = "Training Accuracy")
plt.plot(epochs, val_acc, 'b', label = "Validation Accuracy")
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = "bottom right")
plt.figure()
#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', label = "Training Loss")
plt.plot(epochs, val_loss, 'b', label = "Validation Loss")
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = "upper right")
plt.figure()
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Training and Validation Loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
#Reviewing validation accuracy , precision and recall
y_pred_valid = model.predict(X_valid)
y_pred_valid = np.argmax(y_pred_valid, axis=1)
print("The accuracy percentage for validation dataset is {}".format(accuracy_score(Y_valid, y_pred_valid)))
# Out:
# The accuracy percentage for validation dataset is 0.973

# %%
print('The efficiency metrics for DNN Validation data is :')
print(classification_report(Y_valid, y_pred_valid))
# Out:
# The efficiency metrics for DNN Validation data is :
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       523
#            1       0.98      0.98      0.98       568
#            2       0.96      0.99      0.98       479
#            3       0.96      0.97      0.96       496
#            4       0.97      0.97      0.97       509
#            5       0.97      0.97      0.97       480
#            6       0.98      0.98      0.98       493
#            7       0.97      0.98      0.97       499
#            8       0.98      0.95      0.97       488
#            9       0.96      0.97      0.96       465
#
#     accuracy                           0.97      5000
#    macro avg       0.97      0.97      0.97      5000
# weighted avg       0.97      0.97      0.97      5000

# %%
sns.heatmap(metrics.confusion_matrix(Y_valid, y_pred_valid),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Validation dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Validation dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %%
y_pred_test = model.predict(principalDf_test)
y_pred_test = np.argmax(y_pred_test, axis=1)
print("The accuracy percentage for test dataset is {}".format(accuracy_score(y_test, y_pred_test)))
# Out:
# The accuracy percentage for test dataset is 0.9764

# %%
print('The efficiency metrics for DNN test data is :')
print(classification_report(y_test, y_pred_test))
# Out:
# The efficiency metrics for DNN test data is :
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.97      0.98      0.98      1032
#            3       0.96      0.98      0.97      1010
#            4       0.97      0.97      0.97       982
#            5       0.98      0.96      0.97       892
#            6       0.98      0.98      0.98       958
#            7       0.97      0.98      0.97      1028
#            8       0.98      0.96      0.97       974
#            9       0.97      0.97      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_pred_test),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Test dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Test dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %% [markdown]
# # **Experiment Design 10**

# %%
tf.keras.backend.clear_session()
from keras.constraints import maxnorm
image_size = 784
model = Sequential()
model.add(Dense(32, input_dim=(image_size), activation='relu'))
model.add(Dense( name = "output_layer", units=num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                25120
# _________________________________________________________________
# output_layer (Dense)         (None, 10)                330
# =================================================================
# Total params: 25,450
# Trainable params: 25,450
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, "mnist_experiment10.png", show_shapes=True)

# %%
#Splitting train dataset into train and validation datasets
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(x_train_norm, y_train, test_size=cross_validation_size, random_state=2)

# %%
# For use with non-categorical labels
model.compile(optimizer='adam',           
               loss = 'categorical_crossentropy',
               metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=50,
    mode='auto', baseline=None, restore_best_weights=False)

history = model.fit(X_train, y_train_encoded, epochs = 200, batch_size = 64, callbacks = [early_stopping], validation_data = (X_valid, y_valid_encoded))
# Out:
# Epoch 1/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.4295 - accuracy: 0.8830 - val_loss: 0.2675 - val_accuracy: 0.9234
# Epoch 2/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.2296 - accuracy: 0.9342 - val_loss: 0.2141 - val_accuracy: 0.9382
# Epoch 3/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1849 - accuracy: 0.9473 - val_loss: 0.1952 - val_accuracy: 0.9420
# Epoch 4/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1566 - accuracy: 0.9556 - val_loss: 0.1732 - val_accuracy: 0.9488
# Epoch 5/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1375 - accuracy: 0.9600 - val_loss: 0.1626 - val_accuracy: 0.9530
# Epoch 6/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1232 - accuracy: 0.9642 - val_loss: 0.1621 - val_accuracy: 0.9510
# Epoch 7/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1132 - accuracy: 0.9674 - val_loss: 0.1570 - val_accuracy: 0.9538
# Epoch 8/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.1034 - accuracy: 0.9693 - val_loss: 0.1432 - val_accuracy: 0.9570
# Epoch 9/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0959 - accuracy: 0.9715 - val_loss: 0.1426 - val_accuracy: 0.9586
# Epoch 10/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0896 - accuracy: 0.9731 - val_loss: 0.1386 - val_accuracy: 0.9604
# Epoch 11/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0836 - accuracy: 0.9749 - val_loss: 0.1300 - val_accuracy: 0.9616
# Epoch 12/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0776 - accuracy: 0.9773 - val_loss: 0.1314 - val_accuracy: 0.9620
# Epoch 13/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0739 - accuracy: 0.9779 - val_loss: 0.1325 - val_accuracy: 0.9626
# Epoch 14/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0685 - accuracy: 0.9797 - val_loss: 0.1306 - val_accuracy: 0.9616
# Epoch 15/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0648 - accuracy: 0.9804 - val_loss: 0.1360 - val_accuracy: 0.9636
# Epoch 16/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0620 - accuracy: 0.9812 - val_loss: 0.1328 - val_accuracy: 0.9634
# Epoch 17/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0582 - accuracy: 0.9823 - val_loss: 0.1360 - val_accuracy: 0.9632
# Epoch 18/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0550 - accuracy: 0.9833 - val_loss: 0.1293 - val_accuracy: 0.9644
# Epoch 19/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0521 - accuracy: 0.9840 - val_loss: 0.1283 - val_accuracy: 0.9630
# Epoch 20/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0499 - accuracy: 0.9848 - val_loss: 0.1361 - val_accuracy: 0.9616
# Epoch 21/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0466 - accuracy: 0.9853 - val_loss: 0.1361 - val_accuracy: 0.9612
# Epoch 22/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0450 - accuracy: 0.9863 - val_loss: 0.1339 - val_accuracy: 0.9612
# Epoch 23/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0423 - accuracy: 0.9875 - val_loss: 0.1322 - val_accuracy: 0.9620
# Epoch 24/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0400 - accuracy: 0.9881 - val_loss: 0.1330 - val_accuracy: 0.9632
# Epoch 25/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0383 - accuracy: 0.9883 - val_loss: 0.1455 - val_accuracy: 0.9616
# Epoch 26/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0373 - accuracy: 0.9884 - val_loss: 0.1434 - val_accuracy: 0.9586
# Epoch 27/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0349 - accuracy: 0.9890 - val_loss: 0.1455 - val_accuracy: 0.9628
# Epoch 28/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0335 - accuracy: 0.9896 - val_loss: 0.1439 - val_accuracy: 0.9610
# Epoch 29/200
# 860/860 [==============================] - 2s 2ms/step - loss: 0.0316 - accuracy: 0.9910 - val_loss: 0.1488 - val_accuracy: 0.9618
# Epoch 00029: early stopping

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', label = "Training Accuracy")
plt.plot(epochs, val_acc, 'b', label = "Validation Accuracy")
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = "bottom right")
plt.figure()
#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', label = "Training Loss")
plt.plot(epochs, val_loss, 'b', label = "Validation Loss")
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = "upper right")
plt.figure()
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Training and Validation Loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
#Reviewing validation accuracy , precision and recall
y_pred_valid = model.predict(X_valid)
y_pred_valid = np.argmax(y_pred_valid, axis=1)
print("The accuracy percentage for validation dataset is {}".format(accuracy_score(Y_valid, y_pred_valid)))
# Out:
# The accuracy percentage for validation dataset is 0.9618

# %%
sns.heatmap(metrics.confusion_matrix(Y_valid, y_pred_valid),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for validation dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for validation dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')

# %%
y_pred_test = model.predict(x_test_norm)
y_pred_test = np.argmax(y_pred_test, axis=1)
print("The accuracy percentage for test dataset is {}".format(accuracy_score(y_test, y_pred_test)))
# Out:
# The accuracy percentage for test dataset is 0.9657

# %%
sns.heatmap(metrics.confusion_matrix(y_test, y_pred_test),annot=True,fmt='5.0f',cmap="Blues")
plt.title('Confusion Matrix for Test dataset is', y=1.05, size=15)
plt.ylabel('Predicted Digits')
plt.xlabel('Actual Digits')
# Out:
# Text(0.5, 1.05, 'Confusion Matrix for Test dataset is')
# Text(33.0, 0.5, 'Predicted Digits')
# Text(0.5, 15.0, 'Actual Digits')
