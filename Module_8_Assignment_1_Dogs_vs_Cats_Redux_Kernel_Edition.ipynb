# %% [markdown]
# <a href="https://colab.research.google.com/github/how-to-train-your-model/data-science-portfolio/blob/main/Module_8_Assignment_1_Dogs_vs_Cats_Redux_Kernel_Edition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 8: Dogs vs. Cats Redux: Kernel Edition
#
# ### Author: Pankaj Pant

# %% [markdown]
# Importing Packages

# %%
# !pip install pathlib2
# Out:
# Collecting pathlib2
#   Downloading pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from pathlib2) (1.15.0)
# Installing collected packages: pathlib2
# Successfully installed pathlib2-2.3.7.post1

# %% [markdown]
# # Import Packages

# %%
import os
from pathlib2 import Path
import zipfile
from zipfile import ZipFile
import time

import pandas as pd
import numpy as np
import subprocess

import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

sns.set()

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

from tqdm import tqdm
from PIL import Image, ImageFilter
from IPython.display import display
import cv2

from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Activation, BatchNormalization
from keras.losses import SparseCategoricalCrossentropy
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow import keras
from sklearn.metrics import classification_report

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)
from sklearn.utils._testing import ignore_warnings
from sklearn.exceptions import ConvergenceWarning

# %%
# Allows for muliple output in one cell window
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

#Allows for viewing the complete data in a single window 
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %% [markdown]
# # Data Ingestion
# ### Connect to google drive and import training and test data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -l "/content/drive/My Drive/Colab_Notebooks/MSDS-422/W8"
# Out:
# total 837729
# -rw------- 1 root root   1037710 Feb 23 19:49 'Credit_Card_Fraud_Detection-Solution (1).ipynb'
# drwx------ 2 root root      4096 Feb 24 05:44  data
# -rw------- 1 root root    643913 Feb 23 20:02 'Flight_Delay-Solution (1).ipynb'
# -rw------- 1 root root    915693 Feb 25 23:28 'Module1_Assignment8_Group5 (1).ipynb'
# -rw------- 1 root root    703443 Feb 26 15:47 'Module 8 Assignment 1: Dogs vs. Cats Redux: Kernel Edition.ipynb'
# -rw------- 1 root root       143 Feb 26 15:44 'Module 8: Dogs vs. Cats Redux: Kernel Edition .gdoc'
# -rw------- 1 root root    113903 Feb 24 01:40  sample_submission.csv
# drwx------ 2 root root      4096 Feb 24 12:25  test
# drwx------ 2 root root      4096 Feb 24 05:46  test1
# -rw------- 1 root root 284478493 Feb 24 01:40  test.zip
# drwx------ 2 root root      4096 Feb 24 12:26  train
# drwx------ 2 root root      4096 Feb 24 05:45  train1
# -rw------- 1 root root 569918665 Feb 24 01:40  train.zip

# %%
#Generalize the file path 
w8_files = "/content/drive/My Drive/Colab_Notebooks/MSDS-422/W8"

# %%
base_path = '/content/drive/My Drive/Colab_Notebooks/MSDS-422/W8'
csv_base_path = '/content/drive/My Drive/Colab_Notebooks/MSDS-422/W8'
file_path = 'train.zip'

# %%
zip_files = [str(file) for file in list(Path(base_path).iterdir()) if '.zip' in str(file)]
len(zip_files)
# Out:
# 2

# %%
# def zip2csv(zipFile_name , file_path = '/content/drive/My Drive/Colab_Notebooks/MSDS-422/W8'):
#     """
#     Extract csv from zip files
#     zipFile_name: name of the zip file
#     file_path : name of the folder to store csv
#     """
#     try:
#         with ZipFile(zipFile_name, 'r') as z: 
#             print(f'Extracting {zipFile_name} ') 
#             z.extractall(path=file_path) 
#     except:
#         print(f'zip2csv failed for {zipFile_name}')

# for file in zip_files:
#     zip2csv(file)

# print("Files Extracted")

# %%
# csv_files = [str(file) for file in list(Path(csv_base_path).iterdir()) if '.csv' in str(file)]
# len(csv_files)

# %%
base_dir = '/content/drive/My Drive/Colab_Notebooks/MSDS-422/W8'
train_dir = '../data/train'
test_dir = '../data/test'

# %%
os.makedirs('/content/drive/My Drive/Colab_Notebooks/MSDS-422/W8/data', exist_ok=True)

# %%
# %%time
with zipfile.ZipFile(os.path.join(base_dir, 'train.zip')) as train_zip:
    train_zip.extractall('../data')
    
with zipfile.ZipFile(os.path.join(base_dir, 'test.zip')) as test_zip:
    test_zip.extractall('../data')
# Out:
# CPU times: user 11 s, sys: 4.33 s, total: 15.3 s
# Wall time: 25.3 s

# %%
os.listdir(train_dir)[:5]
# Out:
# ['dog.1012.jpg',
#  'dog.1375.jpg',
#  'dog.11960.jpg',
#  'dog.4271.jpg',
#  'cat.9079.jpg']

# %%
import glob

train_list = glob.glob(os.path.join(train_dir,'*.jpg'))
test_list = glob.glob(os.path.join(test_dir, '*.jpg'))

# %%
len(train_list)
# Out:
# 25000

# %%
len(test_list)
# Out:
# 12500

# %%
from PIL import Image
random_idx = np.random.randint(1,25000,size=10)

fig = plt.figure()
i=1
for idx in random_idx:
    ax = fig.add_subplot(4,4,i)
    img = Image.open(train_list[idx])
    plt.imshow(img)
    i+=1

plt.axis('off')
plt.show()
# Out:
# (-0.5, 498.5, 374.5, -0.5)

# %% [markdown]
# ## Data Extraction

# %%
def label_img(img_name):
  if 'cat' in img_name: return [1, 0]
  elif 'dog' in img_name: return [0, 1]

# %%
train_data = []

with zipfile.ZipFile('/content/drive/My Drive/Colab_Notebooks/MSDS-422/W8/train.zip', 'r') as z:
  for fn in tqdm(z.namelist()):
    if not os.path.isdir(fn) and fn.endswith("jpg"):
      label = label_img(fn)

      img_str = z.read(fn)

      nparr = np.frombuffer(img_str, np.uint8)

      img_np = cv2.imdecode(nparr, cv2.IMREAD_GRAYSCALE)
      img = cv2.resize(img_np, (100, 100)) #HXW

      train_data.append([ np.array(img), np.array(label)])
# Out:
# 100%|██████████| 25001/25001 [00:41<00:00, 609.34it/s]

# %%
len(train_data)
train_data[1]
# Out:
# 25000
# [array([[ 43,  44,  43, ...,  94, 183, 193],
#         [ 40,  37,  38, ..., 103, 177, 194],
#         [ 43,  37,  40, ...,  91, 174, 195],
#         ...,
#         [ 21,  20,  20, ...,  84,  73,  41],
#         [ 24,  18,  21, ...,  59,  39,  30],
#         [ 29,  20,  24, ...,  89,  19,  36]], dtype=uint8), array([1, 0])]

# %% [markdown]
# ## Unzip the files

# %%
! unzip "/content/drive/My Drive/Colab_Notebooks/MSDS-422/W8/train.zip" -d train
! unzip "/content/drive/My Drive/Colab_Notebooks/MSDS-422/W8/test.zip" -d test
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test/test/5499.jpg
#   inflating: test/test/55.jpg
#   inflating: test/test/550.jpg
#   inflating: test/test/5500.jpg
#   inflating: test/test/5501.jpg
#   inflating: test/test/5502.jpg
#   inflating: test/test/5503.jpg
#   inflating: test/test/5504.jpg
#   inflating: test/test/5505.jpg
#   inflating: test/test/5506.jpg
#   inflating: test/test/5507.jpg
#   inflating: test/test/5508.jpg
#   inflating: test/test/5509.jpg
#   inflating: test/test/551.jpg
#   inflating: test/test/5510.jpg
#   inflating: test/test/5511.jpg
#   inflating: test/test/5512.jpg
#   inflating: test/test/5513.jpg
#   inflating: test/test/5514.jpg
#   inflating: test/test/5515.jpg
#   inflating: test/test/5516.jpg
#   inflating: test/test/5517.jpg
#   inflating: test/test/5518.jpg
#   inflating: test/test/5519.jpg
#   inflating: test/test/552.jpg
#   inflating: test/test/5520.jpg
#   inflating: test/test/5521.jpg
#   inflating: test/test/5522.jpg
#   inflating: test/test/5523.jpg
#   inflating: test/test/5524.jpg
#   inflating: test/test/5525.jpg
#   inflating: test/test/5526.jpg
#   inflating: test/test/5527.jpg
#   inflating: test/test/5528.jpg
#   inflating: test/test/5529.jpg
#   inflating: test/test/553.jpg
#   inflating: test/test/5530.jpg
#   inflating: test/test/5531.jpg
#   inflating: test/test/5532.jpg
#   inflating: test/test/5533.jpg
#   inflating: test/test/5534.jpg
#   inflating: test/test/5535.jpg
#   inflating: test/test/5536.jpg
#   inflating: test/test/5537.jpg
#   inflating: test/test/5538.jpg
#   inflating: test/test/5539.jpg
#   inflating: test/test/554.jpg
#   inflating: test/test/5540.jpg
#   inflating: test/test/5541.jpg
#   inflating: test/test/5542.jpg
#   inflating: test/test/5543.jpg
#   inflating: test/test/5544.jpg
#   inflating: test/test/5545.jpg
#   inflating: test/test/5546.jpg
#   inflating: test/test/5547.jpg
#   inflating: test/test/5548.jpg
#   inflating: test/test/5549.jpg
#   inflating: test/test/555.jpg
#   inflating: test/test/5550.jpg
#   inflating: test/test/5551.jpg
#   inflating: test/test/5552.jpg
#   inflating: test/test/5553.jpg
#   inflating: test/test/5554.jpg
#   inflating: test/test/5555.jpg
#   inflating: test/test/5556.jpg
#   inflating: test/test/5557.jpg
#   inflating: test/test/5558.jpg
#   inflating: test/test/5559.jpg
#   inflating: test/test/556.jpg
#   inflating: test/test/5560.jpg
#   inflating: test/test/5561.jpg
#   inflating: test/test/5562.jpg
#   inflating: test/test/5563.jpg
#   inflating: test/test/5564.jpg
#   inflating: test/test/5565.jpg
#   inflating: test/test/5566.jpg
#   inflating: test/test/5567.jpg
#   inflating: test/test/5568.jpg
#   inflating: test/test/5569.jpg
#   inflating: test/test/557.jpg
#   inflating: test/test/5570.jpg
#   inflating: test/test/5571.jpg
#   inflating: test/test/5572.jpg
#   inflating: test/test/5573.jpg
#   inflating: test/test/5574.jpg
#   inflating: test/test/5575.jpg
#   inflating: test/test/5576.jpg
#   inflating: test/test/5577.jpg
#   inflating: test/test/5578.jpg
#   inflating: test/test/5579.jpg
#   inflating: test/test/558.jpg
#   inflating: test/test/5580.jpg
#   inflating: test/test/5581.jpg
#   inflating: test/test/5582.jpg
#   inflating: test/test/5583.jpg
#   inflating: test/test/5584.jpg
#   inflating: test/test/5585.jpg
#   inflating: test/test/5586.jpg
#   inflating: test/test/5587.jpg
#   inflating: test/test/5588.jpg
#   inflating: test/test/5589.jpg
#   inflating: test/test/559.jpg
#   inflating: test/test/5590.jpg
#   inflating: test/test/5591.jpg
#   inflating: test/test/5592.jpg
#   inflating: test/test/5593.jpg
#   inflating: test/test/5594.jpg
#   inflating: test/test/5595.jpg
#   inflating: test/test/5596.jpg
#   inflating: test/test/5597.jpg
#   inflating: test/test/5598.jpg
#   inflating: test/test/5599.jpg
#   inflating: test/test/56.jpg
#   inflating: test/test/560.jpg
#   inflating: test/test/5600.jpg
#   inflating: test/test/5601.jpg
#   inflating: test/test/5602.jpg
#   inflating: test/test/5603.jpg
#   inflating: test/test/5604.jpg
#   inflating: test/test/5605.jpg
#   inflating: test/test/5606.jpg
#   inflating: test/test/5607.jpg
#   inflating: test/test/5608.jpg
#   inflating: test/test/5609.jpg
#   inflating: test/test/561.jpg
#   inflating: test/test/5610.jpg
#   inflating: test/test/5611.jpg
#   inflating: test/test/5612.jpg
#   inflating: test/test/5613.jpg
#   inflating: test/test/5614.jpg
#   inflating: test/test/5615.jpg
#   inflating: test/test/5616.jpg
#   inflating: test/test/5617.jpg
#   inflating: test/test/5618.jpg
#   inflating: test/test/5619.jpg
#   inflating: test/test/562.jpg
#   inflating: test/test/5620.jpg
#   inflating: test/test/5621.jpg
#   inflating: test/test/5622.jpg
#   inflating: test/test/5623.jpg
#   inflating: test/test/5624.jpg
#   inflating: test/test/5625.jpg
#   inflating: test/test/5626.jpg
#   inflating: test/test/5627.jpg
#   inflating: test/test/5628.jpg
#   inflating: test/test/5629.jpg
#   inflating: test/test/563.jpg
#   inflating: test/test/5630.jpg
#   inflating: test/test/5631.jpg
#   inflating: test/test/5632.jpg
#   inflating: test/test/5633.jpg
#   inflating: test/test/5634.jpg
#   inflating: test/test/5635.jpg
#   inflating: test/test/5636.jpg
#   inflating: test/test/5637.jpg
#   inflating: test/test/5638.jpg
#   inflating: test/test/5639.jpg
#   inflating: test/test/564.jpg
#   inflating: test/test/5640.jpg
#   inflating: test/test/5641.jpg
#   inflating: test/test/5642.jpg
#   inflating: test/test/5643.jpg
#   inflating: test/test/5644.jpg
#   inflating: test/test/5645.jpg
#   inflating: test/test/5646.jpg
#   inflating: test/test/5647.jpg
#   inflating: test/test/5648.jpg
#   inflating: test/test/5649.jpg
#   inflating: test/test/565.jpg
#   inflating: test/test/5650.jpg
#   inflating: test/test/5651.jpg
#   inflating: test/test/5652.jpg
#   inflating: test/test/5653.jpg
#   inflating: test/test/5654.jpg
#   inflating: test/test/5655.jpg
#   inflating: test/test/5656.jpg
#   inflating: test/test/5657.jpg
#   inflating: test/test/5658.jpg
#   inflating: test/test/5659.jpg
#   inflating: test/test/566.jpg
#   inflating: test/test/5660.jpg
#   inflating: test/test/5661.jpg
#   inflating: test/test/5662.jpg
#   inflating: test/test/5663.jpg
#   inflating: test/test/5664.jpg
#   inflating: test/test/5665.jpg
#   inflating: test/test/5666.jpg
#   inflating: test/test/5667.jpg
#   inflating: test/test/5668.jpg
#   inflating: test/test/5669.jpg
#   inflating: test/test/567.jpg
#   inflating: test/test/5670.jpg
#   inflating: test/test/5671.jpg
#   inflating: test/test/5672.jpg
#   inflating: test/test/5673.jpg
#   inflating: test/test/5674.jpg
#   inflating: test/test/5675.jpg
#   inflating: test/test/5676.jpg
#   inflating: test/test/5677.jpg
#   inflating: test/test/5678.jpg
#   inflating: test/test/5679.jpg
#   inflating: test/test/568.jpg
#   inflating: test/test/5680.jpg
#   inflating: test/test/5681.jpg
#   inflating: test/test/5682.jpg
#   inflating: test/test/5683.jpg
#   inflating: test/test/5684.jpg
#   inflating: test/test/5685.jpg
#   inflating: test/test/5686.jpg
#   inflating: test/test/5687.jpg
#   inflating: test/test/5688.jpg
#   inflating: test/test/5689.jpg
#   inflating: test/test/569.jpg
#   inflating: test/test/5690.jpg
#   inflating: test/test/5691.jpg
#   inflating: test/test/5692.jpg
#   inflating: test/test/5693.jpg
#   inflating: test/test/5694.jpg
#   inflating: test/test/5695.jpg
#   inflating: test/test/5696.jpg
#   inflating: test/test/5697.jpg
#   inflating: test/test/5698.jpg
#   inflating: test/test/5699.jpg
#   inflating: test/test/57.jpg
#   inflating: test/test/570.jpg
#   inflating: test/test/5700.jpg
#   inflating: test/test/5701.jpg
#   inflating: test/test/5702.jpg
#   inflating: test/test/5703.jpg
#   inflating: test/test/5704.jpg
#   inflating: test/test/5705.jpg
#   inflating: test/test/5706.jpg
#   inflating: test/test/5707.jpg
#   inflating: test/test/5708.jpg
#   inflating: test/test/5709.jpg
#   inflating: test/test/571.jpg
#   inflating: test/test/5710.jpg
#   inflating: test/test/5711.jpg
#   inflating: test/test/5712.jpg
#   inflating: test/test/5713.jpg
#   inflating: test/test/5714.jpg
#   inflating: test/test/5715.jpg
#   inflating: test/test/5716.jpg
#   inflating: test/test/5717.jpg
#   inflating: test/test/5718.jpg
#   inflating: test/test/5719.jpg
#   inflating: test/test/572.jpg
#   inflating: test/test/5720.jpg
#   inflating: test/test/5721.jpg
#   inflating: test/test/5722.jpg
#   inflating: test/test/5723.jpg
#   inflating: test/test/5724.jpg
#   inflating: test/test/5725.jpg
#   inflating: test/test/5726.jpg
#   inflating: test/test/5727.jpg
#   inflating: test/test/5728.jpg
#   inflating: test/test/5729.jpg
#   inflating: test/test/573.jpg
#   inflating: test/test/5730.jpg
#   inflating: test/test/5731.jpg
#   inflating: test/test/5732.jpg
#   inflating: test/test/5733.jpg
#   inflating: test/test/5734.jpg
#   inflating: test/test/5735.jpg
#   inflating: test/test/5736.jpg
#   inflating: test/test/5737.jpg
#   inflating: test/test/5738.jpg
#   inflating: test/test/5739.jpg
#   inflating: test/test/574.jpg
#   inflating: test/test/5740.jpg
#   inflating: test/test/5741.jpg
#   inflating: test/test/5742.jpg
#   inflating: test/test/5743.jpg
#   inflating: test/test/5744.jpg
#   inflating: test/test/5745.jpg
#   inflating: test/test/5746.jpg
#   inflating: test/test/5747.jpg
#   inflating: test/test/5748.jpg
#   inflating: test/test/5749.jpg
#   inflating: test/test/575.jpg
#   inflating: test/test/5750.jpg
#   inflating: test/test/5751.jpg
#   inflating: test/test/5752.jpg
#   inflating: test/test/5753.jpg
#   inflating: test/test/5754.jpg
#   inflating: test/test/5755.jpg
#   inflating: test/test/5756.jpg
#   inflating: test/test/5757.jpg
#   inflating: test/test/5758.jpg
#   inflating: test/test/5759.jpg
#   inflating: test/test/576.jpg
#   inflating: test/test/5760.jpg
#   inflating: test/test/5761.jpg
#   inflating: test/test/5762.jpg
#   inflating: test/test/5763.jpg
#   inflating: test/test/5764.jpg
#   inflating: test/test/5765.jpg
#   inflating: test/test/5766.jpg
#   inflating: test/test/5767.jpg
#   inflating: test/test/5768.jpg
#   inflating: test/test/5769.jpg
#   inflating: test/test/577.jpg
#   inflating: test/test/5770.jpg
#   inflating: test/test/5771.jpg
#   inflating: test/test/5772.jpg
#   inflating: test/test/5773.jpg
#   inflating: test/test/5774.jpg
#   inflating: test/test/5775.jpg
#   inflating: test/test/5776.jpg
#   inflating: test/test/5777.jpg
#   inflating: test/test/5778.jpg
#   inflating: test/test/5779.jpg
#   inflating: test/test/578.jpg
#   inflating: test/test/5780.jpg
#   inflating: test/test/5781.jpg
#   inflating: test/test/5782.jpg
#   inflating: test/test/5783.jpg
#   inflating: test/test/5784.jpg
#   inflating: test/test/5785.jpg
#   inflating: test/test/5786.jpg
#   inflating: test/test/5787.jpg
#   inflating: test/test/5788.jpg
#   inflating: test/test/5789.jpg
#   inflating: test/test/579.jpg
#   inflating: test/test/5790.jpg
#   inflating: test/test/5791.jpg
#   inflating: test/test/5792.jpg
#   inflating: test/test/5793.jpg
#   inflating: test/test/5794.jpg
#   inflating: test/test/5795.jpg
#   inflating: test/test/5796.jpg
#   inflating: test/test/5797.jpg
#   inflating: test/test/5798.jpg
#   inflating: test/test/5799.jpg
#   inflating: test/test/58.jpg
#   inflating: test/test/580.jpg
#   inflating: test/test/5800.jpg
#   inflating: test/test/5801.jpg
#   inflating: test/test/5802.jpg
#   inflating: test/test/5803.jpg
#   inflating: test/test/5804.jpg
#   inflating: test/test/5805.jpg
#   inflating: test/test/5806.jpg
#   inflating: test/test/5807.jpg
#   inflating: test/test/5808.jpg
#   inflating: test/test/5809.jpg
#   inflating: test/test/581.jpg
#   inflating: test/test/5810.jpg
#   inflating: test/test/5811.jpg
#   inflating: test/test/5812.jpg
#   inflating: test/test/5813.jpg
#   inflating: test/test/5814.jpg
#   inflating: test/test/5815.jpg
#   inflating: test/test/5816.jpg
#   inflating: test/test/5817.jpg
#   inflating: test/test/5818.jpg
#   inflating: test/test/5819.jpg
#   inflating: test/test/582.jpg
#   inflating: test/test/5820.jpg
#   inflating: test/test/5821.jpg
#   inflating: test/test/5822.jpg
#   inflating: test/test/5823.jpg
#   inflating: test/test/5824.jpg
#   inflating: test/test/5825.jpg
#   inflating: test/test/5826.jpg
#   inflating: test/test/5827.jpg
#   inflating: test/test/5828.jpg
#   inflating: test/test/5829.jpg
#   inflating: test/test/583.jpg
#   inflating: test/test/5830.jpg
#   inflating: test/test/5831.jpg
#   inflating: test/test/5832.jpg
#   inflating: test/test/5833.jpg
#   inflating: test/test/5834.jpg
#   inflating: test/test/5835.jpg
#   inflating: test/test/5836.jpg
#   inflating: test/test/5837.jpg
#   inflating: test/test/5838.jpg
#   inflating: test/test/5839.jpg
#   inflating: test/test/584.jpg
#   inflating: test/test/5840.jpg
#   inflating: test/test/5841.jpg
#   inflating: test/test/5842.jpg
#   inflating: test/test/5843.jpg
#   inflating: test/test/5844.jpg
#   inflating: test/test/5845.jpg
#   inflating: test/test/5846.jpg
#   inflating: test/test/5847.jpg
#   inflating: test/test/5848.jpg
#   inflating: test/test/5849.jpg
#   inflating: test/test/585.jpg
#   inflating: test/test/5850.jpg
#   inflating: test/test/5851.jpg
#   inflating: test/test/5852.jpg
#   inflating: test/test/5853.jpg
#   inflating: test/test/5854.jpg
#   inflating: test/test/5855.jpg
#   inflating: test/test/5856.jpg
#   inflating: test/test/5857.jpg
#   inflating: test/test/5858.jpg
#   inflating: test/test/5859.jpg
#   inflating: test/test/586.jpg
#   inflating: test/test/5860.jpg
#   inflating: test/test/5861.jpg
#   inflating: test/test/5862.jpg
#   inflating: test/test/5863.jpg
#   inflating: test/test/5864.jpg
#   inflating: test/test/5865.jpg
#   inflating: test/test/5866.jpg
#   inflating: test/test/5867.jpg
#   inflating: test/test/5868.jpg
#   inflating: test/test/5869.jpg
#   inflating: test/test/587.jpg
#   inflating: test/test/5870.jpg
#   inflating: test/test/5871.jpg
#   inflating: test/test/5872.jpg
#   inflating: test/test/5873.jpg
#   inflating: test/test/5874.jpg
#   inflating: test/test/5875.jpg
#   inflating: test/test/5876.jpg
#   inflating: test/test/5877.jpg
#   inflating: test/test/5878.jpg
#   inflating: test/test/5879.jpg
#   inflating: test/test/588.jpg
#   inflating: test/test/5880.jpg
#   inflating: test/test/5881.jpg
#   inflating: test/test/5882.jpg
#   inflating: test/test/5883.jpg
#   inflating: test/test/5884.jpg
#   inflating: test/test/5885.jpg
#   inflating: test/test/5886.jpg
#   inflating: test/test/5887.jpg
#   inflating: test/test/5888.jpg
#   inflating: test/test/5889.jpg
#   inflating: test/test/589.jpg
#   inflating: test/test/5890.jpg
#   inflating: test/test/5891.jpg
#   inflating: test/test/5892.jpg
#   inflating: test/test/5893.jpg
#   inflating: test/test/5894.jpg
#   inflating: test/test/5895.jpg
#   inflating: test/test/5896.jpg
#   inflating: test/test/5897.jpg
#   inflating: test/test/5898.jpg
#   inflating: test/test/5899.jpg
#   inflating: test/test/59.jpg
#   inflating: test/test/590.jpg
#   inflating: test/test/5900.jpg
#   inflating: test/test/5901.jpg
#   inflating: test/test/5902.jpg
#   inflating: test/test/5903.jpg
#   inflating: test/test/5904.jpg
#   inflating: test/test/5905.jpg
#   inflating: test/test/5906.jpg
#   inflating: test/test/5907.jpg
#   inflating: test/test/5908.jpg
#   inflating: test/test/5909.jpg
#   inflating: test/test/591.jpg
#   inflating: test/test/5910.jpg
#   inflating: test/test/5911.jpg
#   inflating: test/test/5912.jpg
#   inflating: test/test/5913.jpg
#   inflating: test/test/5914.jpg
#   inflating: test/test/5915.jpg
#   inflating: test/test/5916.jpg
#   inflating: test/test/5917.jpg
#   inflating: test/test/5918.jpg
#   inflating: test/test/5919.jpg
#   inflating: test/test/592.jpg
#   inflating: test/test/5920.jpg
#   inflating: test/test/5921.jpg
#   inflating: test/test/5922.jpg
#   inflating: test/test/5923.jpg
#   inflating: test/test/5924.jpg
#   inflating: test/test/5925.jpg
#   inflating: test/test/5926.jpg
#   inflating: test/test/5927.jpg
#   inflating: test/test/5928.jpg
#   inflating: test/test/5929.jpg
#   inflating: test/test/593.jpg
#   inflating: test/test/5930.jpg
#   inflating: test/test/5931.jpg
#   inflating: test/test/5932.jpg
#   inflating: test/test/5933.jpg
#   inflating: test/test/5934.jpg
#   inflating: test/test/5935.jpg
#   inflating: test/test/5936.jpg
#   inflating: test/test/5937.jpg
#   inflating: test/test/5938.jpg
#   inflating: test/test/5939.jpg
#   inflating: test/test/594.jpg
#   inflating: test/test/5940.jpg
#   inflating: test/test/5941.jpg
#   inflating: test/test/5942.jpg
#   inflating: test/test/5943.jpg
#   inflating: test/test/5944.jpg
#   inflating: test/test/5945.jpg
#   inflating: test/test/5946.jpg
#   inflating: test/test/5947.jpg
#   inflating: test/test/5948.jpg
#   inflating: test/test/5949.jpg
#   inflating: test/test/595.jpg
#   inflating: test/test/5950.jpg
#   inflating: test/test/5951.jpg
#   inflating: test/test/5952.jpg
#   inflating: test/test/5953.jpg
#   inflating: test/test/5954.jpg
#   inflating: test/test/5955.jpg
#   inflating: test/test/5956.jpg
#   inflating: test/test/5957.jpg
#   inflating: test/test/5958.jpg
#   inflating: test/test/5959.jpg
#   inflating: test/test/596.jpg
#   inflating: test/test/5960.jpg
#   inflating: test/test/5961.jpg
#   inflating: test/test/5962.jpg
#   inflating: test/test/5963.jpg
#   inflating: test/test/5964.jpg
#   inflating: test/test/5965.jpg
#   inflating: test/test/5966.jpg
#   inflating: test/test/5967.jpg
#   inflating: test/test/5968.jpg
#   inflating: test/test/5969.jpg
#   inflating: test/test/597.jpg
#   inflating: test/test/5970.jpg
#   inflating: test/test/5971.jpg
#   inflating: test/test/5972.jpg
#   inflating: test/test/5973.jpg
#   inflating: test/test/5974.jpg
#   inflating: test/test/5975.jpg
#   inflating: test/test/5976.jpg
#   inflating: test/test/5977.jpg
#   inflating: test/test/5978.jpg
#   inflating: test/test/5979.jpg
#   inflating: test/test/598.jpg
#   inflating: test/test/5980.jpg
#   inflating: test/test/5981.jpg
#   inflating: test/test/5982.jpg
#   inflating: test/test/5983.jpg
#   inflating: test/test/5984.jpg
#   inflating: test/test/5985.jpg
#   inflating: test/test/5986.jpg
#   inflating: test/test/5987.jpg
#   inflating: test/test/5988.jpg
#   inflating: test/test/5989.jpg
#   inflating: test/test/599.jpg
#   inflating: test/test/5990.jpg
#   inflating: test/test/5991.jpg
#   inflating: test/test/5992.jpg
#   inflating: test/test/5993.jpg
#   inflating: test/test/5994.jpg
#   inflating: test/test/5995.jpg
#   inflating: test/test/5996.jpg
#   inflating: test/test/5997.jpg
#   inflating: test/test/5998.jpg
#   inflating: test/test/5999.jpg
#   inflating: test/test/6.jpg
#   inflating: test/test/60.jpg
#   inflating: test/test/600.jpg
#   inflating: test/test/6000.jpg
#   inflating: test/test/6001.jpg
#   inflating: test/test/6002.jpg
#   inflating: test/test/6003.jpg
#   inflating: test/test/6004.jpg
#   inflating: test/test/6005.jpg
#   inflating: test/test/6006.jpg
#   inflating: test/test/6007.jpg
#   inflating: test/test/6008.jpg
#   inflating: test/test/6009.jpg
#   inflating: test/test/601.jpg
#   inflating: test/test/6010.jpg
#   inflating: test/test/6011.jpg
#   inflating: test/test/6012.jpg
#   inflating: test/test/6013.jpg
#   inflating: test/test/6014.jpg
#   inflating: test/test/6015.jpg
#   inflating: test/test/6016.jpg
#   inflating: test/test/6017.jpg
#   inflating: test/test/6018.jpg
#   inflating: test/test/6019.jpg
#   inflating: test/test/602.jpg
#   inflating: test/test/6020.jpg
#   inflating: test/test/6021.jpg
#   inflating: test/test/6022.jpg
#   inflating: test/test/6023.jpg
#   inflating: test/test/6024.jpg
#   inflating: test/test/6025.jpg
#   inflating: test/test/6026.jpg
#   inflating: test/test/6027.jpg
#   inflating: test/test/6028.jpg
#   inflating: test/test/6029.jpg
#   inflating: test/test/603.jpg
#   inflating: test/test/6030.jpg
#   inflating: test/test/6031.jpg
#   inflating: test/test/6032.jpg
#   inflating: test/test/6033.jpg
#   inflating: test/test/6034.jpg
#   inflating: test/test/6035.jpg
#   inflating: test/test/6036.jpg
#   inflating: test/test/6037.jpg
#   inflating: test/test/6038.jpg
#   inflating: test/test/6039.jpg
#   inflating: test/test/604.jpg
#   inflating: test/test/6040.jpg
#   inflating: test/test/6041.jpg
#   inflating: test/test/6042.jpg
#   inflating: test/test/6043.jpg
#   inflating: test/test/6044.jpg
#   inflating: test/test/6045.jpg
#   inflating: test/test/6046.jpg
#   inflating: test/test/6047.jpg
#   inflating: test/test/6048.jpg
#   inflating: test/test/6049.jpg
#   inflating: test/test/605.jpg
#   inflating: test/test/6050.jpg
#   inflating: test/test/6051.jpg
#   inflating: test/test/6052.jpg
#   inflating: test/test/6053.jpg
#   inflating: test/test/6054.jpg
#   inflating: test/test/6055.jpg
#   inflating: test/test/6056.jpg
#   inflating: test/test/6057.jpg
#   inflating: test/test/6058.jpg
#   inflating: test/test/6059.jpg
#   inflating: test/test/606.jpg
#   inflating: test/test/6060.jpg
#   inflating: test/test/6061.jpg
#   inflating: test/test/6062.jpg
#   inflating: test/test/6063.jpg
#   inflating: test/test/6064.jpg
#   inflating: test/test/6065.jpg
#   inflating: test/test/6066.jpg
#   inflating: test/test/6067.jpg
#   inflating: test/test/6068.jpg
#   inflating: test/test/6069.jpg
#   inflating: test/test/607.jpg
#   inflating: test/test/6070.jpg
#   inflating: test/test/6071.jpg
#   inflating: test/test/6072.jpg
#   inflating: test/test/6073.jpg
#   inflating: test/test/6074.jpg
#   inflating: test/test/6075.jpg
#   inflating: test/test/6076.jpg
#   inflating: test/test/6077.jpg
#   inflating: test/test/6078.jpg
#   inflating: test/test/6079.jpg
#   inflating: test/test/608.jpg
#   inflating: test/test/6080.jpg
#   inflating: test/test/6081.jpg
#   inflating: test/test/6082.jpg
#   inflating: test/test/6083.jpg
#   inflating: test/test/6084.jpg
#   inflating: test/test/6085.jpg
#   inflating: test/test/6086.jpg
#   inflating: test/test/6087.jpg
#   inflating: test/test/6088.jpg
#   inflating: test/test/6089.jpg
#   inflating: test/test/609.jpg
#   inflating: test/test/6090.jpg
#   inflating: test/test/6091.jpg
#   inflating: test/test/6092.jpg
#   inflating: test/test/6093.jpg
#   inflating: test/test/6094.jpg
#   inflating: test/test/6095.jpg
#   inflating: test/test/6096.jpg
#   inflating: test/test/6097.jpg
#   inflating: test/test/6098.jpg
#   inflating: test/test/6099.jpg
#   inflating: test/test/61.jpg
#   inflating: test/test/610.jpg
#   inflating: test/test/6100.jpg
#   inflating: test/test/6101.jpg
#   inflating: test/test/6102.jpg
#   inflating: test/test/6103.jpg
#   inflating: test/test/6104.jpg
#   inflating: test/test/6105.jpg
#   inflating: test/test/6106.jpg
#   inflating: test/test/6107.jpg
#   inflating: test/test/6108.jpg
#   inflating: test/test/6109.jpg
#   inflating: test/test/611.jpg
#   inflating: test/test/6110.jpg
#   inflating: test/test/6111.jpg
#   inflating: test/test/6112.jpg
#   inflating: test/test/6113.jpg
#   inflating: test/test/6114.jpg
#   inflating: test/test/6115.jpg
#   inflating: test/test/6116.jpg
#   inflating: test/test/6117.jpg
#   inflating: test/test/6118.jpg
#   inflating: test/test/6119.jpg
#   inflating: test/test/612.jpg
#   inflating: test/test/6120.jpg
#   inflating: test/test/6121.jpg
#   inflating: test/test/6122.jpg
#   inflating: test/test/6123.jpg
#   inflating: test/test/6124.jpg
#   inflating: test/test/6125.jpg
#   inflating: test/test/6126.jpg
#   inflating: test/test/6127.jpg
#   inflating: test/test/6128.jpg
#   inflating: test/test/6129.jpg
#   inflating: test/test/613.jpg
#   inflating: test/test/6130.jpg
#   inflating: test/test/6131.jpg
#   inflating: test/test/6132.jpg
#   inflating: test/test/6133.jpg
#   inflating: test/test/6134.jpg
#   inflating: test/test/6135.jpg
#   inflating: test/test/6136.jpg
#   inflating: test/test/6137.jpg
#   inflating: test/test/6138.jpg
#   inflating: test/test/6139.jpg
#   inflating: test/test/614.jpg
#   inflating: test/test/6140.jpg
#   inflating: test/test/6141.jpg
#   inflating: test/test/6142.jpg
#   inflating: test/test/6143.jpg
#   inflating: test/test/6144.jpg
#   inflating: test/test/6145.jpg
#   inflating: test/test/6146.jpg
#   inflating: test/test/6147.jpg
#   inflating: test/test/6148.jpg
#   inflating: test/test/6149.jpg
#   inflating: test/test/615.jpg
#   inflating: test/test/6150.jpg
#   inflating: test/test/6151.jpg
#   inflating: test/test/6152.jpg
#   inflating: test/test/6153.jpg
#   inflating: test/test/6154.jpg
#   inflating: test/test/6155.jpg
#   inflating: test/test/6156.jpg
#   inflating: test/test/6157.jpg
#   inflating: test/test/6158.jpg
#   inflating: test/test/6159.jpg
#   inflating: test/test/616.jpg
#   inflating: test/test/6160.jpg
#   inflating: test/test/6161.jpg
#   inflating: test/test/6162.jpg
#   inflating: test/test/6163.jpg
#   inflating: test/test/6164.jpg
#   inflating: test/test/6165.jpg
#   inflating: test/test/6166.jpg
#   inflating: test/test/6167.jpg
#   inflating: test/test/6168.jpg
#   inflating: test/test/6169.jpg
#   inflating: test/test/617.jpg
#   inflating: test/test/6170.jpg
#   inflating: test/test/6171.jpg
#   inflating: test/test/6172.jpg
#   inflating: test/test/6173.jpg
#   inflating: test/test/6174.jpg
#   inflating: test/test/6175.jpg
#   inflating: test/test/6176.jpg
#   inflating: test/test/6177.jpg
#   inflating: test/test/6178.jpg
#   inflating: test/test/6179.jpg
#   inflating: test/test/618.jpg
#   inflating: test/test/6180.jpg
#   inflating: test/test/6181.jpg
#   inflating: test/test/6182.jpg
#   inflating: test/test/6183.jpg
#   inflating: test/test/6184.jpg
#   inflating: test/test/6185.jpg
#   inflating: test/test/6186.jpg
#   inflating: test/test/6187.jpg
#   inflating: test/test/6188.jpg
#   inflating: test/test/6189.jpg
#   inflating: test/test/619.jpg
#   inflating: test/test/6190.jpg
#   inflating: test/test/6191.jpg
#   inflating: test/test/6192.jpg
#   inflating: test/test/6193.jpg
#   inflating: test/test/6194.jpg
#   inflating: test/test/6195.jpg
#   inflating: test/test/6196.jpg
#   inflating: test/test/6197.jpg
#   inflating: test/test/6198.jpg
#   inflating: test/test/6199.jpg
#   inflating: test/test/62.jpg
#   inflating: test/test/620.jpg
#   inflating: test/test/6200.jpg
#   inflating: test/test/6201.jpg
#   inflating: test/test/6202.jpg
#   inflating: test/test/6203.jpg
#   inflating: test/test/6204.jpg
#   inflating: test/test/6205.jpg
#   inflating: test/test/6206.jpg
#   inflating: test/test/6207.jpg
#   inflating: test/test/6208.jpg
#   inflating: test/test/6209.jpg
#   inflating: test/test/621.jpg
#   inflating: test/test/6210.jpg
#   inflating: test/test/6211.jpg
#   inflating: test/test/6212.jpg
#   inflating: test/test/6213.jpg
#   inflating: test/test/6214.jpg
#   inflating: test/test/6215.jpg
#   inflating: test/test/6216.jpg
#   inflating: test/test/6217.jpg
#   inflating: test/test/6218.jpg
#   inflating: test/test/6219.jpg
#   inflating: test/test/622.jpg
#   inflating: test/test/6220.jpg
#   inflating: test/test/6221.jpg
#   inflating: test/test/6222.jpg
#   inflating: test/test/6223.jpg
#   inflating: test/test/6224.jpg
#   inflating: test/test/6225.jpg
#   inflating: test/test/6226.jpg
#   inflating: test/test/6227.jpg
#   inflating: test/test/6228.jpg
#   inflating: test/test/6229.jpg
#   inflating: test/test/623.jpg
#   inflating: test/test/6230.jpg
#   inflating: test/test/6231.jpg
#   inflating: test/test/6232.jpg
#   inflating: test/test/6233.jpg
#   inflating: test/test/6234.jpg
#   inflating: test/test/6235.jpg
#   inflating: test/test/6236.jpg
#   inflating: test/test/6237.jpg
#   inflating: test/test/6238.jpg
#   inflating: test/test/6239.jpg
#   inflating: test/test/624.jpg
#   inflating: test/test/6240.jpg
#   inflating: test/test/6241.jpg
#   inflating: test/test/6242.jpg
#   inflating: test/test/6243.jpg
#   inflating: test/test/6244.jpg
#   inflating: test/test/6245.jpg
#   inflating: test/test/6246.jpg
#   inflating: test/test/6247.jpg
#   inflating: test/test/6248.jpg
#   inflating: test/test/6249.jpg
#   inflating: test/test/625.jpg
#   inflating: test/test/6250.jpg
#   inflating: test/test/6251.jpg
#   inflating: test/test/6252.jpg
#   inflating: test/test/6253.jpg
#   inflating: test/test/6254.jpg
#   inflating: test/test/6255.jpg
#   inflating: test/test/6256.jpg
#   inflating: test/test/6257.jpg
#   inflating: test/test/6258.jpg
#   inflating: test/test/6259.jpg
#   inflating: test/test/626.jpg
#   inflating: test/test/6260.jpg
#   inflating: test/test/6261.jpg
#   inflating: test/test/6262.jpg
#   inflating: test/test/6263.jpg
#   inflating: test/test/6264.jpg
#   inflating: test/test/6265.jpg
#   inflating: test/test/6266.jpg
#   inflating: test/test/6267.jpg
#   inflating: test/test/6268.jpg
#   inflating: test/test/6269.jpg
#   inflating: test/test/627.jpg
#   inflating: test/test/6270.jpg
#   inflating: test/test/6271.jpg
#   inflating: test/test/6272.jpg
#   inflating: test/test/6273.jpg
#   inflating: test/test/6274.jpg
#   inflating: test/test/6275.jpg
#   inflating: test/test/6276.jpg
#   inflating: test/test/6277.jpg
#   inflating: test/test/6278.jpg
#   inflating: test/test/6279.jpg
#   inflating: test/test/628.jpg
#   inflating: test/test/6280.jpg
#   inflating: test/test/6281.jpg
#   inflating: test/test/6282.jpg
#   inflating: test/test/6283.jpg
#   inflating: test/test/6284.jpg
#   inflating: test/test/6285.jpg
#   inflating: test/test/6286.jpg
#   inflating: test/test/6287.jpg
#   inflating: test/test/6288.jpg
#   inflating: test/test/6289.jpg
#   inflating: test/test/629.jpg
#   inflating: test/test/6290.jpg
#   inflating: test/test/6291.jpg
#   inflating: test/test/6292.jpg
#   inflating: test/test/6293.jpg
#   inflating: test/test/6294.jpg
#   inflating: test/test/6295.jpg
#   inflating: test/test/6296.jpg
#   inflating: test/test/6297.jpg
#   inflating: test/test/6298.jpg
#   inflating: test/test/6299.jpg
#   inflating: test/test/63.jpg
#   inflating: test/test/630.jpg
#   inflating: test/test/6300.jpg
#   inflating: test/test/6301.jpg
#   inflating: test/test/6302.jpg
#   inflating: test/test/6303.jpg
#   inflating: test/test/6304.jpg
#   inflating: test/test/6305.jpg
#   inflating: test/test/6306.jpg
#   inflating: test/test/6307.jpg
#   inflating: test/test/6308.jpg
#   inflating: test/test/6309.jpg
#   inflating: test/test/631.jpg
#   inflating: test/test/6310.jpg
#   inflating: test/test/6311.jpg
#   inflating: test/test/6312.jpg
#   inflating: test/test/6313.jpg
#   inflating: test/test/6314.jpg
#   inflating: test/test/6315.jpg
#   inflating: test/test/6316.jpg
#   inflating: test/test/6317.jpg
#   inflating: test/test/6318.jpg
#   inflating: test/test/6319.jpg
#   inflating: test/test/632.jpg
#   inflating: test/test/6320.jpg
#   inflating: test/test/6321.jpg
#   inflating: test/test/6322.jpg
#   inflating: test/test/6323.jpg
#   inflating: test/test/6324.jpg
#   inflating: test/test/6325.jpg
#   inflating: test/test/6326.jpg
#   inflating: test/test/6327.jpg
#   inflating: test/test/6328.jpg
#   inflating: test/test/6329.jpg
#   inflating: test/test/633.jpg
#   inflating: test/test/6330.jpg
#   inflating: test/test/6331.jpg
#   inflating: test/test/6332.jpg
#   inflating: test/test/6333.jpg
#   inflating: test/test/6334.jpg
#   inflating: test/test/6335.jpg
#   inflating: test/test/6336.jpg
#   inflating: test/test/6337.jpg
#   inflating: test/test/6338.jpg
#   inflating: test/test/6339.jpg
#   inflating: test/test/634.jpg
#   inflating: test/test/6340.jpg
#   inflating: test/test/6341.jpg
#   inflating: test/test/6342.jpg
#   inflating: test/test/6343.jpg
#   inflating: test/test/6344.jpg
#   inflating: test/test/6345.jpg
#   inflating: test/test/6346.jpg
#   inflating: test/test/6347.jpg
#   inflating: test/test/6348.jpg
#   inflating: test/test/6349.jpg
#   inflating: test/test/635.jpg
#   inflating: test/test/6350.jpg
#   inflating: test/test/6351.jpg
#   inflating: test/test/6352.jpg
#   inflating: test/test/6353.jpg
#   inflating: test/test/6354.jpg
#   inflating: test/test/6355.jpg
#   inflating: test/test/6356.jpg
#   inflating: test/test/6357.jpg
#   inflating: test/test/6358.jpg
#   inflating: test/test/6359.jpg
#   inflating: test/test/636.jpg
#   inflating: test/test/6360.jpg
#   inflating: test/test/6361.jpg
#   inflating: test/test/6362.jpg
#   inflating: test/test/6363.jpg
#   inflating: test/test/6364.jpg
#   inflating: test/test/6365.jpg
#   inflating: test/test/6366.jpg
#   inflating: test/test/6367.jpg
#   inflating: test/test/6368.jpg
#   inflating: test/test/6369.jpg
#   inflating: test/test/637.jpg
#   inflating: test/test/6370.jpg
#   inflating: test/test/6371.jpg
#   inflating: test/test/6372.jpg
#   inflating: test/test/6373.jpg
#   inflating: test/test/6374.jpg
#   inflating: test/test/6375.jpg
#   inflating: test/test/6376.jpg
#   inflating: test/test/6377.jpg
#   inflating: test/test/6378.jpg
#   inflating: test/test/6379.jpg
#   inflating: test/test/638.jpg
#   inflating: test/test/6380.jpg
#   inflating: test/test/6381.jpg
#   inflating: test/test/6382.jpg
#   inflating: test/test/6383.jpg
#   inflating: test/test/6384.jpg
#   inflating: test/test/6385.jpg
#   inflating: test/test/6386.jpg
#   inflating: test/test/6387.jpg
#   inflating: test/test/6388.jpg
#   inflating: test/test/6389.jpg
#   inflating: test/test/639.jpg
#   inflating: test/test/6390.jpg
#   inflating: test/test/6391.jpg
#   inflating: test/test/6392.jpg
#   inflating: test/test/6393.jpg
#   inflating: test/test/6394.jpg
#   inflating: test/test/6395.jpg
#   inflating: test/test/6396.jpg
#   inflating: test/test/6397.jpg
#   inflating: test/test/6398.jpg
#   inflating: test/test/6399.jpg
#   inflating: test/test/64.jpg
#   inflating: test/test/640.jpg
#   inflating: test/test/6400.jpg
#   inflating: test/test/6401.jpg
#   inflating: test/test/6402.jpg
#   inflating: test/test/6403.jpg
#   inflating: test/test/6404.jpg
#   inflating: test/test/6405.jpg
#   inflating: test/test/6406.jpg
#   inflating: test/test/6407.jpg
#   inflating: test/test/6408.jpg
#   inflating: test/test/6409.jpg
#   inflating: test/test/641.jpg
#   inflating: test/test/6410.jpg
#   inflating: test/test/6411.jpg
#   inflating: test/test/6412.jpg
#   inflating: test/test/6413.jpg
#   inflating: test/test/6414.jpg
#   inflating: test/test/6415.jpg
#   inflating: test/test/6416.jpg
#   inflating: test/test/6417.jpg
#   inflating: test/test/6418.jpg
#   inflating: test/test/6419.jpg
#   inflating: test/test/642.jpg
#   inflating: test/test/6420.jpg
#   inflating: test/test/6421.jpg
#   inflating: test/test/6422.jpg
#   inflating: test/test/6423.jpg
#   inflating: test/test/6424.jpg
#   inflating: test/test/6425.jpg
#   inflating: test/test/6426.jpg
#   inflating: test/test/6427.jpg
#   inflating: test/test/6428.jpg
#   inflating: test/test/6429.jpg
#   inflating: test/test/643.jpg
#   inflating: test/test/6430.jpg
#   inflating: test/test/6431.jpg
#   inflating: test/test/6432.jpg
#   inflating: test/test/6433.jpg
#   inflating: test/test/6434.jpg
#   inflating: test/test/6435.jpg
#   inflating: test/test/6436.jpg
#   inflating: test/test/6437.jpg
#   inflating: test/test/6438.jpg
#   inflating: test/test/6439.jpg
#   inflating: test/test/644.jpg
#   inflating: test/test/6440.jpg
#   inflating: test/test/6441.jpg
#   inflating: test/test/6442.jpg
#   inflating: test/test/6443.jpg
#   inflating: test/test/6444.jpg
#   inflating: test/test/6445.jpg
#   inflating: test/test/6446.jpg
#   inflating: test/test/6447.jpg
#   inflating: test/test/6448.jpg
#   inflating: test/test/6449.jpg
#   inflating: test/test/645.jpg
#   inflating: test/test/6450.jpg
#   inflating: test/test/6451.jpg
#   inflating: test/test/6452.jpg
#   inflating: test/test/6453.jpg
#   inflating: test/test/6454.jpg
#   inflating: test/test/6455.jpg
#   inflating: test/test/6456.jpg
#   inflating: test/test/6457.jpg
#   inflating: test/test/6458.jpg
#   inflating: test/test/6459.jpg
#   inflating: test/test/646.jpg
#   inflating: test/test/6460.jpg
#   inflating: test/test/6461.jpg
#   inflating: test/test/6462.jpg
#   inflating: test/test/6463.jpg
#   inflating: test/test/6464.jpg
#   inflating: test/test/6465.jpg
#   inflating: test/test/6466.jpg
#   inflating: test/test/6467.jpg
#   inflating: test/test/6468.jpg
#   inflating: test/test/6469.jpg
#   inflating: test/test/647.jpg
#   inflating: test/test/6470.jpg
#   inflating: test/test/6471.jpg
#   inflating: test/test/6472.jpg
#   inflating: test/test/6473.jpg
#   inflating: test/test/6474.jpg
#   inflating: test/test/6475.jpg
#   inflating: test/test/6476.jpg
#   inflating: test/test/6477.jpg
#   inflating: test/test/6478.jpg
#   inflating: test/test/6479.jpg
#   inflating: test/test/648.jpg
#   inflating: test/test/6480.jpg
#   inflating: test/test/6481.jpg
#   inflating: test/test/6482.jpg
#   inflating: test/test/6483.jpg
#   inflating: test/test/6484.jpg
#   inflating: test/test/6485.jpg
#   inflating: test/test/6486.jpg
#   inflating: test/test/6487.jpg
#   inflating: test/test/6488.jpg
#   inflating: test/test/6489.jpg
#   inflating: test/test/649.jpg
#   inflating: test/test/6490.jpg
#   inflating: test/test/6491.jpg
#   inflating: test/test/6492.jpg
#   inflating: test/test/6493.jpg
#   inflating: test/test/6494.jpg
#   inflating: test/test/6495.jpg
#   inflating: test/test/6496.jpg
#   inflating: test/test/6497.jpg
#   inflating: test/test/6498.jpg
#   inflating: test/test/6499.jpg
#   inflating: test/test/65.jpg
#   inflating: test/test/650.jpg
#   inflating: test/test/6500.jpg
#   inflating: test/test/6501.jpg
#   inflating: test/test/6502.jpg
#   inflating: test/test/6503.jpg
#   inflating: test/test/6504.jpg
#   inflating: test/test/6505.jpg
#   inflating: test/test/6506.jpg
#   inflating: test/test/6507.jpg
#   inflating: test/test/6508.jpg
#   inflating: test/test/6509.jpg
#   inflating: test/test/651.jpg
#   inflating: test/test/6510.jpg
#   inflating: test/test/6511.jpg
#   inflating: test/test/6512.jpg
#   inflating: test/test/6513.jpg
#   inflating: test/test/6514.jpg
#   inflating: test/test/6515.jpg
#   inflating: test/test/6516.jpg
#   inflating: test/test/6517.jpg
#   inflating: test/test/6518.jpg
#   inflating: test/test/6519.jpg
#   inflating: test/test/652.jpg
#   inflating: test/test/6520.jpg
#   inflating: test/test/6521.jpg
#   inflating: test/test/6522.jpg
#   inflating: test/test/6523.jpg
#   inflating: test/test/6524.jpg
#   inflating: test/test/6525.jpg
#   inflating: test/test/6526.jpg
#   inflating: test/test/6527.jpg
#   inflating: test/test/6528.jpg
#   inflating: test/test/6529.jpg
#   inflating: test/test/653.jpg
#   inflating: test/test/6530.jpg
#   inflating: test/test/6531.jpg
#   inflating: test/test/6532.jpg
#   inflating: test/test/6533.jpg
#   inflating: test/test/6534.jpg
#   inflating: test/test/6535.jpg
#   inflating: test/test/6536.jpg
#   inflating: test/test/6537.jpg
#   inflating: test/test/6538.jpg
#   inflating: test/test/6539.jpg
#   inflating: test/test/654.jpg
#   inflating: test/test/6540.jpg
#   inflating: test/test/6541.jpg
#   inflating: test/test/6542.jpg
#   inflating: test/test/6543.jpg
#   inflating: test/test/6544.jpg
#   inflating: test/test/6545.jpg
#   inflating: test/test/6546.jpg
#   inflating: test/test/6547.jpg
#   inflating: test/test/6548.jpg
#   inflating: test/test/6549.jpg
#   inflating: test/test/655.jpg
#   inflating: test/test/6550.jpg
#   inflating: test/test/6551.jpg
#   inflating: test/test/6552.jpg
#   inflating: test/test/6553.jpg
#   inflating: test/test/6554.jpg
#   inflating: test/test/6555.jpg
#   inflating: test/test/6556.jpg
#   inflating: test/test/6557.jpg
#   inflating: test/test/6558.jpg
#   inflating: test/test/6559.jpg
#   inflating: test/test/656.jpg
#   inflating: test/test/6560.jpg
#   inflating: test/test/6561.jpg
#   inflating: test/test/6562.jpg
#   inflating: test/test/6563.jpg
#   inflating: test/test/6564.jpg
#   inflating: test/test/6565.jpg
#   inflating: test/test/6566.jpg
#   inflating: test/test/6567.jpg
#   inflating: test/test/6568.jpg
#   inflating: test/test/6569.jpg
#   inflating: test/test/657.jpg
#   inflating: test/test/6570.jpg
#   inflating: test/test/6571.jpg
#   inflating: test/test/6572.jpg
#   inflating: test/test/6573.jpg
#   inflating: test/test/6574.jpg
#   inflating: test/test/6575.jpg
#   inflating: test/test/6576.jpg
#   inflating: test/test/6577.jpg
#   inflating: test/test/6578.jpg
#   inflating: test/test/6579.jpg
#   inflating: test/test/658.jpg
#   inflating: test/test/6580.jpg
#   inflating: test/test/6581.jpg
#   inflating: test/test/6582.jpg
#   inflating: test/test/6583.jpg
#   inflating: test/test/6584.jpg
#   inflating: test/test/6585.jpg
#   inflating: test/test/6586.jpg
#   inflating: test/test/6587.jpg
#   inflating: test/test/6588.jpg
#   inflating: test/test/6589.jpg
#   inflating: test/test/659.jpg
#   inflating: test/test/6590.jpg
#   inflating: test/test/6591.jpg
#   inflating: test/test/6592.jpg
#   inflating: test/test/6593.jpg
#   inflating: test/test/6594.jpg
#   inflating: test/test/6595.jpg
#   inflating: test/test/6596.jpg
#   inflating: test/test/6597.jpg
#   inflating: test/test/6598.jpg
#   inflating: test/test/6599.jpg
#   inflating: test/test/66.jpg
#   inflating: test/test/660.jpg
#   inflating: test/test/6600.jpg
#   inflating: test/test/6601.jpg
#   inflating: test/test/6602.jpg
#   inflating: test/test/6603.jpg
#   inflating: test/test/6604.jpg
#   inflating: test/test/6605.jpg
#   inflating: test/test/6606.jpg
#   inflating: test/test/6607.jpg
#   inflating: test/test/6608.jpg
#   inflating: test/test/6609.jpg
#   inflating: test/test/661.jpg
#   inflating: test/test/6610.jpg
#   inflating: test/test/6611.jpg
#   inflating: test/test/6612.jpg
#   inflating: test/test/6613.jpg
#   inflating: test/test/6614.jpg
#   inflating: test/test/6615.jpg
#   inflating: test/test/6616.jpg
#   inflating: test/test/6617.jpg
#   inflating: test/test/6618.jpg
#   inflating: test/test/6619.jpg
#   inflating: test/test/662.jpg
#   inflating: test/test/6620.jpg
#   inflating: test/test/6621.jpg
#   inflating: test/test/6622.jpg
#   inflating: test/test/6623.jpg
#   inflating: test/test/6624.jpg
#   inflating: test/test/6625.jpg
#   inflating: test/test/6626.jpg
#   inflating: test/test/6627.jpg
#   inflating: test/test/6628.jpg
#   inflating: test/test/6629.jpg
#   inflating: test/test/663.jpg
#   inflating: test/test/6630.jpg
#   inflating: test/test/6631.jpg
#   inflating: test/test/6632.jpg
# ...
#   inflating: test/test/962.jpg
#   inflating: test/test/9620.jpg
#   inflating: test/test/9621.jpg
#   inflating: test/test/9622.jpg
#   inflating: test/test/9623.jpg
#   inflating: test/test/9624.jpg
#   inflating: test/test/9625.jpg
#   inflating: test/test/9626.jpg
#   inflating: test/test/9627.jpg
#   inflating: test/test/9628.jpg
#   inflating: test/test/9629.jpg
#   inflating: test/test/963.jpg
#   inflating: test/test/9630.jpg
#   inflating: test/test/9631.jpg
#   inflating: test/test/9632.jpg
#   inflating: test/test/9633.jpg
#   inflating: test/test/9634.jpg
#   inflating: test/test/9635.jpg
#   inflating: test/test/9636.jpg
#   inflating: test/test/9637.jpg
#   inflating: test/test/9638.jpg
#   inflating: test/test/9639.jpg
#   inflating: test/test/964.jpg
#   inflating: test/test/9640.jpg
#   inflating: test/test/9641.jpg
#   inflating: test/test/9642.jpg
#   inflating: test/test/9643.jpg
#   inflating: test/test/9644.jpg
#   inflating: test/test/9645.jpg
#   inflating: test/test/9646.jpg
#   inflating: test/test/9647.jpg
#   inflating: test/test/9648.jpg
#   inflating: test/test/9649.jpg
#   inflating: test/test/965.jpg
#   inflating: test/test/9650.jpg
#   inflating: test/test/9651.jpg
#   inflating: test/test/9652.jpg
#   inflating: test/test/9653.jpg
#   inflating: test/test/9654.jpg
#   inflating: test/test/9655.jpg
#   inflating: test/test/9656.jpg
#   inflating: test/test/9657.jpg
#   inflating: test/test/9658.jpg
#   inflating: test/test/9659.jpg
#   inflating: test/test/966.jpg
#   inflating: test/test/9660.jpg
#   inflating: test/test/9661.jpg
#   inflating: test/test/9662.jpg
#   inflating: test/test/9663.jpg
#   inflating: test/test/9664.jpg
#   inflating: test/test/9665.jpg
#   inflating: test/test/9666.jpg
#   inflating: test/test/9667.jpg
#   inflating: test/test/9668.jpg
#   inflating: test/test/9669.jpg
#   inflating: test/test/967.jpg
#   inflating: test/test/9670.jpg
#   inflating: test/test/9671.jpg
#   inflating: test/test/9672.jpg
#   inflating: test/test/9673.jpg
#   inflating: test/test/9674.jpg
#   inflating: test/test/9675.jpg
#   inflating: test/test/9676.jpg
#   inflating: test/test/9677.jpg
#   inflating: test/test/9678.jpg
#   inflating: test/test/9679.jpg
#   inflating: test/test/968.jpg
#   inflating: test/test/9680.jpg
#   inflating: test/test/9681.jpg
#   inflating: test/test/9682.jpg
#   inflating: test/test/9683.jpg
#   inflating: test/test/9684.jpg
#   inflating: test/test/9685.jpg
#   inflating: test/test/9686.jpg
#   inflating: test/test/9687.jpg
#   inflating: test/test/9688.jpg
#   inflating: test/test/9689.jpg
#   inflating: test/test/969.jpg
#   inflating: test/test/9690.jpg
#   inflating: test/test/9691.jpg
#   inflating: test/test/9692.jpg
#   inflating: test/test/9693.jpg
#   inflating: test/test/9694.jpg
#   inflating: test/test/9695.jpg
#   inflating: test/test/9696.jpg
#   inflating: test/test/9697.jpg
#   inflating: test/test/9698.jpg
#   inflating: test/test/9699.jpg
#   inflating: test/test/97.jpg
#   inflating: test/test/970.jpg
#   inflating: test/test/9700.jpg
#   inflating: test/test/9701.jpg
#   inflating: test/test/9702.jpg
#   inflating: test/test/9703.jpg
#   inflating: test/test/9704.jpg
#   inflating: test/test/9705.jpg
#   inflating: test/test/9706.jpg
#   inflating: test/test/9707.jpg
#   inflating: test/test/9708.jpg
#   inflating: test/test/9709.jpg
#   inflating: test/test/971.jpg
#   inflating: test/test/9710.jpg
#   inflating: test/test/9711.jpg
#   inflating: test/test/9712.jpg
#   inflating: test/test/9713.jpg
#   inflating: test/test/9714.jpg
#   inflating: test/test/9715.jpg
#   inflating: test/test/9716.jpg
#   inflating: test/test/9717.jpg
#   inflating: test/test/9718.jpg
#   inflating: test/test/9719.jpg
#   inflating: test/test/972.jpg
#   inflating: test/test/9720.jpg
#   inflating: test/test/9721.jpg
#   inflating: test/test/9722.jpg
#   inflating: test/test/9723.jpg
#   inflating: test/test/9724.jpg
#   inflating: test/test/9725.jpg
#   inflating: test/test/9726.jpg
#   inflating: test/test/9727.jpg
#   inflating: test/test/9728.jpg
#   inflating: test/test/9729.jpg
#   inflating: test/test/973.jpg
#   inflating: test/test/9730.jpg
#   inflating: test/test/9731.jpg
#   inflating: test/test/9732.jpg
#   inflating: test/test/9733.jpg
#   inflating: test/test/9734.jpg
#   inflating: test/test/9735.jpg
#   inflating: test/test/9736.jpg
#   inflating: test/test/9737.jpg
#   inflating: test/test/9738.jpg
#   inflating: test/test/9739.jpg
#   inflating: test/test/974.jpg
#   inflating: test/test/9740.jpg
#   inflating: test/test/9741.jpg
#   inflating: test/test/9742.jpg
#   inflating: test/test/9743.jpg
#   inflating: test/test/9744.jpg
#   inflating: test/test/9745.jpg
#   inflating: test/test/9746.jpg
#   inflating: test/test/9747.jpg
#   inflating: test/test/9748.jpg
#   inflating: test/test/9749.jpg
#   inflating: test/test/975.jpg
#   inflating: test/test/9750.jpg
#   inflating: test/test/9751.jpg
#   inflating: test/test/9752.jpg
#   inflating: test/test/9753.jpg
#   inflating: test/test/9754.jpg
#   inflating: test/test/9755.jpg
#   inflating: test/test/9756.jpg
#   inflating: test/test/9757.jpg
#   inflating: test/test/9758.jpg
#   inflating: test/test/9759.jpg
#   inflating: test/test/976.jpg
#   inflating: test/test/9760.jpg
#   inflating: test/test/9761.jpg
#   inflating: test/test/9762.jpg
#   inflating: test/test/9763.jpg
#   inflating: test/test/9764.jpg
#   inflating: test/test/9765.jpg
#   inflating: test/test/9766.jpg
#   inflating: test/test/9767.jpg
#   inflating: test/test/9768.jpg
#   inflating: test/test/9769.jpg
#   inflating: test/test/977.jpg
#   inflating: test/test/9770.jpg
#   inflating: test/test/9771.jpg
#   inflating: test/test/9772.jpg
#   inflating: test/test/9773.jpg
#   inflating: test/test/9774.jpg
#   inflating: test/test/9775.jpg
#   inflating: test/test/9776.jpg
#   inflating: test/test/9777.jpg
#   inflating: test/test/9778.jpg
#   inflating: test/test/9779.jpg
#   inflating: test/test/978.jpg
#   inflating: test/test/9780.jpg
#   inflating: test/test/9781.jpg
#   inflating: test/test/9782.jpg
#   inflating: test/test/9783.jpg
#   inflating: test/test/9784.jpg
#   inflating: test/test/9785.jpg
#   inflating: test/test/9786.jpg
#   inflating: test/test/9787.jpg
#   inflating: test/test/9788.jpg
#   inflating: test/test/9789.jpg
#   inflating: test/test/979.jpg
#   inflating: test/test/9790.jpg
#   inflating: test/test/9791.jpg
#   inflating: test/test/9792.jpg
#   inflating: test/test/9793.jpg
#   inflating: test/test/9794.jpg
#   inflating: test/test/9795.jpg
#   inflating: test/test/9796.jpg
#   inflating: test/test/9797.jpg
#   inflating: test/test/9798.jpg
#   inflating: test/test/9799.jpg
#   inflating: test/test/98.jpg
#   inflating: test/test/980.jpg
#   inflating: test/test/9800.jpg
#   inflating: test/test/9801.jpg
#   inflating: test/test/9802.jpg
#   inflating: test/test/9803.jpg
#   inflating: test/test/9804.jpg
#   inflating: test/test/9805.jpg
#   inflating: test/test/9806.jpg
#   inflating: test/test/9807.jpg
#   inflating: test/test/9808.jpg
#   inflating: test/test/9809.jpg
#   inflating: test/test/981.jpg
#   inflating: test/test/9810.jpg
#   inflating: test/test/9811.jpg
#   inflating: test/test/9812.jpg
#   inflating: test/test/9813.jpg
#   inflating: test/test/9814.jpg
#   inflating: test/test/9815.jpg
#   inflating: test/test/9816.jpg
#   inflating: test/test/9817.jpg
#   inflating: test/test/9818.jpg
#   inflating: test/test/9819.jpg
#   inflating: test/test/982.jpg
#   inflating: test/test/9820.jpg
#   inflating: test/test/9821.jpg
#   inflating: test/test/9822.jpg
#   inflating: test/test/9823.jpg
#   inflating: test/test/9824.jpg
#   inflating: test/test/9825.jpg
#   inflating: test/test/9826.jpg
#   inflating: test/test/9827.jpg
#   inflating: test/test/9828.jpg
#   inflating: test/test/9829.jpg
#   inflating: test/test/983.jpg
#   inflating: test/test/9830.jpg
#   inflating: test/test/9831.jpg
#   inflating: test/test/9832.jpg
#   inflating: test/test/9833.jpg
#   inflating: test/test/9834.jpg
#   inflating: test/test/9835.jpg
#   inflating: test/test/9836.jpg
#   inflating: test/test/9837.jpg
#   inflating: test/test/9838.jpg
#   inflating: test/test/9839.jpg
#   inflating: test/test/984.jpg
#   inflating: test/test/9840.jpg
#   inflating: test/test/9841.jpg
#   inflating: test/test/9842.jpg
#   inflating: test/test/9843.jpg
#   inflating: test/test/9844.jpg
#   inflating: test/test/9845.jpg
#   inflating: test/test/9846.jpg
#   inflating: test/test/9847.jpg
#   inflating: test/test/9848.jpg
#   inflating: test/test/9849.jpg
#   inflating: test/test/985.jpg
#   inflating: test/test/9850.jpg
#   inflating: test/test/9851.jpg
#   inflating: test/test/9852.jpg
#   inflating: test/test/9853.jpg
#   inflating: test/test/9854.jpg
#   inflating: test/test/9855.jpg
#   inflating: test/test/9856.jpg
#   inflating: test/test/9857.jpg
#   inflating: test/test/9858.jpg
#   inflating: test/test/9859.jpg
#   inflating: test/test/986.jpg
#   inflating: test/test/9860.jpg
#   inflating: test/test/9861.jpg
#   inflating: test/test/9862.jpg
#   inflating: test/test/9863.jpg
#   inflating: test/test/9864.jpg
#   inflating: test/test/9865.jpg
#   inflating: test/test/9866.jpg
#   inflating: test/test/9867.jpg
#   inflating: test/test/9868.jpg
#   inflating: test/test/9869.jpg
#   inflating: test/test/987.jpg
#   inflating: test/test/9870.jpg
#   inflating: test/test/9871.jpg
#   inflating: test/test/9872.jpg
#   inflating: test/test/9873.jpg
#   inflating: test/test/9874.jpg
#   inflating: test/test/9875.jpg
#   inflating: test/test/9876.jpg
#   inflating: test/test/9877.jpg
#   inflating: test/test/9878.jpg
#   inflating: test/test/9879.jpg
#   inflating: test/test/988.jpg
#   inflating: test/test/9880.jpg
#   inflating: test/test/9881.jpg
#   inflating: test/test/9882.jpg
#   inflating: test/test/9883.jpg
#   inflating: test/test/9884.jpg
#   inflating: test/test/9885.jpg
#   inflating: test/test/9886.jpg
#   inflating: test/test/9887.jpg
#   inflating: test/test/9888.jpg
#   inflating: test/test/9889.jpg
#   inflating: test/test/989.jpg
#   inflating: test/test/9890.jpg
#   inflating: test/test/9891.jpg
#   inflating: test/test/9892.jpg
#   inflating: test/test/9893.jpg
#   inflating: test/test/9894.jpg
#   inflating: test/test/9895.jpg
#   inflating: test/test/9896.jpg
#   inflating: test/test/9897.jpg
#   inflating: test/test/9898.jpg
#   inflating: test/test/9899.jpg
#   inflating: test/test/99.jpg
#   inflating: test/test/990.jpg
#   inflating: test/test/9900.jpg
#   inflating: test/test/9901.jpg
#   inflating: test/test/9902.jpg
#   inflating: test/test/9903.jpg
#   inflating: test/test/9904.jpg
#   inflating: test/test/9905.jpg
#   inflating: test/test/9906.jpg
#   inflating: test/test/9907.jpg
#   inflating: test/test/9908.jpg
#   inflating: test/test/9909.jpg
#   inflating: test/test/991.jpg
#   inflating: test/test/9910.jpg
#   inflating: test/test/9911.jpg
#   inflating: test/test/9912.jpg
#   inflating: test/test/9913.jpg
#   inflating: test/test/9914.jpg
#   inflating: test/test/9915.jpg
#   inflating: test/test/9916.jpg
#   inflating: test/test/9917.jpg
#   inflating: test/test/9918.jpg
#   inflating: test/test/9919.jpg
#   inflating: test/test/992.jpg
#   inflating: test/test/9920.jpg
#   inflating: test/test/9921.jpg
#   inflating: test/test/9922.jpg
#   inflating: test/test/9923.jpg
#   inflating: test/test/9924.jpg
#   inflating: test/test/9925.jpg
#   inflating: test/test/9926.jpg
#   inflating: test/test/9927.jpg
#   inflating: test/test/9928.jpg
#   inflating: test/test/9929.jpg
#   inflating: test/test/993.jpg
#   inflating: test/test/9930.jpg
#   inflating: test/test/9931.jpg
#   inflating: test/test/9932.jpg
#   inflating: test/test/9933.jpg
#   inflating: test/test/9934.jpg
#   inflating: test/test/9935.jpg
#   inflating: test/test/9936.jpg
#   inflating: test/test/9937.jpg
#   inflating: test/test/9938.jpg
#   inflating: test/test/9939.jpg
#   inflating: test/test/994.jpg
#   inflating: test/test/9940.jpg
#   inflating: test/test/9941.jpg
#   inflating: test/test/9942.jpg
#   inflating: test/test/9943.jpg
#   inflating: test/test/9944.jpg
#   inflating: test/test/9945.jpg
#   inflating: test/test/9946.jpg
#   inflating: test/test/9947.jpg
#   inflating: test/test/9948.jpg
#   inflating: test/test/9949.jpg
#   inflating: test/test/995.jpg
#   inflating: test/test/9950.jpg
#   inflating: test/test/9951.jpg
#   inflating: test/test/9952.jpg
#   inflating: test/test/9953.jpg
#   inflating: test/test/9954.jpg
#   inflating: test/test/9955.jpg
#   inflating: test/test/9956.jpg
#   inflating: test/test/9957.jpg
#   inflating: test/test/9958.jpg
#   inflating: test/test/9959.jpg
#   inflating: test/test/996.jpg
#   inflating: test/test/9960.jpg
#   inflating: test/test/9961.jpg
#   inflating: test/test/9962.jpg
#   inflating: test/test/9963.jpg
#   inflating: test/test/9964.jpg
#   inflating: test/test/9965.jpg
#   inflating: test/test/9966.jpg
#   inflating: test/test/9967.jpg
#   inflating: test/test/9968.jpg
#   inflating: test/test/9969.jpg
#   inflating: test/test/997.jpg
#   inflating: test/test/9970.jpg
#   inflating: test/test/9971.jpg
#   inflating: test/test/9972.jpg
#   inflating: test/test/9973.jpg
#   inflating: test/test/9974.jpg
#   inflating: test/test/9975.jpg
#   inflating: test/test/9976.jpg
#   inflating: test/test/9977.jpg
#   inflating: test/test/9978.jpg
#   inflating: test/test/9979.jpg
#   inflating: test/test/998.jpg
#   inflating: test/test/9980.jpg
#   inflating: test/test/9981.jpg
#   inflating: test/test/9982.jpg
#   inflating: test/test/9983.jpg
#   inflating: test/test/9984.jpg
#   inflating: test/test/9985.jpg
#   inflating: test/test/9986.jpg
#   inflating: test/test/9987.jpg
#   inflating: test/test/9988.jpg
#   inflating: test/test/9989.jpg
#   inflating: test/test/999.jpg
#   inflating: test/test/9990.jpg
#   inflating: test/test/9991.jpg
#   inflating: test/test/9992.jpg
#   inflating: test/test/9993.jpg
#   inflating: test/test/9994.jpg
#   inflating: test/test/9995.jpg
#   inflating: test/test/9996.jpg
#   inflating: test/test/9997.jpg
#   inflating: test/test/9998.jpg
#   inflating: test/test/9999.jpg

# %%
# creating dataframe

# labels
file = os.listdir("./train/train")
Labels = list(map(lambda x: x.split('.')[0], file))

# %%
# for filenames
from pathlib import Path
f = Path("./train/train")
File_Path = list(f.glob(r"**/*.jpg"))

# dataframe
File_Path = pd.Series(File_Path).astype(str)
Labels = pd.Series(Labels)
df = pd.concat([File_Path,Labels],axis=1)
df.columns = ['filename', 'category']

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   filename  25000 non-null  object
#  1   category  25000 non-null  object
# dtypes: object(2)
# memory usage: 390.8+ KB

# %%
df.head()
# Out:
#                     filename category
# 0   train/train/dog.1012.jpg      dog
# 1   train/train/dog.1375.jpg      dog
# 2  train/train/dog.11960.jpg      dog
# 3   train/train/dog.4271.jpg      dog
# 4   train/train/cat.9079.jpg      cat

# %%
df['category'].value_counts()
# Out:
# dog    12500
# cat    12500
# Name: category, dtype: int64

# %%
df.isnull().sum()
# Out:
# filename    0
# category    0
# dtype: int64

# %%
train_data, valid_data = train_test_split(df, test_size= 0.3, random_state = 42)
print(train_data.shape , valid_data.shape)
# Out:
# (17500, 2) (7500, 2)

# %% [markdown]
# # Scaling

# %%
# resetting index

train_data = train_data.reset_index(drop=True)

img_gen = ImageDataGenerator(    
    rotation_range=10,
    rescale=1./255,
    horizontal_flip=True,
)
train_gen = img_gen.flow_from_dataframe(
    train_data, 
    x_col='filename',
    y_col='category',
    target_size= (128,128),
    class_mode='categorical',
    batch_size=32,
    shuffle = False
)
# Out:
# Found 17500 validated image filenames belonging to 2 classes.

# %%
train_data.head()
# Out:
#                    filename category
# 0  train/train/cat.5954.jpg      cat
# 1   train/train/cat.223.jpg      cat
# 2  train/train/cat.2071.jpg      cat
# 3  train/train/cat.6525.jpg      cat
# 4  train/train/dog.9332.jpg      dog

# %%
valid_data = valid_data.reset_index(drop=True)
valid_gen = img_gen.flow_from_dataframe(
    valid_data, 
    x_col='filename',
    y_col='category',
    target_size= (128,128),
    class_mode='categorical',
    batch_size=32,
    shuffle = False
)
# Out:
# Found 7500 validated image filenames belonging to 2 classes.

# %%
valid_data.head()
# Out:
#                    filename category
# 0  train/train/cat.9080.jpg      cat
# 1  train/train/dog.7276.jpg      dog
# 2   train/train/dog.580.jpg      dog
# 3  train/train/cat.6573.jpg      cat
# 4  train/train/dog.2708.jpg      dog

# %%
# Define share for Keras
input_shape = (128,128,3)

# %% [markdown]
# # CNN Models
#
# Correlation operation to capture spatial correlation at very very low level

# %% [markdown]
# ## M1: 2 Layers CNN
# Dropout: A Simple Way to Prevent Neural Networks from Overfitting,

# %%
# creating model
model1 = Sequential()

# Adding layers

# Conv and pooling layers 
model1.add(Conv2D(32, (3, 3), activation='relu', strides=(1, 1),input_shape=input_shape))
# Maxpoling - Reducing the dimensions and summarizing the featues over larger area of image - local (edges) to global features (eyes, mouth)
# No padding is required with max pooling
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(32, (3, 3), activation='relu', strides=(1, 1),input_shape=input_shape))
model1.add(MaxPooling2D(pool_size=(2, 2)))

#flatten layer
model1.add(Flatten())

# dense layers with dropout
model1.add(Dense(128, activation = 'relu'))
# Dropout: A Simple Way to Prevent Neural Networks from Overfitting
model1.add(Dropout(rate = 0.3))
model1.add(Dense(64, activation = 'relu'))

#output layer
model1.add(Dense(2, activation='softmax'))

# %%
# compile model
model1.compile(optimizer='adam',
              loss="categorical_crossentropy", 
              metrics=['accuracy'])

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 28800)             0
#
#  dense (Dense)               (None, 128)               3686528
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 3,705,058
# Trainable params: 3,705,058
# Non-trainable params: 0
# _________________________________________________________________

# %%
# preventing overfitting
earlystop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', min_delta=0, patience=10, verbose=0,
    mode='auto', baseline=None, restore_best_weights=False
)

from keras.callbacks import EarlyStopping, ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', 
                                            patience=2, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
# fitting a basic model
history = model1.fit(train_gen,
                    validation_data = valid_gen,
                    epochs = 10,
                    verbose=1, #for animated bar during epoch
                    callbacks = [earlystop, learning_rate_reduction])
# Out:
# Epoch 1/10
# 547/547 [==============================] - 443s 808ms/step - loss: 0.6550 - accuracy: 0.6175 - val_loss: 0.6244 - val_accuracy: 0.6625 - lr: 0.0010
# Epoch 2/10
# 547/547 [==============================] - 430s 785ms/step - loss: 0.5877 - accuracy: 0.6981 - val_loss: 0.5518 - val_accuracy: 0.7209 - lr: 0.0010
# Epoch 3/10
# 547/547 [==============================] - 429s 783ms/step - loss: 0.5440 - accuracy: 0.7245 - val_loss: 0.5358 - val_accuracy: 0.7360 - lr: 0.0010
# Epoch 4/10
# 547/547 [==============================] - 428s 782ms/step - loss: 0.5021 - accuracy: 0.7588 - val_loss: 0.4892 - val_accuracy: 0.7647 - lr: 0.0010
# Epoch 5/10
# 547/547 [==============================] - 427s 781ms/step - loss: 0.4634 - accuracy: 0.7844 - val_loss: 0.4587 - val_accuracy: 0.7857 - lr: 0.0010
# Epoch 6/10
# 547/547 [==============================] - 428s 782ms/step - loss: 0.4410 - accuracy: 0.7949 - val_loss: 0.4830 - val_accuracy: 0.7737 - lr: 0.0010
# Epoch 7/10
# 547/547 [==============================] - 427s 780ms/step - loss: 0.4124 - accuracy: 0.8123 - val_loss: 0.4359 - val_accuracy: 0.8008 - lr: 0.0010
# Epoch 8/10
# 547/547 [==============================] - 427s 780ms/step - loss: 0.3952 - accuracy: 0.8226 - val_loss: 0.4446 - val_accuracy: 0.7969 - lr: 0.0010
# Epoch 9/10
# 547/547 [==============================] - 428s 782ms/step - loss: 0.3695 - accuracy: 0.8374 - val_loss: 0.4370 - val_accuracy: 0.8035 - lr: 0.0010
# Epoch 10/10
# 547/547 [==============================] - 428s 782ms/step - loss: 0.3529 - accuracy: 0.8435 - val_loss: 0.4358 - val_accuracy: 0.7996 - lr: 0.0010

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt

#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', label = "Training Accuracy")
plt.plot(epochs, val_acc, 'b', label = "Validation Accuracy")
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = "upper left")
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', label = "Training Loss")
plt.plot(epochs, val_loss, 'b', label = "Validation Loss")
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = "upper right")
plt.figure()
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Training and Validation Loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
# expected output
y_valid1 = valid_data.category
y_pred1=model1.predict_generator(generator=valid_gen, verbose=1)
pred1 = np.argmax(y_pred1,axis = 1) # pick the class with highest probability
labels = (valid_gen.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred11 = [labels[k] for k in pred1]
# Out:
# 235/235 [==============================] - 74s 315ms/step

# %%
print(classification_report(y_valid1, pred11))
# Out:
#               precision    recall  f1-score   support
#
#          cat       0.81      0.79      0.80      3781
#          dog       0.79      0.81      0.80      3719
#
#     accuracy                           0.80      7500
#    macro avg       0.80      0.80      0.80      7500
# weighted avg       0.80      0.80      0.80      7500

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_valid1, pred11),annot=True,fmt='5.0f',cmap="Purples")
plt.title('Confusion Matrix : Actual v/s Predicted', y=1.05, size=15)
#ax = fig.add_subplot(111)
plt.xlabel("Predicted Value")
plt.ylabel("Actual Value")
plt.show()
# Out:
# Text(0.5, 1.05, 'Confusion Matrix : Actual v/s Predicted')
# Text(0.5, 12.5, 'Predicted Value')
# Text(30.5, 0.5, 'Actual Value')

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
y_valid11 = le.fit_transform(y_valid1)
#y_valid1 =  label_img(y_valid)
pred111 = pd.Series(y_pred1[:,1])

# %%
from sklearn.metrics import precision_recall_curve

#y_scores = best_rfgs.predict_proba(X_valid)
#y_scores = y_scores[:,1]

precision, recall, threshold = precision_recall_curve(y_valid11, pred111)
def plot_precision_and_recall(precision, recall, threshold):
    plt.plot(threshold, precision[:-1], "r-", label="Precision", linewidth=5)
    plt.plot(threshold, recall[:-1], "b", label="Recall", linewidth=5)
    plt.xlabel("Threshold", fontsize=19)
    plt.legend(loc="upper right", fontsize=19)
    plt.ylim([0, 1])

plt.figure(figsize=(14, 7))
plot_precision_and_recall(precision, recall, threshold)
plt.show()

# %% [markdown]
# Although the accuracy is very high, we can see that the training accuracy consistently increase after 10 epochs at a much higher rate compared to the validation epoch indicating a potential overfitting.The Kaggle log loss score for Test dataset was 0.45 ,which further confirms that this model is overfitting on the training dataset and we have scope of tunning it further.

# %% [markdown]
# ## M2: 3 Layers CNN

# %%
# creating model
model2 = Sequential()

# Adding layers

# 1: Convolution layer with 32 filters, strides
model2.add(Conv2D(32, (3, 3), activation='relu', strides=(1, 1),input_shape=input_shape))
# 2: Max pooling layer
model2.add(MaxPooling2D(pool_size=(2, 2)))

# 3: Convolution layer with 64 filter, strides and Max Pooling layer
model2.add(Conv2D(64, (3, 3), activation='relu', strides=(1, 1),input_shape=input_shape))
model2.add(MaxPooling2D(pool_size=(2, 2)))

# 4: Convolution layer with 64 filters
model2.add(Conv2D(64, (3, 3), activation='relu', strides=(1, 1),input_shape=input_shape))
model2.add(MaxPooling2D(pool_size=(2, 2)))

# 6: Fully-connected 512 node layer
model2.add(Dense(512, activation='relu'))

# 7: Dropout (50%) layer to combat overfitting
model2.add(Dropout(rate = 0.5))

# 8: Fully-connected layer with two outputs
#flatten layer to get the desired two outputs
# This is where Learning takes place
model2.add(Flatten())
model2.add(Dense(2, activation='softmax'))

# %%
model2.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 126, 126, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 63, 63, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  dense_3 (Dense)             (None, 14, 14, 512)       33280
#
#  dropout_1 (Dropout)         (None, 14, 14, 512)       0
#
#  flatten_1 (Flatten)         (None, 100352)            0
#
#  dense_4 (Dense)             (None, 2)                 200706
#
# =================================================================
# Total params: 290,306
# Trainable params: 290,306
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fitting a basic model
history2 = model2.fit(train_gen,
                    validation_data = valid_gen,
                    epochs = 10,
                    verbose=1, #for animated bar during epoch
                    callbacks = [earlystop, learning_rate_reduction])
# Out:
# Epoch 1/10
# 547/547 [==============================] - 599s 1s/step - loss: 0.6477 - accuracy: 0.6262 - val_loss: 0.6079 - val_accuracy: 0.6515 - lr: 0.0010
# Epoch 2/10
# 547/547 [==============================] - 593s 1s/step - loss: 0.5496 - accuracy: 0.7211 - val_loss: 0.5495 - val_accuracy: 0.7189 - lr: 0.0010
# Epoch 3/10
# 547/547 [==============================] - 593s 1s/step - loss: 0.4916 - accuracy: 0.7643 - val_loss: 0.4778 - val_accuracy: 0.7693 - lr: 0.0010
# Epoch 4/10
# 547/547 [==============================] - 602s 1s/step - loss: 0.4479 - accuracy: 0.7937 - val_loss: 0.4395 - val_accuracy: 0.7989 - lr: 0.0010
# Epoch 5/10
# 547/547 [==============================] - 604s 1s/step - loss: 0.4176 - accuracy: 0.8109 - val_loss: 0.3980 - val_accuracy: 0.8233 - lr: 0.0010
# Epoch 6/10
# 547/547 [==============================] - 599s 1s/step - loss: 0.3928 - accuracy: 0.8246 - val_loss: 0.3598 - val_accuracy: 0.8399 - lr: 0.0010
# Epoch 7/10
# 547/547 [==============================] - 596s 1s/step - loss: 0.3698 - accuracy: 0.8374 - val_loss: 0.3446 - val_accuracy: 0.8487 - lr: 0.0010
# Epoch 8/10
# 547/547 [==============================] - 598s 1s/step - loss: 0.3631 - accuracy: 0.8422 - val_loss: 0.3920 - val_accuracy: 0.8360 - lr: 0.0010
# Epoch 9/10
# 547/547 [==============================] - 598s 1s/step - loss: 0.3488 - accuracy: 0.8502 - val_loss: 0.3325 - val_accuracy: 0.8547 - lr: 0.0010
# Epoch 10/10
#  74/547 [===>..........................] - ETA: 7:24 - loss: 0.3399 - accuracy: 0.8526

# %%
# expected output
y_valid = valid_data.category
y_pred=model2.predict_generator(generator=valid_gen, verbose=1)
pred = np.argmax(y_pred,axis = 1) # pick the class with highest probability
labels = (valid_gen.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred2 = [labels[k] for k in pred]
# Out:
# 235/235 [==============================] - 102s 433ms/step

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history2.history['accuracy']
val_acc=history2.history['val_accuracy']
loss=history2.history['loss']
val_loss=history2.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', label = "Training Accuracy")
plt.plot(epochs, val_acc, 'b', label = "Validation Accuracy")
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = "upper left")
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', label = "Training Loss")
plt.plot(epochs, val_loss, 'b', label = "Validation Loss")
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = "upper right")
plt.figure()
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Training and Validation Loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
print(classification_report(y_valid, pred2))
# Out:
#               precision    recall  f1-score   support
#
#          cat       0.85      0.86      0.85      3781
#          dog       0.85      0.84      0.85      3719
#
#     accuracy                           0.85      7500
#    macro avg       0.85      0.85      0.85      7500
# weighted avg       0.85      0.85      0.85      7500

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_valid, pred2),annot=True,fmt='5.0f',cmap="Purples")
plt.title('Confusion Matrix : Actual v/s Predicted', y=1.05, size=15)
#ax = fig.add_subplot(111)
plt.xlabel("Predicted Value")
plt.ylabel("Actual Value")
plt.show()
# Out:
# Text(0.5, 1.05, 'Confusion Matrix : Actual v/s Predicted')
# Text(0.5, 12.5, 'Predicted Value')
# Text(30.5, 0.5, 'Actual Value')

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
y_valid11 = le.fit_transform(y_valid)
#y_valid1 =  label_img(y_valid)
pred3 = pd.Series(y_pred[:,1])

# %%
from sklearn.metrics import precision_recall_curve

#y_scores = best_rfgs.predict_proba(X_valid)
#y_scores = y_scores[:,1]

precision, recall, threshold = precision_recall_curve(y_valid11, pred3)
def plot_precision_and_recall(precision, recall, threshold):
    plt.plot(threshold, precision[:-1], "r-", label="Precision", linewidth=5)
    plt.plot(threshold, recall[:-1], "b", label="Recall", linewidth=5)
    plt.xlabel("Threshold", fontsize=19)
    plt.legend(loc="upper right", fontsize=19)
    plt.ylim([0, 1])

plt.figure(figsize=(14, 7))
plot_precision_and_recall(precision, recall, threshold)
plt.show()

# %% [markdown]
# The accuracy score is better at 10th epoch compared to our first experiment. Thus, will try experiment 3 with regularization and drop out layers.

# %% [markdown]
# ## M3: 3 Layers CNN
#
# Batch Normalization -  Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch. This has the effect of stabilizing the learning process and dramatically reducing the number of training epochs required to train deep networks.

# %%
model3 = Sequential()
model3.add(Conv2D(32, (3, 3), activation='relu', strides=(1, 1),input_shape=input_shape))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(0.25))

model3.add(Conv2D(64, (3, 3), activation='relu' ))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(0.25))

model3.add(Conv2D(128, (3, 3), activation='relu'))
model3.add(BatchNormalization())
model3.add(MaxPooling2D(pool_size=(2, 2)))
model3.add(Dropout(0.25))

model3.add(Flatten())
model3.add(Dense(512, activation='relu'))
model3.add(BatchNormalization())
model3.add(Dropout(0.5))
model3.add(Dense(2, activation='softmax')) # 2 because we have cat and dog classes

model3.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

model3.summary()

# %%
# fitting a basic model
history3 = model3.fit(train_gen,
                    validation_data = valid_gen,
                    epochs = 10,
                    verbose=1, #for animated bar during epoch
                    callbacks = [earlystop, learning_rate_reduction])
# Out:
# Epoch 1/10
# 547/547 [==============================] - 908s 2s/step - loss: 0.5585 - accuracy: 0.7294 - val_loss: 0.5626 - val_accuracy: 0.7112 - lr: 0.0010
# Epoch 2/10
# 547/547 [==============================] - 912s 2s/step - loss: 0.4477 - accuracy: 0.7931 - val_loss: 0.5795 - val_accuracy: 0.6847 - lr: 0.0010
# Epoch 3/10
# 547/547 [==============================] - 893s 2s/step - loss: 0.3962 - accuracy: 0.8207 - val_loss: 0.4256 - val_accuracy: 0.8181 - lr: 0.0010
# Epoch 4/10
# 547/547 [==============================] - 893s 2s/step - loss: 0.3609 - accuracy: 0.8436 - val_loss: 0.4523 - val_accuracy: 0.8089 - lr: 0.0010
# Epoch 5/10
# 547/547 [==============================] - 887s 2s/step - loss: 0.3378 - accuracy: 0.8531 - val_loss: 0.3744 - val_accuracy: 0.8437 - lr: 0.0010
# Epoch 6/10
# 547/547 [==============================] - 891s 2s/step - loss: 0.3155 - accuracy: 0.8635 - val_loss: 0.9474 - val_accuracy: 0.7212 - lr: 0.0010
# Epoch 7/10
# 547/547 [==============================] - ETA: 0s - loss: 0.2998 - accuracy: 0.8755
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 547/547 [==============================] - 885s 2s/step - loss: 0.2998 - accuracy: 0.8755 - val_loss: 0.3966 - val_accuracy: 0.8147 - lr: 0.0010
# Epoch 8/10
# 547/547 [==============================] - 882s 2s/step - loss: 0.2626 - accuracy: 0.8910 - val_loss: 0.2595 - val_accuracy: 0.8887 - lr: 5.0000e-04
# Epoch 9/10
# 547/547 [==============================] - 887s 2s/step - loss: 0.2459 - accuracy: 0.8978 - val_loss: 0.2954 - val_accuracy: 0.8743 - lr: 5.0000e-04
# Epoch 10/10
# 547/547 [==============================] - ETA: 0s - loss: 0.2368 - accuracy: 0.9002
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 547/547 [==============================] - 888s 2s/step - loss: 0.2368 - accuracy: 0.9002 - val_loss: 0.2944 - val_accuracy: 0.8827 - lr: 5.0000e-04

# %%
# expected output
y_valid = valid_data.category
y_pred=model3.predict_generator(generator=valid_gen, verbose=1)
pred = np.argmax(y_pred,axis = 1) # pick the class with highest probability
labels = (valid_gen.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred2 = [labels[k] for k in pred]
# Out:
# 235/235 [==============================] - 104s 439ms/step

# %%
#-----------------------------------------------------------
# Retrieve a list of list results on training and test data
# sets for each training epoch
#-----------------------------------------------------------
acc=history3.history['accuracy']
val_acc=history3.history['val_accuracy']
loss=history3.history['loss']
val_loss=history3.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

#------------------------------------------------
# Plot training and validation accuracy per epoch
#------------------------------------------------
plt.plot(epochs, acc, 'r', label = "Training Accuracy")
plt.plot(epochs, val_acc, 'b', label = "Validation Accuracy")
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc = "upper left")
plt.figure()

#------------------------------------------------
# Plot training and validation loss per epoch
#------------------------------------------------
plt.plot(epochs, loss, 'r', label = "Training Loss")
plt.plot(epochs, val_loss, 'b', label = "Validation Loss")
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc = "upper right")
plt.figure()
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Accuracy')
# Text(0.5, 1.0, 'Training and Validation Loss')
# Text(0.5, 0, 'Epochs')
# Text(0, 0.5, 'Loss')

# %%
print(classification_report(y_valid, pred2))
# Out:
#               precision    recall  f1-score   support
#
#          cat       0.85      0.93      0.89      3781
#          dog       0.93      0.83      0.87      3719
#
#     accuracy                           0.88      7500
#    macro avg       0.89      0.88      0.88      7500
# weighted avg       0.89      0.88      0.88      7500

# %%
from sklearn.metrics import confusion_matrix
sns.heatmap(confusion_matrix(y_valid, pred2),annot=True,fmt='5.0f',cmap="Purples")
plt.title('Confusion Matrix : Actual v/s Predicted', y=1.05, size=15)
#ax = fig.add_subplot(111)
plt.xlabel("Predicted Value")
plt.ylabel("Actual Value")
plt.show()
# Out:
# Text(0.5, 1.05, 'Confusion Matrix : Actual v/s Predicted')
# Text(0.5, 12.5, 'Predicted Value')
# Text(30.5, 0.5, 'Actual Value')

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
y_valid11 = le.fit_transform(y_valid)
#y_valid1 =  label_img(y_valid)
pred3 = pd.Series(y_pred[:,1])

# %%
from sklearn.metrics import precision_recall_curve

#y_scores = best_rfgs.predict_proba(X_valid)
#y_scores = y_scores[:,1]

precision, recall, threshold = precision_recall_curve(y_valid11, pred3)
def plot_precision_and_recall(precision, recall, threshold):
    plt.plot(threshold, precision[:-1], "r-", label="Precision", linewidth=5)
    plt.plot(threshold, recall[:-1], "b", label="Recall", linewidth=5)
    plt.xlabel("Threshold", fontsize=19)
    plt.legend(loc="upper right", fontsize=19)
    plt.ylim([0, 1])

plt.figure(figsize=(14, 7))
plot_precision_and_recall(precision, recall, threshold)
plt.show()

# %% [markdown]
# Clearly, this model fits the best with the highest accuracy and f1 score for cats as well as dogs .Kaggle log loss score was 0.24 , which means that the model performs well for test dataset as well.

# %% [markdown]
# ##Kaggle Submission

# %%
test_filenames = os.listdir("./test/test")
test_df = pd.DataFrame({
    'filename': test_filenames
})

# %%
test_df.head(5)

# %%
test_image_gen = ImageDataGenerator(rescale=1/255.)

# %%
test_gen = test_image_gen.flow_from_dataframe(
    test_df, 
    "./test/test",
    x_col='filename',
    y_col=None,
    target_size=(128,128),
    class_mode=None,
    batch_size=32,
    shuffle = False # not to shuffle the given data
)

# %%
y_test1=model1.predict_generator(generator=test_gen, verbose=1)
pred_test1 = np.argmax(y_test1,axis = 1)

# %%
# labelling data
labels1 = (train_gen.class_indices)
labels1 = dict((v,k) for k,v in labels1.items())
pred_test11 = [labels1[k] for k in pred_test1]

# %%
submission1 = pd.DataFrame({'id':pd.Series(test_gen.filenames),
                           'label':pd.Series(y_test1[:,1])})
submission1['id'] = submission1.id.str.extract('(\d+)')
submission1['id'] = pd.to_numeric(submission1['id'])
submission1.to_csv("dogs_vs_cats_sub1.csv", index=False)

# %% [markdown]
# ### M1: Kaggle Score: 0.41397
# ![image.png](data:image/png;base64,...)

# %%
y_test2=model2.predict_generator(generator=test_gen, verbose=1)
pred_test2 = np.argmax(y_test2,axis = 1)

# %%
# labelling data
labels2 = (train_gen.class_indices)
labels2 = dict((v,k) for k,v in labels2.items())
pred_test12= [labels2[k] for k in pred_test2]

# %%
submission2 = pd.DataFrame({'id':pd.Series(test_gen.filenames),
                           'label':pd.Series(y_test2[:,1])})
submission2['id'] = submission2.id.str.extract('(\d+)')
submission2['id'] = pd.to_numeric(submission2['id'])
submission2.to_csv("dogs_vs_cats_sub2.csv", index=False)

# %% [markdown]
# ###M2: Kaggle Score: 0.29240
#
# ![image.png](data:image/png;base64,...)

# %%
y_test3=model3.predict_generator(generator=test_gen, verbose=1)
pred_test3 = np.argmax(y_test3,axis = 1)

#pred= model.predict_generator(validation_generator, verbose=1)
#predicted_class_indices=[1 if x >= 0.5 else 0 for x in pred]

# %%
# labelling data
labels3 = (train_gen.class_indices)
labels3 = dict((v,k) for k,v in labels3.items())
pred_test13 = [labels3[k] for k in pred_test3]

# %%
submission3 = pd.DataFrame({'id':pd.Series(test_gen.filenames),
                           'label':pd.Series(y_test3[:,1])})
submission3['id'] = submission3.id.str.extract('(\d+)')
submission3['id'] = pd.to_numeric(submission3['id'])
submission3.to_csv("dogs_vs_cats_sub3.csv", index=False)

# %% [markdown]
# ###M3: Kaggle Score: 0.35020
#
# ![image.png](data:image/png;base64,...)
